# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import load_model
import matplotlib.pyplot as plt
import plotly.express as px
import pandas as pd
import numpy as np
import json
# Out:
# 2024-04-30 02:21:34.256769: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-30 02:21:34.373439: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-30 02:21:34.863929: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/baran-tomik/bin/miniconda3/envs/tf/lib/
# 2024-04-30 02:21:34.864024: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/baran-tomik/bin/miniconda3/envs/tf/lib/
# 2024-04-30 02:21:34.864030: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
checkpoint_model_filepath = 'checkpoints/'
trained_model_filepath = 'trained_models/'
training_data_path = 'data_1m/'
nn_config_path = '../config/nn_config.json'
wandb_config_path = '../config/wandb_config.json'

print('Training data path:', training_data_path)

import nn_model
# Out:
# Training data path: data_1m/
# /home/baran-tomik/bin/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# /home/baran-tomik/bin/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.13.0 and strictly below 2.16.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.10.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
try:
  with open(wandb_config_path, 'r') as f:
    wandb_config = json.load(f)

  wandb_log = True
  wandb_run_name = wandb_config["wandb_run_name"]
  wandb_group_name = wandb_config["wandb_group_name"]
  wandb_entity = wandb_config["wandb_entity"]
  wandb_project_name = wandb_config["wandb_project_name"]
  if wandb_config["new_model"] == 'false':
    new_model = False
  else:
    new_model = True
  run_name_before = wandb_config["run_name_before"]   # Model to be loaded
  if wandb_config["eval_only"] == 'false':
    eval_only = False
  else:
    eval_only = True

  print('wandb_log:', wandb_log)
  print('wandb_run_name:', wandb_run_name)
  print('wandb_group_name:', wandb_group_name)
  print('wandb_entity:', wandb_entity)
  print('wandb_project_name:', wandb_project_name)
  print('new_model:', new_model)
  print('run_name_before:', run_name_before)
  print('eval_only:', eval_only)

except OSError as e:
  print('\nERROR loading wandb_config file')
  print(e)
  # quit()
# Out:
# wandb_log: True
# wandb_run_name: arch5_25m_movielens_context_max_abs_scaler_gc
# wandb_group_name: 25m_deep_dense
# wandb_entity: xbarantomik
# wandb_project_name: DP
# new_model: True
# run_name_before: -
# eval_only: False

# %%
try:
  with open(nn_config_path, 'r') as f:
    nn_config = json.load(f)

  epochs = int(nn_config['epochs'])
  batch_size = int(nn_config['batch_size'])
  patience = int(nn_config['patience'])
  learning_rate = float(nn_config['learning_rate'])
  architecture = int(nn_config['architecture'])
  training_data_file = nn_config['training_data_file'] + '/'

  print('epochs:', epochs)
  print('batch_size:', batch_size)
  print('patience:', patience)
  print('learning_rate:', learning_rate)
  print('architecture:', architecture)
  print('training_data_file:', training_data_file)

except OSError as e:
  print('\nERROR loading nn_config file')
  print(e)
# Out:
# epochs: 25
# batch_size: 128
# patience: 15
# learning_rate: 0.001
# architecture: 5
# training_data_file: movielens_context_max_abs_scaler/

# %% [markdown]
# #### Load training data

# %%
try:
  train_data = np.load(training_data_path + training_data_file + 'train_data.npy')
  val_data = np.load(training_data_path + training_data_file + 'val_data.npy')
  test_data = np.load(training_data_path + training_data_file + 'test_data.npy')
  train_target_ratings = np.load(training_data_path + training_data_file + 'train_target_ratings.npy')
  val_target_ratings = np.load(training_data_path + training_data_file + 'val_target_ratings.npy')
  test_target_ratings = np.load(training_data_path + training_data_file + 'test_target_ratings.npy')

except OSError as e:
  print('\nERROR loading training data')
  print(e)
  quit()

# %%
if wandb_log:
  import wandb
  from wandb.keras import WandbMetricsLogger, WandbModelCheckpoint

  wandb.login()

  wandb.init(
    config=nn_config,
    entity=wandb_entity,
    project=wandb_project_name,
    name=wandb_run_name,
    group=wandb_group_name
  )
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: xbarantomik. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/home/baran-tomik/projects/DP/training/wandb/run-20240430_022136-yeybr920</code>
# Syncing run <strong><a href='https://wandb.ai/xbarantomik/dp/runs/yeybr920' target="_blank">arch5_25m_movielens_context_max_abs_scaler_gc</a></strong> to <a href='https://wandb.ai/xbarantomik/dp' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/xbarantomik/dp' target="_blank">https://wandb.ai/xbarantomik/dp</a>
#  View run at <a href='https://wandb.ai/xbarantomik/dp/runs/yeybr920' target="_blank">https://wandb.ai/xbarantomik/dp/runs/yeybr920</a>

# %% [markdown]
# #### NN MODEL

# %%
early_stopping = EarlyStopping(patience=patience, monitor='val_loss')

# %%
checkpoint_filepath = checkpoint_model_filepath + f"{wandb_run_name}_checkpoint.h5"
checkpoint_callback = ModelCheckpoint(filepath=checkpoint_filepath, monitor='val_loss', save_best_only=True, mode='min', save_weights_only=False, save_format='tf')

if wandb_log:
  callbacks = [early_stopping, checkpoint_callback, WandbMetricsLogger()]
else:
  callbacks = [early_stopping, checkpoint_callback]

# %% [markdown]
# #### Create model

# %%
if new_model:
  my_model = nn_model.create_model(architecture=architecture, lr=learning_rate, train_data_shape=train_data.shape[1])
  print('\nCreated a new model')
else:
  my_model = load_model(checkpoint_model_filepath + run_name_before + '_checkpoint.h5')
  print('\nLoaded a model')

if my_model != None:
  my_model.summary()
else:
  print('\nERROR loading NN model')
  quit()
# Out:
# Model 5
#
# Created a new model
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# 2024-04-30 02:21:41.680466: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-30 02:21:41.714203: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-30 02:21:41.714428: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-30 02:21:41.715087: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-30 02:21:41.715636: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-30 02:21:41.715823: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-30 02:21:41.715990: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-30 02:21:41.770078: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-30 02:21:41.770247: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-30 02:21:41.770365: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-30 02:21:41.770462: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7511 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1070, pci bus id: 0000:01:00.0, compute capability: 6.1
#  dense (Dense)               (None, 512)               15872
#
#  activation (Activation)     (None, 512)               0
#
#  dropout (Dropout)           (None, 512)               0
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  activation_1 (Activation)   (None, 512)               0
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 512)               262656
#
#  activation_2 (Activation)   (None, 512)               0
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 256)               131328
#
#  activation_3 (Activation)   (None, 256)               0
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 256)               65792
#
#  activation_4 (Activation)   (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 738,561
# Trainable params: 738,561
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Model fitting

# %%
if not eval_only:
  print('Training model')
  trained_model = my_model.fit(train_data, train_target_ratings, batch_size, epochs, validation_data=(val_data, val_target_ratings), callbacks=callbacks, verbose=1)
  my_model.save(trained_model_filepath + f"{wandb_run_name}_trained.keras")
else:
  print('Only evaluating model')
# Out:
# Training model
# Epoch 1/25
# 6252/6252 [==============================] - 16s 2ms/step - loss: 1.2142 - root_mean_squared_error: 1.1019 - mean_absolute_error: 0.8954 - r_square: 0.0259 - val_loss: 1.1412 - val_root_mean_squared_error: 1.0683 - val_mean_absolute_error: 0.8643 - val_r_square: 0.0912
# Epoch 2/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.1567 - root_mean_squared_error: 1.0755 - mean_absolute_error: 0.8728 - r_square: 0.0720 - val_loss: 1.1324 - val_root_mean_squared_error: 1.0641 - val_mean_absolute_error: 0.8631 - val_r_square: 0.0982
# Epoch 3/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.1400 - root_mean_squared_error: 1.0677 - mean_absolute_error: 0.8659 - r_square: 0.0854 - val_loss: 1.1181 - val_root_mean_squared_error: 1.0574 - val_mean_absolute_error: 0.8557 - val_r_square: 0.1096
# Epoch 4/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.1301 - root_mean_squared_error: 1.0631 - mean_absolute_error: 0.8621 - r_square: 0.0933 - val_loss: 1.1132 - val_root_mean_squared_error: 1.0551 - val_mean_absolute_error: 0.8525 - val_r_square: 0.1136
# Epoch 5/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.1222 - root_mean_squared_error: 1.0593 - mean_absolute_error: 0.8585 - r_square: 0.0997 - val_loss: 1.1208 - val_root_mean_squared_error: 1.0587 - val_mean_absolute_error: 0.8752 - val_r_square: 0.1075
# Epoch 6/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.1172 - root_mean_squared_error: 1.0570 - mean_absolute_error: 0.8562 - r_square: 0.1037 - val_loss: 1.1007 - val_root_mean_squared_error: 1.0491 - val_mean_absolute_error: 0.8459 - val_r_square: 0.1235
# Epoch 7/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.1111 - root_mean_squared_error: 1.0541 - mean_absolute_error: 0.8539 - r_square: 0.1086 - val_loss: 1.0965 - val_root_mean_squared_error: 1.0471 - val_mean_absolute_error: 0.8437 - val_r_square: 0.1268
# Epoch 8/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.1074 - root_mean_squared_error: 1.0523 - mean_absolute_error: 0.8523 - r_square: 0.1116 - val_loss: 1.0948 - val_root_mean_squared_error: 1.0463 - val_mean_absolute_error: 0.8536 - val_r_square: 0.1282
# Epoch 9/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.1041 - root_mean_squared_error: 1.0508 - mean_absolute_error: 0.8508 - r_square: 0.1142 - val_loss: 1.0997 - val_root_mean_squared_error: 1.0487 - val_mean_absolute_error: 0.8380 - val_r_square: 0.1243
# Epoch 10/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.1011 - root_mean_squared_error: 1.0493 - mean_absolute_error: 0.8496 - r_square: 0.1166 - val_loss: 1.0881 - val_root_mean_squared_error: 1.0431 - val_mean_absolute_error: 0.8430 - val_r_square: 0.1335
# Epoch 11/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0981 - root_mean_squared_error: 1.0479 - mean_absolute_error: 0.8482 - r_square: 0.1190 - val_loss: 1.0877 - val_root_mean_squared_error: 1.0429 - val_mean_absolute_error: 0.8399 - val_r_square: 0.1339
# Epoch 12/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0960 - root_mean_squared_error: 1.0469 - mean_absolute_error: 0.8465 - r_square: 0.1207 - val_loss: 1.0920 - val_root_mean_squared_error: 1.0450 - val_mean_absolute_error: 0.8409 - val_r_square: 0.1304
# Epoch 13/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0946 - root_mean_squared_error: 1.0462 - mean_absolute_error: 0.8461 - r_square: 0.1218 - val_loss: 1.0885 - val_root_mean_squared_error: 1.0433 - val_mean_absolute_error: 0.8403 - val_r_square: 0.1332
# Epoch 14/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0929 - root_mean_squared_error: 1.0454 - mean_absolute_error: 0.8448 - r_square: 0.1232 - val_loss: 1.0867 - val_root_mean_squared_error: 1.0425 - val_mean_absolute_error: 0.8392 - val_r_square: 0.1346
# Epoch 15/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0921 - root_mean_squared_error: 1.0450 - mean_absolute_error: 0.8447 - r_square: 0.1238 - val_loss: 1.0875 - val_root_mean_squared_error: 1.0429 - val_mean_absolute_error: 0.8454 - val_r_square: 0.1339
# Epoch 16/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0910 - root_mean_squared_error: 1.0445 - mean_absolute_error: 0.8443 - r_square: 0.1247 - val_loss: 1.0845 - val_root_mean_squared_error: 1.0414 - val_mean_absolute_error: 0.8409 - val_r_square: 0.1364
# Epoch 17/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0889 - root_mean_squared_error: 1.0435 - mean_absolute_error: 0.8432 - r_square: 0.1264 - val_loss: 1.0808 - val_root_mean_squared_error: 1.0396 - val_mean_absolute_error: 0.8374 - val_r_square: 0.1393
# Epoch 18/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0881 - root_mean_squared_error: 1.0431 - mean_absolute_error: 0.8429 - r_square: 0.1271 - val_loss: 1.0772 - val_root_mean_squared_error: 1.0379 - val_mean_absolute_error: 0.8342 - val_r_square: 0.1422
# Epoch 19/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0866 - root_mean_squared_error: 1.0424 - mean_absolute_error: 0.8424 - r_square: 0.1282 - val_loss: 1.0837 - val_root_mean_squared_error: 1.0410 - val_mean_absolute_error: 0.8412 - val_r_square: 0.1370
# Epoch 20/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0854 - root_mean_squared_error: 1.0418 - mean_absolute_error: 0.8420 - r_square: 0.1292 - val_loss: 1.0756 - val_root_mean_squared_error: 1.0371 - val_mean_absolute_error: 0.8397 - val_r_square: 0.1435
# Epoch 21/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0849 - root_mean_squared_error: 1.0416 - mean_absolute_error: 0.8418 - r_square: 0.1296 - val_loss: 1.0801 - val_root_mean_squared_error: 1.0393 - val_mean_absolute_error: 0.8419 - val_r_square: 0.1398
# Epoch 22/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0834 - root_mean_squared_error: 1.0409 - mean_absolute_error: 0.8412 - r_square: 0.1308 - val_loss: 1.0738 - val_root_mean_squared_error: 1.0362 - val_mean_absolute_error: 0.8352 - val_r_square: 0.1449
# Epoch 23/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0828 - root_mean_squared_error: 1.0406 - mean_absolute_error: 0.8408 - r_square: 0.1313 - val_loss: 1.0789 - val_root_mean_squared_error: 1.0387 - val_mean_absolute_error: 0.8364 - val_r_square: 0.1409
# Epoch 24/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0825 - root_mean_squared_error: 1.0404 - mean_absolute_error: 0.8405 - r_square: 0.1316 - val_loss: 1.0782 - val_root_mean_squared_error: 1.0384 - val_mean_absolute_error: 0.8432 - val_r_square: 0.1414
# Epoch 25/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0814 - root_mean_squared_error: 1.0399 - mean_absolute_error: 0.8401 - r_square: 0.1324 - val_loss: 1.0752 - val_root_mean_squared_error: 1.0369 - val_mean_absolute_error: 0.8394 - val_r_square: 0.1438

# %% [markdown]
# #### After fitting

# %%
metric_name = ['Loss', 'RootMSE', 'MAE', 'R2']
train_metric = ['loss', 'root_mean_squared_error', 'mean_absolute_error', 'r_square']
val_metric = ['val_loss', 'val_root_mean_squared_error', 'val_mean_absolute_error', 'val_r_square']

for i in range(len(metric_name)):

  print(f"\n----------- {metric_name[i]} chart -----------\n")

  # matplotlib chart
  plt.plot(trained_model.history[train_metric[i]], label=f"Train {metric_name[i]}")
  plt.plot(trained_model.history[val_metric[i]], label=f"Val {metric_name[i]}")
  plt.legend()
  plt.show()
# Out:
# ----------- Loss chart -----------
# ----------- RootMSE chart -----------
# ----------- MAE chart -----------
# ----------- R2 chart -----------

# %%
# Validation data values in the last epoch
print("number of epochs:", trained_model.epoch[-1] + 1)
print("val_loss:", trained_model.history['val_loss'][-1])
print("val_root_mean_squared_error:", trained_model.history['val_root_mean_squared_error'][-1])
print("val_mean_absolute_error:", trained_model.history['val_mean_absolute_error'][-1])
print("val_r2_score:", trained_model.history['val_r_square'][-1])
# Out:
# number of epochs: 25
# val_loss: 1.0751904249191284
# val_root_mean_squared_error: 1.0369138717651367
# val_mean_absolute_error: 0.8394196033477783
# val_r2_score: 0.14379137754440308

# %%
# Evaluate the model on the test data
print("Evaluate on test data")
test_loss, test_mean_squared_error, test_mean_absolute_error, test_r2_score = my_model.evaluate(test_data, test_target_ratings)
print("Test_loss:", test_loss)
print("Test_root_mean_squared_error:", test_mean_squared_error)
print("Test_mean_absolute_error:", test_mean_absolute_error)
print("Test_r2_score:", test_r2_score)
print('\n')

print("Generate predictions for 10 samples")
predictions = my_model.predict(test_data)
test_y_comparison = pd.DataFrame({'test_y_true': test_target_ratings, 'test_y_pred': [x for x in predictions]})

print(test_y_comparison.head(10))
# Out:
# Evaluate on test data
# 3126/3126 [==============================] - 4s 1ms/step - loss: 1.0781 - root_mean_squared_error: 1.0383 - mean_absolute_error: 0.8419 - r_square: 0.1388
# Test_loss: 1.0780675411224365
# Test_root_mean_squared_error: 1.0383002758026123
# Test_mean_absolute_error: 0.8418652415275574
# Test_r2_score: 0.13880395889282227
#
#
# Generate predictions for 10 samples
# 3126/3126 [==============================] - 2s 765us/step
#    test_y_true  test_y_pred
# 0            4  [3.7318776]
# 1            3  [2.6628184]
# 2            5   [3.913341]
# 3            5  [4.0439086]
# 4            4   [3.857688]
# 5            4  [3.7039306]
# 6            4  [4.2571645]
# 7            3   [3.818396]
# 8            1  [3.3619401]
# 9            5  [3.6931531]

# %%
if wandb_log:
  wandb.finish()
# Out:
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch/epoch</td><td>▁▁▂▂▂▂▃▃▃▄▄▄▅▅▅▅▆▆▆▇▇▇▇██</td></tr><tr><td>epoch/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/loss</td><td>█▅▄▄▃▃▃▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/mean_absolute_error</td><td>█▅▄▄▃▃▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/r_square</td><td>▁▄▅▅▆▆▆▇▇▇▇▇▇▇▇▇█████████</td></tr><tr><td>epoch/root_mean_squared_error</td><td>█▅▄▄▃▃▃▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/val_loss</td><td>█▇▆▅▆▄▃▃▄▂▂▃▃▂▂▂▂▁▂▁▂▁▂▁▁</td></tr><tr><td>epoch/val_mean_absolute_error</td><td>▆▆▅▄█▃▃▄▂▃▂▂▂▂▃▂▂▁▂▂▂▁▁▃▂</td></tr><tr><td>epoch/val_r_square</td><td>▁▂▃▄▃▅▆▆▅▇▇▆▆▇▇▇▇█▇█▇█▇██</td></tr><tr><td>epoch/val_root_mean_squared_error</td><td>█▇▆▅▆▄▃▃▄▃▂▃▃▂▂▂▂▁▂▁▂▁▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/epoch</td><td>24</td></tr><tr><td>epoch/learning_rate</td><td>0.001</td></tr><tr><td>epoch/loss</td><td>1.08137</td></tr><tr><td>epoch/mean_absolute_error</td><td>0.84009</td></tr><tr><td>epoch/r_square</td><td>0.13244</td></tr><tr><td>epoch/root_mean_squared_error</td><td>1.03989</td></tr><tr><td>epoch/val_loss</td><td>1.07519</td></tr><tr><td>epoch/val_mean_absolute_error</td><td>0.83942</td></tr><tr><td>epoch/val_r_square</td><td>0.14379</td></tr><tr><td>epoch/val_root_mean_squared_error</td><td>1.03691</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">arch5_25m_movielens_context_max_abs_scaler_gc</strong> at: <a href='https://wandb.ai/xbarantomik/dp/runs/yeybr920' target="_blank">https://wandb.ai/xbarantomik/dp/runs/yeybr920</a><br/> View project at: <a href='https://wandb.ai/xbarantomik/dp' target="_blank">https://wandb.ai/xbarantomik/dp</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240430_022136-yeybr920/logs</code>
