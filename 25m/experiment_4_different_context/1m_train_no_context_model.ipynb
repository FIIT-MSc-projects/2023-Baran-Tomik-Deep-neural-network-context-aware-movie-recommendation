# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import load_model
import matplotlib.pyplot as plt
import plotly.express as px
import pandas as pd
import numpy as np
import json
# Out:
# 2024-04-29 22:57:03.955299: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-29 22:57:04.072070: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-29 22:57:04.565967: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/baran-tomik/bin/miniconda3/envs/tf/lib/
# 2024-04-29 22:57:04.566066: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/baran-tomik/bin/miniconda3/envs/tf/lib/
# 2024-04-29 22:57:04.566072: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
checkpoint_model_filepath = 'checkpoints/'
trained_model_filepath = 'trained_models/'
training_data_path = 'data_1m/'
nn_config_path = '../config/nn_config.json'
wandb_config_path = '../config/wandb_config.json'

print('Training data path:', training_data_path)

import nn_model
# Out:
# Training data path: data_1m/
# /home/baran-tomik/bin/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# /home/baran-tomik/bin/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.13.0 and strictly below 2.16.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.10.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
try:
  with open(wandb_config_path, 'r') as f:
    wandb_config = json.load(f)

  wandb_log = True
  wandb_run_name = wandb_config["wandb_run_name"]
  wandb_group_name = wandb_config["wandb_group_name"]
  wandb_entity = wandb_config["wandb_entity"]
  wandb_project_name = wandb_config["wandb_project_name"]
  if wandb_config["new_model"] == 'false':
    new_model = False
  else:
    new_model = True
  run_name_before = wandb_config["run_name_before"]   # Model to be loaded
  if wandb_config["eval_only"] == 'false':
    eval_only = False
  else:
    eval_only = True

  print('wandb_log:', wandb_log)
  print('wandb_run_name:', wandb_run_name)
  print('wandb_group_name:', wandb_group_name)
  print('wandb_entity:', wandb_entity)
  print('wandb_project_name:', wandb_project_name)
  print('new_model:', new_model)
  print('run_name_before:', run_name_before)
  print('eval_only:', eval_only)

except OSError as e:
  print('\nERROR loading wandb_config file')
  print(e)
  # quit()
# Out:
# wandb_log: True
# wandb_run_name: arch5_1m_no_context_max_abs_scaler_gc
# wandb_group_name: 1m_deep_dense
# wandb_entity: xbarantomik
# wandb_project_name: DP
# new_model: True
# run_name_before: -
# eval_only: False

# %%
try:
  with open(nn_config_path, 'r') as f:
    nn_config = json.load(f)

  epochs = int(nn_config['epochs'])
  batch_size = int(nn_config['batch_size'])
  patience = int(nn_config['patience'])
  learning_rate = float(nn_config['learning_rate'])
  architecture = int(nn_config['architecture'])
  training_data_file = nn_config['training_data_file'] + '/'

  print('epochs:', epochs)
  print('batch_size:', batch_size)
  print('patience:', patience)
  print('learning_rate:', learning_rate)
  print('architecture:', architecture)
  print('training_data_file:', training_data_file)

except OSError as e:
  print('\nERROR loading nn_config file')
  print(e)
# Out:
# epochs: 25
# batch_size: 128
# patience: 15
# learning_rate: 0.001
# architecture: 5
# training_data_file: no_context_max_abs_scaler/

# %% [markdown]
# #### Load training data

# %%
try:
  train_data = np.load(training_data_path + training_data_file + 'train_data.npy')
  val_data = np.load(training_data_path + training_data_file + 'val_data.npy')
  test_data = np.load(training_data_path + training_data_file + 'test_data.npy')
  train_target_ratings = np.load(training_data_path + training_data_file + 'train_target_ratings.npy')
  val_target_ratings = np.load(training_data_path + training_data_file + 'val_target_ratings.npy')
  test_target_ratings = np.load(training_data_path + training_data_file + 'test_target_ratings.npy')

except OSError as e:
  print('\nERROR loading training data')
  print(e)
  quit()

# %%
if wandb_log:
  import wandb
  from wandb.keras import WandbMetricsLogger, WandbModelCheckpoint

  wandb.login()

  wandb.init(
    config=nn_config,
    entity=wandb_entity,
    project=wandb_project_name,
    name=wandb_run_name,
    group=wandb_group_name
  )
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: xbarantomik. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/home/baran-tomik/projects/DP/training/wandb/run-20240429_225706-jv84ck7w</code>
# Syncing run <strong><a href='https://wandb.ai/xbarantomik/dp/runs/jv84ck7w' target="_blank">arch5_1m_no_context_max_abs_scaler_gc</a></strong> to <a href='https://wandb.ai/xbarantomik/dp' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/xbarantomik/dp' target="_blank">https://wandb.ai/xbarantomik/dp</a>
#  View run at <a href='https://wandb.ai/xbarantomik/dp/runs/jv84ck7w' target="_blank">https://wandb.ai/xbarantomik/dp/runs/jv84ck7w</a>

# %% [markdown]
# #### NN MODEL

# %%
early_stopping = EarlyStopping(patience=patience, monitor='val_loss')

# %%
checkpoint_filepath = checkpoint_model_filepath + f"{wandb_run_name}_checkpoint.h5"
checkpoint_callback = ModelCheckpoint(filepath=checkpoint_filepath, monitor='val_loss', save_best_only=True, mode='min', save_weights_only=False, save_format='tf')

if wandb_log:
  callbacks = [early_stopping, checkpoint_callback, WandbMetricsLogger()]
else:
  callbacks = [early_stopping, checkpoint_callback]

# %% [markdown]
# #### Create model

# %%
if new_model:
  my_model = nn_model.create_model(architecture=architecture, lr=learning_rate, train_data_shape=train_data.shape[1])
  print('\nCreated a new model')
else:
  my_model = load_model(checkpoint_model_filepath + run_name_before + '_checkpoint.h5')
  print('\nLoaded a model')

if my_model != None:
  my_model.summary()
else:
  print('\nERROR loading NN model')
  quit()
# Out:
# Model 5
#
# Created a new model
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               1536
#
#  activation (Activation)     (None, 512)               0
#
#  dropout (Dropout)           (None, 512)               0
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  activation_1 (Activation)   (None, 512)               0
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 512)               262656
#
#  activation_2 (Activation)   (None, 512)               0
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 256)               131328
#
#  activation_3 (Activation)   (None, 256)               0
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 256)               65792
#
#  activation_4 (Activation)   (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 724,225
# Trainable params: 724,225
# Non-trainable params: 0
# _________________________________________________________________
# 2024-04-29 22:57:11.232951: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-29 22:57:11.257089: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-29 22:57:11.257352: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-29 22:57:11.258082: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-29 22:57:11.258656: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-29 22:57:11.258835: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-29 22:57:11.258955: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-29 22:57:11.333469: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-29 22:57:11.333636: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-29 22:57:11.333769: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-29 22:57:11.333876: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7511 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1070, pci bus id: 0000:01:00.0, compute capability: 6.1

# %% [markdown]
# ## Model fitting

# %%
if not eval_only:
  print('Training model')
  trained_model = my_model.fit(train_data, train_target_ratings, batch_size, epochs, validation_data=(val_data, val_target_ratings), callbacks=callbacks, verbose=1)
  my_model.save(trained_model_filepath + f"{wandb_run_name}_trained.keras")
else:
  print('Only evaluating model')
# Out:
# Training model
# Epoch 1/25
# 6252/6252 [==============================] - 16s 2ms/step - loss: 1.2768 - root_mean_squared_error: 1.1299 - mean_absolute_error: 0.9273 - r_square: -0.0243 - val_loss: 1.2252 - val_root_mean_squared_error: 1.1069 - val_mean_absolute_error: 0.9180 - val_r_square: 0.0244
# Epoch 2/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.2334 - root_mean_squared_error: 1.1106 - mean_absolute_error: 0.9158 - r_square: 0.0104 - val_loss: 1.2260 - val_root_mean_squared_error: 1.1072 - val_mean_absolute_error: 0.9240 - val_r_square: 0.0237
# Epoch 3/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.2275 - root_mean_squared_error: 1.1079 - mean_absolute_error: 0.9151 - r_square: 0.0152 - val_loss: 1.2180 - val_root_mean_squared_error: 1.1036 - val_mean_absolute_error: 0.9051 - val_r_square: 0.0301
# Epoch 4/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.2227 - root_mean_squared_error: 1.1057 - mean_absolute_error: 0.9138 - r_square: 0.0191 - val_loss: 1.2150 - val_root_mean_squared_error: 1.1023 - val_mean_absolute_error: 0.9108 - val_r_square: 0.0324
# Epoch 5/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.2192 - root_mean_squared_error: 1.1042 - mean_absolute_error: 0.9130 - r_square: 0.0219 - val_loss: 1.2126 - val_root_mean_squared_error: 1.1012 - val_mean_absolute_error: 0.9113 - val_r_square: 0.0344
# Epoch 6/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.2164 - root_mean_squared_error: 1.1029 - mean_absolute_error: 0.9123 - r_square: 0.0241 - val_loss: 1.2116 - val_root_mean_squared_error: 1.1007 - val_mean_absolute_error: 0.9111 - val_r_square: 0.0352
# Epoch 7/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.2138 - root_mean_squared_error: 1.1017 - mean_absolute_error: 0.9118 - r_square: 0.0262 - val_loss: 1.2114 - val_root_mean_squared_error: 1.1006 - val_mean_absolute_error: 0.9122 - val_r_square: 0.0354
# Epoch 8/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.2148 - root_mean_squared_error: 1.1022 - mean_absolute_error: 0.9114 - r_square: 0.0254 - val_loss: 1.2203 - val_root_mean_squared_error: 1.1047 - val_mean_absolute_error: 0.9062 - val_r_square: 0.0283
# Epoch 9/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.2148 - root_mean_squared_error: 1.1022 - mean_absolute_error: 0.9106 - r_square: 0.0254 - val_loss: 1.2210 - val_root_mean_squared_error: 1.1050 - val_mean_absolute_error: 0.9043 - val_r_square: 0.0277
# Epoch 10/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.2139 - root_mean_squared_error: 1.1018 - mean_absolute_error: 0.9102 - r_square: 0.0261 - val_loss: 1.2175 - val_root_mean_squared_error: 1.1034 - val_mean_absolute_error: 0.9084 - val_r_square: 0.0305
# Epoch 11/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.2135 - root_mean_squared_error: 1.1016 - mean_absolute_error: 0.9104 - r_square: 0.0264 - val_loss: 1.2144 - val_root_mean_squared_error: 1.1020 - val_mean_absolute_error: 0.9055 - val_r_square: 0.0329
# Epoch 12/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.2119 - root_mean_squared_error: 1.1009 - mean_absolute_error: 0.9093 - r_square: 0.0277 - val_loss: 1.2139 - val_root_mean_squared_error: 1.1018 - val_mean_absolute_error: 0.9074 - val_r_square: 0.0333
# Epoch 13/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.2115 - root_mean_squared_error: 1.1007 - mean_absolute_error: 0.9090 - r_square: 0.0281 - val_loss: 1.2156 - val_root_mean_squared_error: 1.1025 - val_mean_absolute_error: 0.9067 - val_r_square: 0.0320
# Epoch 14/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.2101 - root_mean_squared_error: 1.1001 - mean_absolute_error: 0.9086 - r_square: 0.0291 - val_loss: 1.2128 - val_root_mean_squared_error: 1.1013 - val_mean_absolute_error: 0.9090 - val_r_square: 0.0342
# Epoch 15/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.2104 - root_mean_squared_error: 1.1002 - mean_absolute_error: 0.9084 - r_square: 0.0289 - val_loss: 1.2126 - val_root_mean_squared_error: 1.1012 - val_mean_absolute_error: 0.9031 - val_r_square: 0.0344
# Epoch 16/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.2096 - root_mean_squared_error: 1.0998 - mean_absolute_error: 0.9079 - r_square: 0.0295 - val_loss: 1.2138 - val_root_mean_squared_error: 1.1017 - val_mean_absolute_error: 0.9051 - val_r_square: 0.0334
# Epoch 17/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.2094 - root_mean_squared_error: 1.0997 - mean_absolute_error: 0.9079 - r_square: 0.0298 - val_loss: 1.2158 - val_root_mean_squared_error: 1.1026 - val_mean_absolute_error: 0.9125 - val_r_square: 0.0318
# Epoch 18/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.2087 - root_mean_squared_error: 1.0994 - mean_absolute_error: 0.9075 - r_square: 0.0303 - val_loss: 1.2140 - val_root_mean_squared_error: 1.1018 - val_mean_absolute_error: 0.9074 - val_r_square: 0.0333
# Epoch 19/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.2081 - root_mean_squared_error: 1.0991 - mean_absolute_error: 0.9071 - r_square: 0.0308 - val_loss: 1.2129 - val_root_mean_squared_error: 1.1013 - val_mean_absolute_error: 0.9100 - val_r_square: 0.0341
# Epoch 20/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.2086 - root_mean_squared_error: 1.0994 - mean_absolute_error: 0.9069 - r_square: 0.0304 - val_loss: 1.2137 - val_root_mean_squared_error: 1.1017 - val_mean_absolute_error: 0.9091 - val_r_square: 0.0335
# Epoch 21/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.2083 - root_mean_squared_error: 1.0992 - mean_absolute_error: 0.9070 - r_square: 0.0306 - val_loss: 1.2155 - val_root_mean_squared_error: 1.1025 - val_mean_absolute_error: 0.9097 - val_r_square: 0.0321
# Epoch 22/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.2083 - root_mean_squared_error: 1.0992 - mean_absolute_error: 0.9071 - r_square: 0.0306 - val_loss: 1.2153 - val_root_mean_squared_error: 1.1024 - val_mean_absolute_error: 0.9024 - val_r_square: 0.0322

# %% [markdown]
# #### After fitting

# %%
metric_name = ['Loss', 'RootMSE', 'MAE', 'R2']
train_metric = ['loss', 'root_mean_squared_error', 'mean_absolute_error', 'r_square']
val_metric = ['val_loss', 'val_root_mean_squared_error', 'val_mean_absolute_error', 'val_r_square']

for i in range(len(metric_name)):

  print(f"\n----------- {metric_name[i]} chart -----------\n")

  # matplotlib chart
  plt.plot(trained_model.history[train_metric[i]], label=f"Train {metric_name[i]}")
  plt.plot(trained_model.history[val_metric[i]], label=f"Val {metric_name[i]}")
  plt.legend()
  plt.show()
# Out:
# ----------- Loss chart -----------
# ----------- RootMSE chart -----------
# ----------- MAE chart -----------
# ----------- R2 chart -----------

# %%
# Validation data values in the last epoch
print("number of epochs:", trained_model.epoch[-1] + 1)
print("val_loss:", trained_model.history['val_loss'][-1])
print("val_root_mean_squared_error:", trained_model.history['val_root_mean_squared_error'][-1])
print("val_mean_absolute_error:", trained_model.history['val_mean_absolute_error'][-1])
print("val_r2_score:", trained_model.history['val_r_square'][-1])
# Out:
# number of epochs: 22
# val_loss: 1.2153220176696777
# val_root_mean_squared_error: 1.1024163961410522
# val_mean_absolute_error: 0.9023506045341492
# val_r2_score: 0.0322001576423645

# %%
# Evaluate the model on the test data
print("Evaluate on test data")
test_loss, test_mean_squared_error, test_mean_absolute_error, test_r2_score = my_model.evaluate(test_data, test_target_ratings)
print("Test_loss:", test_loss)
print("Test_root_mean_squared_error:", test_mean_squared_error)
print("Test_mean_absolute_error:", test_mean_absolute_error)
print("Test_r2_score:", test_r2_score)
print('\n')

print("Generate predictions for 10 samples")
predictions = my_model.predict(test_data)
test_y_comparison = pd.DataFrame({'test_y_true': test_target_ratings, 'test_y_pred': [x for x in predictions]})

print(test_y_comparison.head(10))
# Out:
# Evaluate on test data
# 3126/3126 [==============================] - 4s 1ms/step - loss: 1.2156 - root_mean_squared_error: 1.1025 - mean_absolute_error: 0.9031 - r_square: 0.0289
# Test_loss: 1.215604305267334
# Test_root_mean_squared_error: 1.1025444269180298
# Test_mean_absolute_error: 0.9031201004981995
# Test_r2_score: 0.028935015201568604
#
#
# Generate predictions for 10 samples
# 3126/3126 [==============================] - 2s 760us/step
#    test_y_true  test_y_pred
# 0            4   [3.450088]
# 1            3  [3.4530141]
# 2            5  [3.5107722]
# 3            5  [3.5370288]
# 4            4  [3.5362744]
# 5            4   [3.450088]
# 6            4  [3.5616608]
# 7            3  [4.0036016]
# 8            1  [3.5751328]
# 9            5  [4.0036016]

# %%
if wandb_log:
  wandb.finish()
# Out:
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch/epoch</td><td>▁▁▂▂▂▃▃▃▄▄▄▅▅▅▆▆▆▇▇▇██</td></tr><tr><td>epoch/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/loss</td><td>█▄▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/mean_absolute_error</td><td>█▄▄▃▃▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁</td></tr><tr><td>epoch/r_square</td><td>▁▅▆▇▇▇▇▇▇▇▇███████████</td></tr><tr><td>epoch/root_mean_squared_error</td><td>█▄▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/val_loss</td><td>██▄▃▂▁▁▅▆▄▂▂▃▂▂▂▃▂▂▂▃▃</td></tr><tr><td>epoch/val_mean_absolute_error</td><td>▆█▂▄▄▄▄▂▂▃▂▃▂▃▁▂▄▃▃▃▃▁</td></tr><tr><td>epoch/val_r_square</td><td>▁▁▅▆▇██▄▃▅▇▇▆▇▇▇▆▇▇▇▆▆</td></tr><tr><td>epoch/val_root_mean_squared_error</td><td>██▄▃▂▁▁▅▆▄▂▂▃▂▂▂▃▂▂▂▃▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/epoch</td><td>21</td></tr><tr><td>epoch/learning_rate</td><td>0.001</td></tr><tr><td>epoch/loss</td><td>1.20827</td></tr><tr><td>epoch/mean_absolute_error</td><td>0.90711</td></tr><tr><td>epoch/r_square</td><td>0.03063</td></tr><tr><td>epoch/root_mean_squared_error</td><td>1.09921</td></tr><tr><td>epoch/val_loss</td><td>1.21532</td></tr><tr><td>epoch/val_mean_absolute_error</td><td>0.90235</td></tr><tr><td>epoch/val_r_square</td><td>0.0322</td></tr><tr><td>epoch/val_root_mean_squared_error</td><td>1.10242</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">arch5_1m_no_context_max_abs_scaler_gc</strong> at: <a href='https://wandb.ai/xbarantomik/dp/runs/jv84ck7w' target="_blank">https://wandb.ai/xbarantomik/dp/runs/jv84ck7w</a><br/> View project at: <a href='https://wandb.ai/xbarantomik/dp' target="_blank">https://wandb.ai/xbarantomik/dp</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240429_225706-jv84ck7w/logs</code>
