# %% [markdown]
# ## Experiment 4 - 1m - Added IMDb Context model

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import load_model
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json
# Out:
# 2024-04-30 19:10:03.895731: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-30 19:10:04.009475: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-30 19:10:04.501576: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/baran-tomik/bin/miniconda3/envs/tf/lib/
# 2024-04-30 19:10:04.501654: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/baran-tomik/bin/miniconda3/envs/tf/lib/
# 2024-04-30 19:10:04.501661: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
checkpoint_model_filepath = 'checkpoints/'
trained_model_filepath = 'trained_models/'
training_data_path = 'data_1m/'
nn_config_path = '../config/nn_config.json'
wandb_config_path = '../config/wandb_config.json'

print('Training data path:', training_data_path)

import nn_model
# Out:
# Training data path: data_1m/
# /home/baran-tomik/bin/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# /home/baran-tomik/bin/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.13.0 and strictly below 2.16.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.10.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
try:
  with open(wandb_config_path, 'r') as f:
    wandb_config = json.load(f)

  wandb_log = True
  wandb_run_name = wandb_config["wandb_run_name"]
  wandb_group_name = wandb_config["wandb_group_name"]
  wandb_entity = wandb_config["wandb_entity"]
  wandb_project_name = wandb_config["wandb_project_name"]
  if wandb_config["new_model"] == 'false':
    new_model = False
  else:
    new_model = True
  run_name_before = wandb_config["run_name_before"]   # Model to be loaded
  if wandb_config["eval_only"] == 'false':
    eval_only = False
  else:
    eval_only = True

  print('wandb_log:', wandb_log)
  print('wandb_run_name:', wandb_run_name)
  print('wandb_group_name:', wandb_group_name)
  print('wandb_entity:', wandb_entity)
  print('wandb_project_name:', wandb_project_name)
  print('new_model:', new_model)
  print('run_name_before:', run_name_before)
  print('eval_only:', eval_only)

except OSError as e:
  print('\nERROR loading wandb_config file')
  print(e)
  # quit()
# Out:
# wandb_log: True
# wandb_run_name: arch5_1m_added_imdb_context_max_abs_scaler_gc_2
# wandb_group_name: 1m_deep_dense
# wandb_entity: xbarantomik
# wandb_project_name: DP
# new_model: True
# run_name_before: -
# eval_only: False

# %%
try:
  with open(nn_config_path, 'r') as f:
    nn_config = json.load(f)

  epochs = int(nn_config['epochs'])
  batch_size = int(nn_config['batch_size'])
  patience = int(nn_config['patience'])
  learning_rate = float(nn_config['learning_rate'])
  architecture = int(nn_config['architecture'])
  training_data_file = nn_config['training_data_file'] + '/'

  print('epochs:', epochs)
  print('batch_size:', batch_size)
  print('patience:', patience)
  print('learning_rate:', learning_rate)
  print('architecture:', architecture)
  print('training_data_file:', training_data_file)

except OSError as e:
  print('\nERROR loading nn_config file')
  print(e)
# Out:
# epochs: 25
# batch_size: 128
# patience: 15
# learning_rate: 0.001
# architecture: 5
# training_data_file: added_imdb_context_max_abs_scaler/

# %% [markdown]
# #### Load training data

# %%
try:
  train_data = np.load(training_data_path + training_data_file + 'train_data.npy')
  val_data = np.load(training_data_path + training_data_file + 'val_data.npy')
  test_data = np.load(training_data_path + training_data_file + 'test_data.npy')
  train_target_ratings = np.load(training_data_path + training_data_file + 'train_target_ratings.npy')
  val_target_ratings = np.load(training_data_path + training_data_file + 'val_target_ratings.npy')
  test_target_ratings = np.load(training_data_path + training_data_file + 'test_target_ratings.npy')

except OSError as e:
  print('\nERROR loading training data')
  print(e)
  quit()

# %%
if wandb_log:
  import wandb
  from wandb.keras import WandbMetricsLogger, WandbModelCheckpoint

  wandb.login()

  wandb.init(
    config=nn_config,
    entity=wandb_entity,
    project=wandb_project_name,
    name=wandb_run_name,
    group=wandb_group_name
  )
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: xbarantomik. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/home/baran-tomik/projects/DP/training/wandb/run-20240430_191006-zupzpvcs</code>
# Syncing run <strong><a href='https://wandb.ai/xbarantomik/dp/runs/zupzpvcs' target="_blank">arch5_1m_added_imdb_context_max_abs_scaler_gc_2</a></strong> to <a href='https://wandb.ai/xbarantomik/dp' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/xbarantomik/dp' target="_blank">https://wandb.ai/xbarantomik/dp</a>
#  View run at <a href='https://wandb.ai/xbarantomik/dp/runs/zupzpvcs' target="_blank">https://wandb.ai/xbarantomik/dp/runs/zupzpvcs</a>

# %% [markdown]
# #### NN MODEL

# %%
early_stopping = EarlyStopping(patience=patience, monitor='val_loss')

# %%
checkpoint_filepath = checkpoint_model_filepath + f"{wandb_run_name}_checkpoint.h5"
checkpoint_callback = ModelCheckpoint(filepath=checkpoint_filepath, monitor='val_loss', save_best_only=True, mode='min', save_weights_only=False, save_format='tf')

if wandb_log:
  callbacks = [early_stopping, checkpoint_callback, WandbMetricsLogger()]
else:
  callbacks = [early_stopping, checkpoint_callback]

# %% [markdown]
# #### Create model

# %%
if new_model:
  my_model = nn_model.create_model(architecture=architecture, lr=learning_rate, train_data_shape=train_data.shape[1])
  print('\nCreated a new model')
else:
  my_model = load_model(checkpoint_model_filepath + run_name_before + '_checkpoint.h5')
  print('\nLoaded a model')

if my_model != None:
  my_model.summary()
else:
  print('\nERROR loading NN model')
  quit()
# Out:
# Model 5
#
# Created a new model
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               21504
#
#  activation (Activation)     (None, 512)               0
#
#  dropout (Dropout)           (None, 512)               0
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  activation_1 (Activation)   (None, 512)               0
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 512)               262656
#
#  activation_2 (Activation)   (None, 512)               0
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 256)               131328
#
#  activation_3 (Activation)   (None, 256)               0
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 256)               65792
#
#  activation_4 (Activation)   (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 744,193
# Trainable params: 744,193
# Non-trainable params: 0
# _________________________________________________________________
# 2024-04-30 19:10:11.301120: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-30 19:10:11.326380: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-30 19:10:11.326553: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-30 19:10:11.326979: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-30 19:10:11.327551: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-30 19:10:11.327724: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-30 19:10:11.327842: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-30 19:10:11.397429: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-30 19:10:11.397601: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-30 19:10:11.397721: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-30 19:10:11.397818: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 180 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1070, pci bus id: 0000:01:00.0, compute capability: 6.1

# %% [markdown]
# ## Model fitting

# %%
if not eval_only:
  print('Training model')
  trained_model = my_model.fit(train_data, train_target_ratings, batch_size, epochs, validation_data=(val_data, val_target_ratings), callbacks=callbacks, verbose=1)
  my_model.save(trained_model_filepath + f"{wandb_run_name}_trained.keras")
else:
  print('Only evaluating model')
# Out:
# Training model
# Epoch 1/25
# 3315/3315 [==============================] - 9s 2ms/step - loss: 1.1021 - root_mean_squared_error: 1.0498 - mean_absolute_error: 0.8314 - r_square: 0.0224 - val_loss: 1.0048 - val_root_mean_squared_error: 1.0024 - val_mean_absolute_error: 0.8012 - val_r_square: 0.1056
# Epoch 2/25
# 3315/3315 [==============================] - 8s 2ms/step - loss: 1.0270 - root_mean_squared_error: 1.0134 - mean_absolute_error: 0.8014 - r_square: 0.0890 - val_loss: 0.9878 - val_root_mean_squared_error: 0.9939 - val_mean_absolute_error: 0.7781 - val_r_square: 0.1208
# Epoch 3/25
# 3315/3315 [==============================] - 8s 2ms/step - loss: 1.0123 - root_mean_squared_error: 1.0061 - mean_absolute_error: 0.7952 - r_square: 0.1020 - val_loss: 0.9760 - val_root_mean_squared_error: 0.9879 - val_mean_absolute_error: 0.7782 - val_r_square: 0.1313
# Epoch 4/25
# 3315/3315 [==============================] - 8s 2ms/step - loss: 1.0028 - root_mean_squared_error: 1.0014 - mean_absolute_error: 0.7909 - r_square: 0.1104 - val_loss: 0.9715 - val_root_mean_squared_error: 0.9856 - val_mean_absolute_error: 0.7765 - val_r_square: 0.1353
# Epoch 5/25
# 3315/3315 [==============================] - 8s 2ms/step - loss: 0.9936 - root_mean_squared_error: 0.9968 - mean_absolute_error: 0.7865 - r_square: 0.1186 - val_loss: 0.9671 - val_root_mean_squared_error: 0.9834 - val_mean_absolute_error: 0.7771 - val_r_square: 0.1392
# Epoch 6/25
# 3315/3315 [==============================] - 8s 2ms/step - loss: 0.9875 - root_mean_squared_error: 0.9937 - mean_absolute_error: 0.7838 - r_square: 0.1240 - val_loss: 0.9671 - val_root_mean_squared_error: 0.9834 - val_mean_absolute_error: 0.7708 - val_r_square: 0.1392
# Epoch 7/25
# 3315/3315 [==============================] - 8s 2ms/step - loss: 0.9826 - root_mean_squared_error: 0.9913 - mean_absolute_error: 0.7812 - r_square: 0.1283 - val_loss: 0.9597 - val_root_mean_squared_error: 0.9796 - val_mean_absolute_error: 0.7685 - val_r_square: 0.1458
# Epoch 8/25
# 3315/3315 [==============================] - 8s 2ms/step - loss: 0.9778 - root_mean_squared_error: 0.9888 - mean_absolute_error: 0.7791 - r_square: 0.1326 - val_loss: 0.9626 - val_root_mean_squared_error: 0.9811 - val_mean_absolute_error: 0.7728 - val_r_square: 0.1432
# Epoch 9/25
# 3315/3315 [==============================] - 8s 2ms/step - loss: 0.9747 - root_mean_squared_error: 0.9873 - mean_absolute_error: 0.7774 - r_square: 0.1353 - val_loss: 0.9548 - val_root_mean_squared_error: 0.9772 - val_mean_absolute_error: 0.7703 - val_r_square: 0.1501
# Epoch 10/25
# 3315/3315 [==============================] - 8s 2ms/step - loss: 0.9703 - root_mean_squared_error: 0.9850 - mean_absolute_error: 0.7752 - r_square: 0.1393 - val_loss: 0.9585 - val_root_mean_squared_error: 0.9790 - val_mean_absolute_error: 0.7671 - val_r_square: 0.1469
# Epoch 11/25
# 3315/3315 [==============================] - 8s 2ms/step - loss: 0.9679 - root_mean_squared_error: 0.9838 - mean_absolute_error: 0.7744 - r_square: 0.1414 - val_loss: 0.9519 - val_root_mean_squared_error: 0.9756 - val_mean_absolute_error: 0.7641 - val_r_square: 0.1527
# Epoch 12/25
# 3315/3315 [==============================] - 8s 2ms/step - loss: 0.9658 - root_mean_squared_error: 0.9828 - mean_absolute_error: 0.7735 - r_square: 0.1432 - val_loss: 0.9501 - val_root_mean_squared_error: 0.9747 - val_mean_absolute_error: 0.7691 - val_r_square: 0.1544
# Epoch 13/25
# 3315/3315 [==============================] - 8s 2ms/step - loss: 0.9624 - root_mean_squared_error: 0.9810 - mean_absolute_error: 0.7716 - r_square: 0.1463 - val_loss: 0.9504 - val_root_mean_squared_error: 0.9749 - val_mean_absolute_error: 0.7639 - val_r_square: 0.1541
# Epoch 14/25
# 3315/3315 [==============================] - 8s 2ms/step - loss: 0.9604 - root_mean_squared_error: 0.9800 - mean_absolute_error: 0.7708 - r_square: 0.1481 - val_loss: 0.9512 - val_root_mean_squared_error: 0.9753 - val_mean_absolute_error: 0.7717 - val_r_square: 0.1533
# Epoch 15/25
# 3315/3315 [==============================] - 8s 2ms/step - loss: 0.9589 - root_mean_squared_error: 0.9792 - mean_absolute_error: 0.7704 - r_square: 0.1494 - val_loss: 0.9528 - val_root_mean_squared_error: 0.9761 - val_mean_absolute_error: 0.7632 - val_r_square: 0.1519
# Epoch 16/25
# 3315/3315 [==============================] - 8s 2ms/step - loss: 0.9575 - root_mean_squared_error: 0.9785 - mean_absolute_error: 0.7692 - r_square: 0.1506 - val_loss: 0.9462 - val_root_mean_squared_error: 0.9727 - val_mean_absolute_error: 0.7675 - val_r_square: 0.1578
# Epoch 17/25
# 3315/3315 [==============================] - 8s 2ms/step - loss: 0.9549 - root_mean_squared_error: 0.9772 - mean_absolute_error: 0.7680 - r_square: 0.1529 - val_loss: 0.9455 - val_root_mean_squared_error: 0.9724 - val_mean_absolute_error: 0.7682 - val_r_square: 0.1584
# Epoch 18/25
# 3315/3315 [==============================] - 8s 2ms/step - loss: 0.9553 - root_mean_squared_error: 0.9774 - mean_absolute_error: 0.7685 - r_square: 0.1525 - val_loss: 0.9498 - val_root_mean_squared_error: 0.9746 - val_mean_absolute_error: 0.7635 - val_r_square: 0.1546
# Epoch 19/25
# 3315/3315 [==============================] - 8s 2ms/step - loss: 0.9530 - root_mean_squared_error: 0.9762 - mean_absolute_error: 0.7668 - r_square: 0.1546 - val_loss: 0.9590 - val_root_mean_squared_error: 0.9793 - val_mean_absolute_error: 0.7635 - val_r_square: 0.1464
# Epoch 20/25
# 3315/3315 [==============================] - 8s 2ms/step - loss: 0.9528 - root_mean_squared_error: 0.9761 - mean_absolute_error: 0.7667 - r_square: 0.1547 - val_loss: 0.9428 - val_root_mean_squared_error: 0.9710 - val_mean_absolute_error: 0.7654 - val_r_square: 0.1609
# Epoch 21/25
# 3315/3315 [==============================] - 8s 2ms/step - loss: 0.9509 - root_mean_squared_error: 0.9751 - mean_absolute_error: 0.7657 - r_square: 0.1565 - val_loss: 0.9500 - val_root_mean_squared_error: 0.9747 - val_mean_absolute_error: 0.7627 - val_r_square: 0.1545
# Epoch 22/25
# 3315/3315 [==============================] - 8s 2ms/step - loss: 0.9509 - root_mean_squared_error: 0.9751 - mean_absolute_error: 0.7660 - r_square: 0.1565 - val_loss: 0.9435 - val_root_mean_squared_error: 0.9714 - val_mean_absolute_error: 0.7635 - val_r_square: 0.1602
# Epoch 23/25
# 3315/3315 [==============================] - 8s 2ms/step - loss: 0.9489 - root_mean_squared_error: 0.9741 - mean_absolute_error: 0.7647 - r_square: 0.1582 - val_loss: 0.9422 - val_root_mean_squared_error: 0.9707 - val_mean_absolute_error: 0.7630 - val_r_square: 0.1614
# Epoch 24/25
# 3315/3315 [==============================] - 8s 2ms/step - loss: 0.9495 - root_mean_squared_error: 0.9744 - mean_absolute_error: 0.7650 - r_square: 0.1577 - val_loss: 0.9447 - val_root_mean_squared_error: 0.9720 - val_mean_absolute_error: 0.7649 - val_r_square: 0.1592
# Epoch 25/25
# 3315/3315 [==============================] - 8s 2ms/step - loss: 0.9485 - root_mean_squared_error: 0.9739 - mean_absolute_error: 0.7641 - r_square: 0.1586 - val_loss: 0.9433 - val_root_mean_squared_error: 0.9712 - val_mean_absolute_error: 0.7582 - val_r_square: 0.1604

# %% [markdown]
# #### After fitting

# %%
metric_name = ['Loss', 'RootMSE', 'MAE', 'R2']
train_metric = ['loss', 'root_mean_squared_error', 'mean_absolute_error', 'r_square']
val_metric = ['val_loss', 'val_root_mean_squared_error', 'val_mean_absolute_error', 'val_r_square']

for i in range(len(metric_name)):

  print(f"\n----------- {metric_name[i]} chart -----------\n")

  # matplotlib chart
  plt.plot(trained_model.history[train_metric[i]], label=f"Train {metric_name[i]}")
  plt.plot(trained_model.history[val_metric[i]], label=f"Val {metric_name[i]}")
  plt.legend()
  plt.show()
# Out:
# ----------- Loss chart -----------
# ----------- RootMSE chart -----------
# ----------- MAE chart -----------
# ----------- R2 chart -----------

# %%
# Validation data values in the last epoch
print("number of epochs:", trained_model.epoch[-1] + 1)
print("val_loss:", trained_model.history['val_loss'][-1])
print("val_root_mean_squared_error:", trained_model.history['val_root_mean_squared_error'][-1])
print("val_mean_absolute_error:", trained_model.history['val_mean_absolute_error'][-1])
print("val_r2_score:", trained_model.history['val_r_square'][-1])
# Out:
# number of epochs: 25
# val_loss: 0.943271279335022
# val_root_mean_squared_error: 0.9712215662002563
# val_mean_absolute_error: 0.7582390904426575
# val_r2_score: 0.16041529178619385

# %%
# Evaluate the model on the test data
print("Evaluate on test data")
test_loss, test_mean_squared_error, test_mean_absolute_error, test_r2_score = my_model.evaluate(test_data, test_target_ratings)
print("Test_loss:", test_loss)
print("Test_root_mean_squared_error:", test_mean_squared_error)
print("Test_mean_absolute_error:", test_mean_absolute_error)
print("Test_r2_score:", test_r2_score)
print('\n')

print("Generate predictions for 10 samples")
predictions = my_model.predict(test_data)
test_y_comparison = pd.DataFrame({'test_y_true': test_target_ratings, 'test_y_pred': [x for x in predictions]})

print(test_y_comparison.head(10))
# Out:
# Evaluate on test data
# 1658/1658 [==============================] - 2s 1ms/step - loss: 0.9420 - root_mean_squared_error: 0.9705 - mean_absolute_error: 0.7567 - r_square: 0.1599
# Test_loss: 0.9419532418251038
# Test_root_mean_squared_error: 0.9705427289009094
# Test_mean_absolute_error: 0.756660521030426
# Test_r2_score: 0.15985411405563354
#
#
# Generate predictions for 10 samples
# 1658/1658 [==============================] - 1s 766us/step
#    test_y_true  test_y_pred
# 0          3.5  [4.0695395]
# 1          4.0   [3.919613]
# 2          4.0   [4.101766]
# 3          5.0  [3.8343859]
# 4          4.0  [3.5105388]
# 5          5.0  [3.8462791]
# 6          4.0  [3.9906776]
# 7          3.0  [3.4999568]
# 8          5.0  [3.7499974]
# 9          3.0  [3.4509792]

# %%
if wandb_log:
  wandb.finish()
# Out:
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch/epoch</td><td>▁▁▂▂▂▂▃▃▃▄▄▄▅▅▅▅▆▆▆▇▇▇▇██</td></tr><tr><td>epoch/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/loss</td><td>█▅▄▃▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/mean_absolute_error</td><td>█▅▄▄▃▃▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/r_square</td><td>▁▄▅▆▆▆▆▇▇▇▇▇▇▇███████████</td></tr><tr><td>epoch/root_mean_squared_error</td><td>█▅▄▄▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/val_loss</td><td>█▆▅▄▄▄▃▃▂▃▂▂▂▂▂▁▁▂▃▁▂▁▁▁▁</td></tr><tr><td>epoch/val_mean_absolute_error</td><td>█▄▄▄▄▃▃▃▃▂▂▃▂▃▂▃▃▂▂▂▂▂▂▂▁</td></tr><tr><td>epoch/val_r_square</td><td>▁▃▄▅▅▅▆▆▇▆▇▇▇▇▇██▇▆█▇████</td></tr><tr><td>epoch/val_root_mean_squared_error</td><td>█▆▅▄▄▄▃▃▂▃▂▂▂▂▂▁▁▂▃▁▂▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/epoch</td><td>24</td></tr><tr><td>epoch/learning_rate</td><td>0.001</td></tr><tr><td>epoch/loss</td><td>0.94849</td></tr><tr><td>epoch/mean_absolute_error</td><td>0.76414</td></tr><tr><td>epoch/r_square</td><td>0.15861</td></tr><tr><td>epoch/root_mean_squared_error</td><td>0.9739</td></tr><tr><td>epoch/val_loss</td><td>0.94327</td></tr><tr><td>epoch/val_mean_absolute_error</td><td>0.75824</td></tr><tr><td>epoch/val_r_square</td><td>0.16042</td></tr><tr><td>epoch/val_root_mean_squared_error</td><td>0.97122</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">arch5_1m_added_imdb_context_max_abs_scaler_gc_2</strong> at: <a href='https://wandb.ai/xbarantomik/dp/runs/zupzpvcs' target="_blank">https://wandb.ai/xbarantomik/dp/runs/zupzpvcs</a><br/> View project at: <a href='https://wandb.ai/xbarantomik/dp' target="_blank">https://wandb.ai/xbarantomik/dp</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240430_191006-zupzpvcs/logs</code>
