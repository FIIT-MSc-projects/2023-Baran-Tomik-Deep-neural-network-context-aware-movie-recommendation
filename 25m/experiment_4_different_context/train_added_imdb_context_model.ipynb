# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import load_model
import matplotlib.pyplot as plt
import plotly.express as px
import pandas as pd
import numpy as np
import json
# Out:
# 2024-04-29 22:27:06.714527: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-29 22:27:06.832656: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-29 22:27:07.330681: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/baran-tomik/bin/miniconda3/envs/tf/lib/
# 2024-04-29 22:27:07.330777: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/baran-tomik/bin/miniconda3/envs/tf/lib/
# 2024-04-29 22:27:07.330784: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
checkpoint_model_filepath = 'checkpoints/'
trained_model_filepath = 'trained_models/'
training_data_path = 'data_1m/'
nn_config_path = '../config/nn_config.json'
wandb_config_path = '../config/wandb_config.json'

print('Training data path:', training_data_path)

import nn_model
# Out:
# Training data path: data_1m/
# /home/baran-tomik/bin/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# /home/baran-tomik/bin/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.13.0 and strictly below 2.16.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.10.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
try:
  with open(wandb_config_path, 'r') as f:
    wandb_config = json.load(f)

  wandb_log = True
  wandb_run_name = wandb_config["wandb_run_name"]
  wandb_group_name = wandb_config["wandb_group_name"]
  wandb_entity = wandb_config["wandb_entity"]
  wandb_project_name = wandb_config["wandb_project_name"]
  if wandb_config["new_model"] == 'false':
    new_model = False
  else:
    new_model = True
  run_name_before = wandb_config["run_name_before"]   # Model to be loaded
  if wandb_config["eval_only"] == 'false':
    eval_only = False
  else:
    eval_only = True

  print('wandb_log:', wandb_log)
  print('wandb_run_name:', wandb_run_name)
  print('wandb_group_name:', wandb_group_name)
  print('wandb_entity:', wandb_entity)
  print('wandb_project_name:', wandb_project_name)
  print('new_model:', new_model)
  print('run_name_before:', run_name_before)
  print('eval_only:', eval_only)

except OSError as e:
  print('\nERROR loading wandb_config file')
  print(e)
  # quit()
# Out:
# wandb_log: True
# wandb_run_name: arch5_1m_added_imdb_context_max_abs_scaler_gc
# wandb_group_name: 1m_deep_dense
# wandb_entity: xbarantomik
# wandb_project_name: DP
# new_model: True
# run_name_before: -
# eval_only: False

# %%
try:
  with open(nn_config_path, 'r') as f:
    nn_config = json.load(f)

  epochs = int(nn_config['epochs'])
  batch_size = int(nn_config['batch_size'])
  patience = int(nn_config['patience'])
  learning_rate = float(nn_config['learning_rate'])
  architecture = int(nn_config['architecture'])
  training_data_file = nn_config['training_data_file'] + '/'

  print('epochs:', epochs)
  print('batch_size:', batch_size)
  print('patience:', patience)
  print('learning_rate:', learning_rate)
  print('architecture:', architecture)
  print('training_data_file:', training_data_file)

except OSError as e:
  print('\nERROR loading nn_config file')
  print(e)
# Out:
# epochs: 25
# batch_size: 128
# patience: 15
# learning_rate: 0.001
# architecture: 5
# training_data_file: added_imdb_context_max_abs_scaler/

# %% [markdown]
# #### Load training data

# %%
try:
  train_data = np.load(training_data_path + training_data_file + 'train_data.npy')
  val_data = np.load(training_data_path + training_data_file + 'val_data.npy')
  test_data = np.load(training_data_path + training_data_file + 'test_data.npy')
  train_target_ratings = np.load(training_data_path + training_data_file + 'train_target_ratings.npy')
  val_target_ratings = np.load(training_data_path + training_data_file + 'val_target_ratings.npy')
  test_target_ratings = np.load(training_data_path + training_data_file + 'test_target_ratings.npy')

except OSError as e:
  print('\nERROR loading training data')
  print(e)
  quit()

# %%
if wandb_log:
  import wandb
  from wandb.keras import WandbMetricsLogger, WandbModelCheckpoint

  wandb.login()

  wandb.init(
    config=nn_config,
    entity=wandb_entity,
    project=wandb_project_name,
    name=wandb_run_name,
    group=wandb_group_name
  )
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: xbarantomik. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/home/baran-tomik/projects/DP/training/wandb/run-20240429_222709-l0fjc2yi</code>
# Syncing run <strong><a href='https://wandb.ai/xbarantomik/dp/runs/l0fjc2yi' target="_blank">arch5_1m_added_imdb_context_max_abs_scaler_gc</a></strong> to <a href='https://wandb.ai/xbarantomik/dp' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/xbarantomik/dp' target="_blank">https://wandb.ai/xbarantomik/dp</a>
#  View run at <a href='https://wandb.ai/xbarantomik/dp/runs/l0fjc2yi' target="_blank">https://wandb.ai/xbarantomik/dp/runs/l0fjc2yi</a>

# %% [markdown]
# #### NN MODEL

# %%
early_stopping = EarlyStopping(patience=patience, monitor='val_loss')

# %%
checkpoint_filepath = checkpoint_model_filepath + f"{wandb_run_name}_checkpoint.h5"
checkpoint_callback = ModelCheckpoint(filepath=checkpoint_filepath, monitor='val_loss', save_best_only=True, mode='min', save_weights_only=False, save_format='tf')

if wandb_log:
  callbacks = [early_stopping, checkpoint_callback, WandbMetricsLogger()]
else:
  callbacks = [early_stopping, checkpoint_callback]

# %% [markdown]
# #### Create model

# %%
if new_model:
  my_model = nn_model.create_model(architecture=architecture, lr=learning_rate, train_data_shape=train_data.shape[1])
  print('\nCreated a new model')
else:
  my_model = load_model(checkpoint_model_filepath + run_name_before + '_checkpoint.h5')
  print('\nLoaded a model')

if my_model != None:
  my_model.summary()
else:
  print('\nERROR loading NN model')
  quit()
# Out:
# Model 5
#
# Created a new model
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               21504
#
#  activation (Activation)     (None, 512)               0
#
#  dropout (Dropout)           (None, 512)               0
# 2024-04-29 22:27:14.083810: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-29 22:27:14.113427: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-29 22:27:14.113661: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-29 22:27:14.114333: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-29 22:27:14.114880: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-29 22:27:14.115079: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-29 22:27:14.115253: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-29 22:27:14.175129: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-29 22:27:14.175436: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-29 22:27:14.175560: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-29 22:27:14.175657: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7511 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1070, pci bus id: 0000:01:00.0, compute capability: 6.1
#  flatten (Flatten)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  activation_1 (Activation)   (None, 512)               0
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 512)               262656
#
#  activation_2 (Activation)   (None, 512)               0
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 256)               131328
#
#  activation_3 (Activation)   (None, 256)               0
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 256)               65792
#
#  activation_4 (Activation)   (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 744,193
# Trainable params: 744,193
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Model fitting

# %%
if not eval_only:
  print('Training model')
  trained_model = my_model.fit(train_data, train_target_ratings, batch_size, epochs, validation_data=(val_data, val_target_ratings), callbacks=callbacks, verbose=1)
  my_model.save(trained_model_filepath + f"{wandb_run_name}_trained.keras")
else:
  print('Only evaluating model')
# Out:
# Training model
# Epoch 1/25
# 3315/3315 [==============================] - 9s 2ms/step - loss: 1.1035 - root_mean_squared_error: 1.0505 - mean_absolute_error: 0.8328 - r_square: 0.0211 - val_loss: 0.9954 - val_root_mean_squared_error: 0.9977 - val_mean_absolute_error: 0.7931 - val_r_square: 0.1140
# Epoch 2/25
# 3315/3315 [==============================] - 8s 2ms/step - loss: 1.0266 - root_mean_squared_error: 1.0132 - mean_absolute_error: 0.8008 - r_square: 0.0893 - val_loss: 0.9904 - val_root_mean_squared_error: 0.9952 - val_mean_absolute_error: 0.7797 - val_r_square: 0.1185
# Epoch 3/25
# 3315/3315 [==============================] - 8s 2ms/step - loss: 1.0127 - root_mean_squared_error: 1.0063 - mean_absolute_error: 0.7954 - r_square: 0.1016 - val_loss: 0.9757 - val_root_mean_squared_error: 0.9878 - val_mean_absolute_error: 0.7768 - val_r_square: 0.1316
# Epoch 4/25
# 3315/3315 [==============================] - 8s 2ms/step - loss: 1.0015 - root_mean_squared_error: 1.0008 - mean_absolute_error: 0.7900 - r_square: 0.1116 - val_loss: 0.9768 - val_root_mean_squared_error: 0.9883 - val_mean_absolute_error: 0.7720 - val_r_square: 0.1306
# Epoch 5/25
# 3315/3315 [==============================] - 8s 2ms/step - loss: 0.9933 - root_mean_squared_error: 0.9966 - mean_absolute_error: 0.7863 - r_square: 0.1189 - val_loss: 0.9645 - val_root_mean_squared_error: 0.9821 - val_mean_absolute_error: 0.7743 - val_r_square: 0.1415
# Epoch 6/25
# 3315/3315 [==============================] - 8s 2ms/step - loss: 0.9881 - root_mean_squared_error: 0.9940 - mean_absolute_error: 0.7840 - r_square: 0.1235 - val_loss: 0.9623 - val_root_mean_squared_error: 0.9810 - val_mean_absolute_error: 0.7717 - val_r_square: 0.1435
# Epoch 7/25
# 3315/3315 [==============================] - 8s 2ms/step - loss: 0.9823 - root_mean_squared_error: 0.9911 - mean_absolute_error: 0.7813 - r_square: 0.1286 - val_loss: 0.9627 - val_root_mean_squared_error: 0.9812 - val_mean_absolute_error: 0.7695 - val_r_square: 0.1431
# Epoch 8/25
# 3315/3315 [==============================] - 8s 2ms/step - loss: 0.9774 - root_mean_squared_error: 0.9886 - mean_absolute_error: 0.7787 - r_square: 0.1329 - val_loss: 0.9627 - val_root_mean_squared_error: 0.9812 - val_mean_absolute_error: 0.7713 - val_r_square: 0.1431
# Epoch 9/25
# 3315/3315 [==============================] - 8s 2ms/step - loss: 0.9733 - root_mean_squared_error: 0.9866 - mean_absolute_error: 0.7771 - r_square: 0.1366 - val_loss: 0.9575 - val_root_mean_squared_error: 0.9785 - val_mean_absolute_error: 0.7737 - val_r_square: 0.1478
# Epoch 10/25
# 3315/3315 [==============================] - 8s 3ms/step - loss: 0.9711 - root_mean_squared_error: 0.9854 - mean_absolute_error: 0.7760 - r_square: 0.1386 - val_loss: 0.9504 - val_root_mean_squared_error: 0.9749 - val_mean_absolute_error: 0.7687 - val_r_square: 0.1541
# Epoch 11/25
# 3315/3315 [==============================] - 8s 2ms/step - loss: 0.9664 - root_mean_squared_error: 0.9831 - mean_absolute_error: 0.7737 - r_square: 0.1427 - val_loss: 0.9513 - val_root_mean_squared_error: 0.9753 - val_mean_absolute_error: 0.7663 - val_r_square: 0.1533
# Epoch 12/25
# 3315/3315 [==============================] - 8s 2ms/step - loss: 0.9656 - root_mean_squared_error: 0.9827 - mean_absolute_error: 0.7733 - r_square: 0.1434 - val_loss: 0.9520 - val_root_mean_squared_error: 0.9757 - val_mean_absolute_error: 0.7670 - val_r_square: 0.1526
# Epoch 13/25
# 3315/3315 [==============================] - 8s 2ms/step - loss: 0.9622 - root_mean_squared_error: 0.9809 - mean_absolute_error: 0.7718 - r_square: 0.1464 - val_loss: 0.9461 - val_root_mean_squared_error: 0.9727 - val_mean_absolute_error: 0.7659 - val_r_square: 0.1579
# Epoch 14/25
# 3315/3315 [==============================] - 8s 2ms/step - loss: 0.9611 - root_mean_squared_error: 0.9804 - mean_absolute_error: 0.7710 - r_square: 0.1474 - val_loss: 0.9492 - val_root_mean_squared_error: 0.9743 - val_mean_absolute_error: 0.7618 - val_r_square: 0.1551
# Epoch 15/25
# 3315/3315 [==============================] - 8s 2ms/step - loss: 0.9589 - root_mean_squared_error: 0.9792 - mean_absolute_error: 0.7705 - r_square: 0.1494 - val_loss: 0.9479 - val_root_mean_squared_error: 0.9736 - val_mean_absolute_error: 0.7661 - val_r_square: 0.1563
# Epoch 16/25
# 3315/3315 [==============================] - 8s 2ms/step - loss: 0.9573 - root_mean_squared_error: 0.9784 - mean_absolute_error: 0.7695 - r_square: 0.1508 - val_loss: 0.9499 - val_root_mean_squared_error: 0.9746 - val_mean_absolute_error: 0.7627 - val_r_square: 0.1545
# Epoch 17/25
# 3315/3315 [==============================] - 8s 2ms/step - loss: 0.9563 - root_mean_squared_error: 0.9779 - mean_absolute_error: 0.7689 - r_square: 0.1517 - val_loss: 0.9500 - val_root_mean_squared_error: 0.9747 - val_mean_absolute_error: 0.7652 - val_r_square: 0.1544
# Epoch 18/25
# 3315/3315 [==============================] - 8s 2ms/step - loss: 0.9547 - root_mean_squared_error: 0.9771 - mean_absolute_error: 0.7684 - r_square: 0.1531 - val_loss: 0.9462 - val_root_mean_squared_error: 0.9727 - val_mean_absolute_error: 0.7651 - val_r_square: 0.1578
# Epoch 19/25
# 3315/3315 [==============================] - 8s 2ms/step - loss: 0.9534 - root_mean_squared_error: 0.9764 - mean_absolute_error: 0.7672 - r_square: 0.1542 - val_loss: 0.9497 - val_root_mean_squared_error: 0.9745 - val_mean_absolute_error: 0.7644 - val_r_square: 0.1547
# Epoch 20/25
# 3315/3315 [==============================] - 8s 2ms/step - loss: 0.9520 - root_mean_squared_error: 0.9757 - mean_absolute_error: 0.7668 - r_square: 0.1555 - val_loss: 0.9472 - val_root_mean_squared_error: 0.9732 - val_mean_absolute_error: 0.7617 - val_r_square: 0.1569
# Epoch 21/25
# 3315/3315 [==============================] - 8s 2ms/step - loss: 0.9503 - root_mean_squared_error: 0.9748 - mean_absolute_error: 0.7659 - r_square: 0.1570 - val_loss: 0.9450 - val_root_mean_squared_error: 0.9721 - val_mean_absolute_error: 0.7645 - val_r_square: 0.1589
# Epoch 22/25
# 3315/3315 [==============================] - 8s 2ms/step - loss: 0.9507 - root_mean_squared_error: 0.9750 - mean_absolute_error: 0.7660 - r_square: 0.1566 - val_loss: 0.9456 - val_root_mean_squared_error: 0.9724 - val_mean_absolute_error: 0.7618 - val_r_square: 0.1584
# Epoch 23/25
# 3315/3315 [==============================] - 8s 2ms/step - loss: 0.9500 - root_mean_squared_error: 0.9747 - mean_absolute_error: 0.7655 - r_square: 0.1572 - val_loss: 0.9463 - val_root_mean_squared_error: 0.9728 - val_mean_absolute_error: 0.7629 - val_r_square: 0.1577
# Epoch 24/25
# 3315/3315 [==============================] - 8s 2ms/step - loss: 0.9492 - root_mean_squared_error: 0.9743 - mean_absolute_error: 0.7651 - r_square: 0.1580 - val_loss: 0.9488 - val_root_mean_squared_error: 0.9740 - val_mean_absolute_error: 0.7624 - val_r_square: 0.1555
# Epoch 25/25
# 3315/3315 [==============================] - 8s 2ms/step - loss: 0.9487 - root_mean_squared_error: 0.9740 - mean_absolute_error: 0.7647 - r_square: 0.1584 - val_loss: 0.9418 - val_root_mean_squared_error: 0.9705 - val_mean_absolute_error: 0.7615 - val_r_square: 0.1617

# %% [markdown]
# #### After fitting

# %%
metric_name = ['Loss', 'RootMSE', 'MAE', 'R2']
train_metric = ['loss', 'root_mean_squared_error', 'mean_absolute_error', 'r_square']
val_metric = ['val_loss', 'val_root_mean_squared_error', 'val_mean_absolute_error', 'val_r_square']

for i in range(len(metric_name)):

  print(f"\n----------- {metric_name[i]} chart -----------\n")

  # matplotlib chart
  plt.plot(trained_model.history[train_metric[i]], label=f"Train {metric_name[i]}")
  plt.plot(trained_model.history[val_metric[i]], label=f"Val {metric_name[i]}")
  plt.legend()
  plt.show()
# Out:
# ----------- Loss chart -----------
# ----------- RootMSE chart -----------
# ----------- MAE chart -----------
# ----------- R2 chart -----------

# %%
# Validation data values in the last epoch
print("number of epochs:", trained_model.epoch[-1] + 1)
print("val_loss:", trained_model.history['val_loss'][-1])
print("val_root_mean_squared_error:", trained_model.history['val_root_mean_squared_error'][-1])
print("val_mean_absolute_error:", trained_model.history['val_mean_absolute_error'][-1])
print("val_r2_score:", trained_model.history['val_r_square'][-1])
# Out:
# number of epochs: 25
# val_loss: 0.9418167471885681
# val_root_mean_squared_error: 0.9704724550247192
# val_mean_absolute_error: 0.7615285515785217
# val_r2_score: 0.16170990467071533

# %%
# Evaluate the model on the test data
print("Evaluate on test data")
test_loss, test_mean_squared_error, test_mean_absolute_error, test_r2_score = my_model.evaluate(test_data, test_target_ratings)
print("Test_loss:", test_loss)
print("Test_root_mean_squared_error:", test_mean_squared_error)
print("Test_mean_absolute_error:", test_mean_absolute_error)
print("Test_r2_score:", test_r2_score)
print('\n')

print("Generate predictions for 10 samples")
predictions = my_model.predict(test_data)
test_y_comparison = pd.DataFrame({'test_y_true': test_target_ratings, 'test_y_pred': [x for x in predictions]})

print(test_y_comparison.head(10))
# Out:
# Evaluate on test data
# 1658/1658 [==============================] - 2s 1ms/step - loss: 0.9404 - root_mean_squared_error: 0.9697 - mean_absolute_error: 0.7596 - r_square: 0.1613
# Test_loss: 0.9403674602508545
# Test_root_mean_squared_error: 0.9697254300117493
# Test_mean_absolute_error: 0.7595880627632141
# Test_r2_score: 0.1612684726715088
#
#
# Generate predictions for 10 samples
# 1658/1658 [==============================] - 1s 769us/step
#    test_y_true  test_y_pred
# 0          3.5   [4.117687]
# 1          4.0  [3.7974598]
# 2          4.0   [4.095219]
# 3          5.0  [3.8036819]
# 4          4.0  [3.4669762]
# 5          5.0  [3.9912143]
# 6          4.0  [3.9634423]
# 7          3.0   [3.593416]
# 8          5.0  [3.5927036]
# 9          3.0  [3.3595448]

# %%
if wandb_log:
  wandb.finish()
