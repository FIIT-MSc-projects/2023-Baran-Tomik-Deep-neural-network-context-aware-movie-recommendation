# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import load_model
import matplotlib.pyplot as plt
import plotly.express as px
import pandas as pd
import numpy as np
import json
# Out:
# 2024-04-29 22:46:31.271373: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-29 22:46:31.389353: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-29 22:46:31.885058: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/baran-tomik/bin/miniconda3/envs/tf/lib/
# 2024-04-29 22:46:31.885158: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/baran-tomik/bin/miniconda3/envs/tf/lib/
# 2024-04-29 22:46:31.885164: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
checkpoint_model_filepath = 'checkpoints/'
trained_model_filepath = 'trained_models/'
training_data_path = 'data_1m/'
nn_config_path = '../config/nn_config.json'
wandb_config_path = '../config/wandb_config.json'

print('Training data path:', training_data_path)

import nn_model
# Out:
# Training data path: data_1m/
# /home/baran-tomik/bin/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# /home/baran-tomik/bin/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.13.0 and strictly below 2.16.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.10.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
try:
  with open(wandb_config_path, 'r') as f:
    wandb_config = json.load(f)

  wandb_log = True
  wandb_run_name = wandb_config["wandb_run_name"]
  wandb_group_name = wandb_config["wandb_group_name"]
  wandb_entity = wandb_config["wandb_entity"]
  wandb_project_name = wandb_config["wandb_project_name"]
  if wandb_config["new_model"] == 'false':
    new_model = False
  else:
    new_model = True
  run_name_before = wandb_config["run_name_before"]   # Model to be loaded
  if wandb_config["eval_only"] == 'false':
    eval_only = False
  else:
    eval_only = True

  print('wandb_log:', wandb_log)
  print('wandb_run_name:', wandb_run_name)
  print('wandb_group_name:', wandb_group_name)
  print('wandb_entity:', wandb_entity)
  print('wandb_project_name:', wandb_project_name)
  print('new_model:', new_model)
  print('run_name_before:', run_name_before)
  print('eval_only:', eval_only)

except OSError as e:
  print('\nERROR loading wandb_config file')
  print(e)
  # quit()
# Out:
# wandb_log: True
# wandb_run_name: arch5_1m_movielens_context_max_abs_scaler_gc
# wandb_group_name: 1m_deep_dense
# wandb_entity: xbarantomik
# wandb_project_name: DP
# new_model: True
# run_name_before: -
# eval_only: False

# %%
try:
  with open(nn_config_path, 'r') as f:
    nn_config = json.load(f)

  epochs = int(nn_config['epochs'])
  batch_size = int(nn_config['batch_size'])
  patience = int(nn_config['patience'])
  learning_rate = float(nn_config['learning_rate'])
  architecture = int(nn_config['architecture'])
  training_data_file = nn_config['training_data_file'] + '/'

  print('epochs:', epochs)
  print('batch_size:', batch_size)
  print('patience:', patience)
  print('learning_rate:', learning_rate)
  print('architecture:', architecture)
  print('training_data_file:', training_data_file)

except OSError as e:
  print('\nERROR loading nn_config file')
  print(e)
# Out:
# epochs: 25
# batch_size: 128
# patience: 15
# learning_rate: 0.001
# architecture: 5
# training_data_file: movielens_context_max_abs_scaler/

# %% [markdown]
# #### Load training data

# %%
try:
  train_data = np.load(training_data_path + training_data_file + 'train_data.npy')
  val_data = np.load(training_data_path + training_data_file + 'val_data.npy')
  test_data = np.load(training_data_path + training_data_file + 'test_data.npy')
  train_target_ratings = np.load(training_data_path + training_data_file + 'train_target_ratings.npy')
  val_target_ratings = np.load(training_data_path + training_data_file + 'val_target_ratings.npy')
  test_target_ratings = np.load(training_data_path + training_data_file + 'test_target_ratings.npy')

except OSError as e:
  print('\nERROR loading training data')
  print(e)
  quit()

# %%
if wandb_log:
  import wandb
  from wandb.keras import WandbMetricsLogger, WandbModelCheckpoint

  wandb.login()

  wandb.init(
    config=nn_config,
    entity=wandb_entity,
    project=wandb_project_name,
    name=wandb_run_name,
    group=wandb_group_name
  )
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: xbarantomik. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/home/baran-tomik/projects/DP/training/wandb/run-20240429_224634-6k2s3l1k</code>
# Syncing run <strong><a href='https://wandb.ai/xbarantomik/dp/runs/6k2s3l1k' target="_blank">arch5_1m_movielens_context_max_abs_scaler_gc</a></strong> to <a href='https://wandb.ai/xbarantomik/dp' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/xbarantomik/dp' target="_blank">https://wandb.ai/xbarantomik/dp</a>
#  View run at <a href='https://wandb.ai/xbarantomik/dp/runs/6k2s3l1k' target="_blank">https://wandb.ai/xbarantomik/dp/runs/6k2s3l1k</a>

# %% [markdown]
# #### NN MODEL

# %%
early_stopping = EarlyStopping(patience=patience, monitor='val_loss')

# %%
checkpoint_filepath = checkpoint_model_filepath + f"{wandb_run_name}_checkpoint.h5"
checkpoint_callback = ModelCheckpoint(filepath=checkpoint_filepath, monitor='val_loss', save_best_only=True, mode='min', save_weights_only=False, save_format='tf')

if wandb_log:
  callbacks = [early_stopping, checkpoint_callback, WandbMetricsLogger()]
else:
  callbacks = [early_stopping, checkpoint_callback]

# %% [markdown]
# #### Create model

# %%
if new_model:
  my_model = nn_model.create_model(architecture=architecture, lr=learning_rate, train_data_shape=train_data.shape[1])
  print('\nCreated a new model')
else:
  my_model = load_model(checkpoint_model_filepath + run_name_before + '_checkpoint.h5')
  print('\nLoaded a model')

if my_model != None:
  my_model.summary()
else:
  print('\nERROR loading NN model')
  quit()
# Out:
# Model 5
# 2024-04-29 22:46:38.661456: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-29 22:46:38.686239: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-29 22:46:38.686418: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-29 22:46:38.687513: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-29 22:46:38.688110: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-29 22:46:38.688305: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-29 22:46:38.688432: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-29 22:46:38.750092: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-29 22:46:38.750265: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-29 22:46:38.750384: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-29 22:46:38.750479: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7511 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1070, pci bus id: 0000:01:00.0, compute capability: 6.1
# Created a new model
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               15872
#
#  activation (Activation)     (None, 512)               0
#
#  dropout (Dropout)           (None, 512)               0
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  activation_1 (Activation)   (None, 512)               0
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 512)               262656
#
#  activation_2 (Activation)   (None, 512)               0
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 256)               131328
#
#  activation_3 (Activation)   (None, 256)               0
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 256)               65792
#
#  activation_4 (Activation)   (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 738,561
# Trainable params: 738,561
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Model fitting

# %%
if not eval_only:
  print('Training model')
  trained_model = my_model.fit(train_data, train_target_ratings, batch_size, epochs, validation_data=(val_data, val_target_ratings), callbacks=callbacks, verbose=1)
  my_model.save(trained_model_filepath + f"{wandb_run_name}_trained.keras")
else:
  print('Only evaluating model')
# Out:
# Training model
# Epoch 1/25
# 6252/6252 [==============================] - 16s 2ms/step - loss: 1.2164 - root_mean_squared_error: 1.1029 - mean_absolute_error: 0.8965 - r_square: 0.0241 - val_loss: 1.1564 - val_root_mean_squared_error: 1.0753 - val_mean_absolute_error: 0.8891 - val_r_square: 0.0791
# Epoch 2/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.1550 - root_mean_squared_error: 1.0747 - mean_absolute_error: 0.8721 - r_square: 0.0734 - val_loss: 1.1227 - val_root_mean_squared_error: 1.0596 - val_mean_absolute_error: 0.8579 - val_r_square: 0.1059
# Epoch 3/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.1386 - root_mean_squared_error: 1.0670 - mean_absolute_error: 0.8655 - r_square: 0.0865 - val_loss: 1.1159 - val_root_mean_squared_error: 1.0563 - val_mean_absolute_error: 0.8556 - val_r_square: 0.1114
# Epoch 4/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.1291 - root_mean_squared_error: 1.0626 - mean_absolute_error: 0.8613 - r_square: 0.0941 - val_loss: 1.1076 - val_root_mean_squared_error: 1.0524 - val_mean_absolute_error: 0.8560 - val_r_square: 0.1180
# Epoch 5/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.1225 - root_mean_squared_error: 1.0595 - mean_absolute_error: 0.8590 - r_square: 0.0994 - val_loss: 1.1061 - val_root_mean_squared_error: 1.0517 - val_mean_absolute_error: 0.8526 - val_r_square: 0.1192
# Epoch 6/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.1174 - root_mean_squared_error: 1.0571 - mean_absolute_error: 0.8568 - r_square: 0.1035 - val_loss: 1.1000 - val_root_mean_squared_error: 1.0488 - val_mean_absolute_error: 0.8465 - val_r_square: 0.1241
# Epoch 7/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.1127 - root_mean_squared_error: 1.0549 - mean_absolute_error: 0.8543 - r_square: 0.1073 - val_loss: 1.0982 - val_root_mean_squared_error: 1.0479 - val_mean_absolute_error: 0.8517 - val_r_square: 0.1255
# Epoch 8/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.1101 - root_mean_squared_error: 1.0536 - mean_absolute_error: 0.8539 - r_square: 0.1094 - val_loss: 1.0948 - val_root_mean_squared_error: 1.0463 - val_mean_absolute_error: 0.8442 - val_r_square: 0.1282
# Epoch 9/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.1053 - root_mean_squared_error: 1.0514 - mean_absolute_error: 0.8522 - r_square: 0.1132 - val_loss: 1.0965 - val_root_mean_squared_error: 1.0471 - val_mean_absolute_error: 0.8415 - val_r_square: 0.1268
# Epoch 10/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.1037 - root_mean_squared_error: 1.0506 - mean_absolute_error: 0.8511 - r_square: 0.1145 - val_loss: 1.0935 - val_root_mean_squared_error: 1.0457 - val_mean_absolute_error: 0.8402 - val_r_square: 0.1292
# Epoch 11/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.1008 - root_mean_squared_error: 1.0492 - mean_absolute_error: 0.8492 - r_square: 0.1169 - val_loss: 1.0942 - val_root_mean_squared_error: 1.0460 - val_mean_absolute_error: 0.8477 - val_r_square: 0.1287
# Epoch 12/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0991 - root_mean_squared_error: 1.0484 - mean_absolute_error: 0.8477 - r_square: 0.1182 - val_loss: 1.0870 - val_root_mean_squared_error: 1.0426 - val_mean_absolute_error: 0.8416 - val_r_square: 0.1343
# Epoch 13/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0967 - root_mean_squared_error: 1.0472 - mean_absolute_error: 0.8468 - r_square: 0.1201 - val_loss: 1.0917 - val_root_mean_squared_error: 1.0448 - val_mean_absolute_error: 0.8348 - val_r_square: 0.1306
# Epoch 14/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0957 - root_mean_squared_error: 1.0468 - mean_absolute_error: 0.8464 - r_square: 0.1209 - val_loss: 1.0861 - val_root_mean_squared_error: 1.0421 - val_mean_absolute_error: 0.8428 - val_r_square: 0.1351
# Epoch 15/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0943 - root_mean_squared_error: 1.0461 - mean_absolute_error: 0.8459 - r_square: 0.1220 - val_loss: 1.0852 - val_root_mean_squared_error: 1.0417 - val_mean_absolute_error: 0.8428 - val_r_square: 0.1358
# Epoch 16/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0928 - root_mean_squared_error: 1.0454 - mean_absolute_error: 0.8453 - r_square: 0.1232 - val_loss: 1.0862 - val_root_mean_squared_error: 1.0422 - val_mean_absolute_error: 0.8423 - val_r_square: 0.1350
# Epoch 17/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0914 - root_mean_squared_error: 1.0447 - mean_absolute_error: 0.8442 - r_square: 0.1244 - val_loss: 1.0858 - val_root_mean_squared_error: 1.0420 - val_mean_absolute_error: 0.8367 - val_r_square: 0.1354
# Epoch 18/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0903 - root_mean_squared_error: 1.0442 - mean_absolute_error: 0.8439 - r_square: 0.1253 - val_loss: 1.0911 - val_root_mean_squared_error: 1.0446 - val_mean_absolute_error: 0.8499 - val_r_square: 0.1311
# Epoch 19/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0897 - root_mean_squared_error: 1.0439 - mean_absolute_error: 0.8438 - r_square: 0.1258 - val_loss: 1.0904 - val_root_mean_squared_error: 1.0442 - val_mean_absolute_error: 0.8390 - val_r_square: 0.1317
# Epoch 20/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0892 - root_mean_squared_error: 1.0437 - mean_absolute_error: 0.8436 - r_square: 0.1261 - val_loss: 1.0840 - val_root_mean_squared_error: 1.0412 - val_mean_absolute_error: 0.8366 - val_r_square: 0.1368
# Epoch 21/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0877 - root_mean_squared_error: 1.0429 - mean_absolute_error: 0.8430 - r_square: 0.1273 - val_loss: 1.0837 - val_root_mean_squared_error: 1.0410 - val_mean_absolute_error: 0.8385 - val_r_square: 0.1370
# Epoch 22/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0867 - root_mean_squared_error: 1.0424 - mean_absolute_error: 0.8425 - r_square: 0.1282 - val_loss: 1.0865 - val_root_mean_squared_error: 1.0424 - val_mean_absolute_error: 0.8474 - val_r_square: 0.1348
# Epoch 23/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0864 - root_mean_squared_error: 1.0423 - mean_absolute_error: 0.8423 - r_square: 0.1284 - val_loss: 1.0842 - val_root_mean_squared_error: 1.0413 - val_mean_absolute_error: 0.8365 - val_r_square: 0.1366
# Epoch 24/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0855 - root_mean_squared_error: 1.0419 - mean_absolute_error: 0.8420 - r_square: 0.1292 - val_loss: 1.0817 - val_root_mean_squared_error: 1.0400 - val_mean_absolute_error: 0.8436 - val_r_square: 0.1386
# Epoch 25/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0847 - root_mean_squared_error: 1.0415 - mean_absolute_error: 0.8418 - r_square: 0.1298 - val_loss: 1.0800 - val_root_mean_squared_error: 1.0392 - val_mean_absolute_error: 0.8403 - val_r_square: 0.1400

# %% [markdown]
# #### After fitting

# %%
metric_name = ['Loss', 'RootMSE', 'MAE', 'R2']
train_metric = ['loss', 'root_mean_squared_error', 'mean_absolute_error', 'r_square']
val_metric = ['val_loss', 'val_root_mean_squared_error', 'val_mean_absolute_error', 'val_r_square']

for i in range(len(metric_name)):

  print(f"\n----------- {metric_name[i]} chart -----------\n")

  # matplotlib chart
  plt.plot(trained_model.history[train_metric[i]], label=f"Train {metric_name[i]}")
  plt.plot(trained_model.history[val_metric[i]], label=f"Val {metric_name[i]}")
  plt.legend()
  plt.show()
# Out:
# ----------- Loss chart -----------
# ----------- RootMSE chart -----------
# ----------- MAE chart -----------
# ----------- R2 chart -----------

# %%
# Validation data values in the last epoch
print("number of epochs:", trained_model.epoch[-1] + 1)
print("val_loss:", trained_model.history['val_loss'][-1])
print("val_root_mean_squared_error:", trained_model.history['val_root_mean_squared_error'][-1])
print("val_mean_absolute_error:", trained_model.history['val_mean_absolute_error'][-1])
print("val_r2_score:", trained_model.history['val_r_square'][-1])
# Out:
# number of epochs: 25
# val_loss: 1.079965353012085
# val_root_mean_squared_error: 1.03921377658844
# val_mean_absolute_error: 0.8403325080871582
# val_r2_score: 0.1399889588356018

# %%
# Evaluate the model on the test data
print("Evaluate on test data")
test_loss, test_mean_squared_error, test_mean_absolute_error, test_r2_score = my_model.evaluate(test_data, test_target_ratings)
print("Test_loss:", test_loss)
print("Test_root_mean_squared_error:", test_mean_squared_error)
print("Test_mean_absolute_error:", test_mean_absolute_error)
print("Test_r2_score:", test_r2_score)
print('\n')

print("Generate predictions for 10 samples")
predictions = my_model.predict(test_data)
test_y_comparison = pd.DataFrame({'test_y_true': test_target_ratings, 'test_y_pred': [x for x in predictions]})

print(test_y_comparison.head(10))
# Out:
# Evaluate on test data
# 3126/3126 [==============================] - 4s 1ms/step - loss: 1.0826 - root_mean_squared_error: 1.0405 - mean_absolute_error: 0.8426 - r_square: 0.1352
# Test_loss: 1.0825555324554443
# Test_root_mean_squared_error: 1.0404592752456665
# Test_mean_absolute_error: 0.8425660133361816
# Test_r2_score: 0.13521873950958252
#
#
# Generate predictions for 10 samples
# 3126/3126 [==============================] - 2s 762us/step
#    test_y_true  test_y_pred
# 0            4  [3.7494845]
# 1            3  [2.9358213]
# 2            5  [3.8799531]
# 3            5  [4.1120396]
# 4            4  [3.9292178]
# 5            4  [3.7478967]
# 6            4  [4.0792413]
# 7            3    [3.88721]
# 8            1  [3.2899146]
# 9            5  [4.0089507]

# %%
if wandb_log:
  wandb.finish()
# Out:
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch/epoch</td><td>▁▁▂▂▂▂▃▃▃▄▄▄▅▅▅▅▆▆▆▇▇▇▇██</td></tr><tr><td>epoch/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/loss</td><td>█▅▄▃▃▃▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/mean_absolute_error</td><td>█▅▄▃▃▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/r_square</td><td>▁▄▅▆▆▆▇▇▇▇▇▇▇▇▇██████████</td></tr><tr><td>epoch/root_mean_squared_error</td><td>█▅▄▃▃▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/val_loss</td><td>█▅▄▄▃▃▃▂▃▂▂▂▂▂▁▂▂▂▂▁▁▂▁▁▁</td></tr><tr><td>epoch/val_mean_absolute_error</td><td>█▄▄▄▃▃▃▂▂▂▃▂▁▂▂▂▁▃▂▁▁▃▁▂▂</td></tr><tr><td>epoch/val_r_square</td><td>▁▄▅▅▆▆▆▇▆▇▇▇▇▇█▇▇▇▇██▇███</td></tr><tr><td>epoch/val_root_mean_squared_error</td><td>█▅▄▄▃▃▃▂▃▂▂▂▂▂▁▂▂▂▂▁▁▂▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/epoch</td><td>24</td></tr><tr><td>epoch/learning_rate</td><td>0.001</td></tr><tr><td>epoch/loss</td><td>1.08467</td></tr><tr><td>epoch/mean_absolute_error</td><td>0.84177</td></tr><tr><td>epoch/r_square</td><td>0.12979</td></tr><tr><td>epoch/root_mean_squared_error</td><td>1.04148</td></tr><tr><td>epoch/val_loss</td><td>1.07997</td></tr><tr><td>epoch/val_mean_absolute_error</td><td>0.84033</td></tr><tr><td>epoch/val_r_square</td><td>0.13999</td></tr><tr><td>epoch/val_root_mean_squared_error</td><td>1.03921</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">arch5_1m_movielens_context_max_abs_scaler_gc</strong> at: <a href='https://wandb.ai/xbarantomik/dp/runs/6k2s3l1k' target="_blank">https://wandb.ai/xbarantomik/dp/runs/6k2s3l1k</a><br/> View project at: <a href='https://wandb.ai/xbarantomik/dp' target="_blank">https://wandb.ai/xbarantomik/dp</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240429_224634-6k2s3l1k/logs</code>
