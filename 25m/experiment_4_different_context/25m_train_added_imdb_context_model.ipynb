# %% [markdown]
# ## Experiment 4 - 25m - Added IMDb Context model

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import load_model
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json
# Out:
# 2024-05-12 13:02:38.060272: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-12 13:02:38.180465: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-12 13:02:38.673412: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/baran-tomik/bin/miniconda3/envs/tf/lib/
# 2024-05-12 13:02:38.673510: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/baran-tomik/bin/miniconda3/envs/tf/lib/
# 2024-05-12 13:02:38.673516: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
checkpoint_model_filepath = 'checkpoints/'
trained_model_filepath = 'trained_models/'
training_data_path = 'data_25m/'
nn_config_path = '../config/nn_config.json'
wandb_config_path = '../config/wandb_config.json'

print('Training data path:', training_data_path)

import nn_model
# Out:
# Training data path: data_25m/
# /home/baran-tomik/bin/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# /home/baran-tomik/bin/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.13.0 and strictly below 2.16.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.10.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
try:
  with open(wandb_config_path, 'r') as f:
    wandb_config = json.load(f)

  wandb_log = True
  wandb_run_name = wandb_config["wandb_run_name"]
  wandb_group_name = wandb_config["wandb_group_name"]
  wandb_entity = wandb_config["wandb_entity"]
  wandb_project_name = wandb_config["wandb_project_name"]
  if wandb_config["new_model"] == 'false':
    new_model = False
  else:
    new_model = True
  run_name_before = wandb_config["run_name_before"]   # Model to be loaded
  if wandb_config["eval_only"] == 'false':
    eval_only = False
  else:
    eval_only = True

  print('wandb_log:', wandb_log)
  print('wandb_run_name:', wandb_run_name)
  print('wandb_group_name:', wandb_group_name)
  print('wandb_entity:', wandb_entity)
  print('wandb_project_name:', wandb_project_name)
  print('new_model:', new_model)
  print('run_name_before:', run_name_before)
  print('eval_only:', eval_only)

except OSError as e:
  print('\nERROR loading wandb_config file')
  print(e)
  # quit()
# Out:
# wandb_log: True
# wandb_run_name: arch5_25m_added_imdb_context_max_abs_scaler_gn
# wandb_group_name: 25m_deep_dense
# wandb_entity: xbarantomik
# wandb_project_name: DP
# new_model: True
# run_name_before: -
# eval_only: False

# %%
try:
  with open(nn_config_path, 'r') as f:
    nn_config = json.load(f)

  epochs = int(nn_config['epochs'])
  batch_size = int(nn_config['batch_size'])
  patience = int(nn_config['patience'])
  learning_rate = float(nn_config['learning_rate'])
  architecture = int(nn_config['architecture'])
  training_data_file = nn_config['training_data_file'] + '/'

  print('epochs:', epochs)
  print('batch_size:', batch_size)
  print('patience:', patience)
  print('learning_rate:', learning_rate)
  print('architecture:', architecture)
  print('training_data_file:', training_data_file)

except OSError as e:
  print('\nERROR loading nn_config file')
  print(e)
# Out:
# epochs: 25
# batch_size: 128
# patience: 15
# learning_rate: 0.001
# architecture: 5
# training_data_file: added_imdb_context_max_abs_scaler/

# %% [markdown]
# #### Load training data

# %%
try:
  train_data = np.load(training_data_path + training_data_file + 'train_data.npy')
  val_data = np.load(training_data_path + training_data_file + 'val_data.npy')
  test_data = np.load(training_data_path + training_data_file + 'test_data.npy')
  train_target_ratings = np.load(training_data_path + training_data_file + 'train_target_ratings.npy')
  val_target_ratings = np.load(training_data_path + training_data_file + 'val_target_ratings.npy')
  test_target_ratings = np.load(training_data_path + training_data_file + 'test_target_ratings.npy')

except OSError as e:
  print('\nERROR loading training data')
  print(e)
  quit()

# %%
if wandb_log:
  import wandb
  from wandb.keras import WandbMetricsLogger, WandbModelCheckpoint

  wandb.login()

  wandb.init(
    config=nn_config,
    entity=wandb_entity,
    project=wandb_project_name,
    name=wandb_run_name,
    group=wandb_group_name
  )
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: xbarantomik. Use `wandb login --relogin` to force relogin
# wandb version 0.17.0 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/home/baran-tomik/projects/DP/training/wandb/run-20240512_130242-8lhaoqw4</code>
# Syncing run <strong><a href='https://wandb.ai/xbarantomik/dp/runs/8lhaoqw4' target="_blank">arch5_25m_added_imdb_context_max_abs_scaler_gn</a></strong> to <a href='https://wandb.ai/xbarantomik/dp' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/xbarantomik/dp' target="_blank">https://wandb.ai/xbarantomik/dp</a>
#  View run at <a href='https://wandb.ai/xbarantomik/dp/runs/8lhaoqw4' target="_blank">https://wandb.ai/xbarantomik/dp/runs/8lhaoqw4</a>

# %% [markdown]
# #### NN MODEL

# %%
early_stopping = EarlyStopping(patience=patience, monitor='val_loss')

# %%
checkpoint_filepath = checkpoint_model_filepath + f"{wandb_run_name}_checkpoint.h5"
checkpoint_callback = ModelCheckpoint(filepath=checkpoint_filepath, monitor='val_loss', save_best_only=True, mode='min', save_weights_only=False, save_format='tf')

if wandb_log:
  callbacks = [early_stopping, checkpoint_callback, WandbMetricsLogger()]
else:
  callbacks = [early_stopping, checkpoint_callback]

# %% [markdown]
# #### Create model

# %%
if new_model:
  my_model = nn_model.create_model(architecture=architecture, lr=learning_rate, train_data_shape=train_data.shape[1])
  print('\nCreated a new model')
else:
  my_model = load_model(checkpoint_model_filepath + run_name_before + '_checkpoint.h5')
  print('\nLoaded a model')

if my_model != None:
  my_model.summary()
else:
  print('\nERROR loading NN model')
  quit()
# Out:
# Model 5
#
# Created a new model
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               21504
# 2024-05-12 13:02:46.889969: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-12 13:02:46.917843: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-12 13:02:46.918035: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-12 13:02:46.918828: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-12 13:02:46.919295: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-12 13:02:46.919463: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-12 13:02:46.919630: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-12 13:02:46.981618: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-12 13:02:46.981793: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-12 13:02:46.981912: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-12 13:02:46.982008: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7511 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1070, pci bus id: 0000:01:00.0, compute capability: 6.1
#  activation (Activation)     (None, 512)               0
#
#  dropout (Dropout)           (None, 512)               0
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  activation_1 (Activation)   (None, 512)               0
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 512)               262656
#
#  activation_2 (Activation)   (None, 512)               0
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 256)               131328
#
#  activation_3 (Activation)   (None, 256)               0
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 256)               65792
#
#  activation_4 (Activation)   (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 744,193
# Trainable params: 744,193
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Model fitting

# %%
if not eval_only:
  print('Training model')
  trained_model = my_model.fit(train_data, train_target_ratings, batch_size, epochs, validation_data=(val_data, val_target_ratings), callbacks=callbacks, verbose=1)
  my_model.save(trained_model_filepath + f"{wandb_run_name}_trained.keras")
else:
  print('Only evaluating model')
# Out:
# Training model
# 2024-05-12 13:02:48.274042: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 3277831100 exceeds 10% of free system memory.
# 2024-05-12 13:02:50.188869: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 3277831100 exceeds 10% of free system memory.
# Epoch 1/25
# 156147/156147 [==============================] - 370s 2ms/step - loss: 1.0197 - root_mean_squared_error: 1.0098 - mean_absolute_error: 0.7908 - r_square: 0.0932 - val_loss: 0.9902 - val_root_mean_squared_error: 0.9951 - val_mean_absolute_error: 0.7737 - val_r_square: 0.1194
# Epoch 2/25
# 156147/156147 [==============================] - 369s 2ms/step - loss: 0.9953 - root_mean_squared_error: 0.9976 - mean_absolute_error: 0.7791 - r_square: 0.1152 - val_loss: 0.9800 - val_root_mean_squared_error: 0.9899 - val_mean_absolute_error: 0.7713 - val_r_square: 0.1285
# Epoch 3/25
# 156147/156147 [==============================] - 370s 2ms/step - loss: 0.9897 - root_mean_squared_error: 0.9948 - mean_absolute_error: 0.7764 - r_square: 0.1200 - val_loss: 0.9700 - val_root_mean_squared_error: 0.9849 - val_mean_absolute_error: 0.7660 - val_r_square: 0.1374
# Epoch 4/25
# 156147/156147 [==============================] - 370s 2ms/step - loss: 0.9877 - root_mean_squared_error: 0.9938 - mean_absolute_error: 0.7753 - r_square: 0.1218 - val_loss: 0.9693 - val_root_mean_squared_error: 0.9846 - val_mean_absolute_error: 0.7678 - val_r_square: 0.1379
# Epoch 5/25
# 156147/156147 [==============================] - 370s 2ms/step - loss: 0.9864 - root_mean_squared_error: 0.9932 - mean_absolute_error: 0.7745 - r_square: 0.1228 - val_loss: 0.9690 - val_root_mean_squared_error: 0.9844 - val_mean_absolute_error: 0.7658 - val_r_square: 0.1382
# Epoch 6/25
# 156147/156147 [==============================] - 370s 2ms/step - loss: 0.9856 - root_mean_squared_error: 0.9928 - mean_absolute_error: 0.7741 - r_square: 0.1239 - val_loss: 0.9665 - val_root_mean_squared_error: 0.9831 - val_mean_absolute_error: 0.7649 - val_r_square: 0.1404
# Epoch 7/25
# 156147/156147 [==============================] - 370s 2ms/step - loss: 0.9852 - root_mean_squared_error: 0.9926 - mean_absolute_error: 0.7740 - r_square: 0.1242 - val_loss: 0.9663 - val_root_mean_squared_error: 0.9830 - val_mean_absolute_error: 0.7656 - val_r_square: 0.1406
# Epoch 8/25
# 156147/156147 [==============================] - 370s 2ms/step - loss: 0.9852 - root_mean_squared_error: 0.9926 - mean_absolute_error: 0.7739 - r_square: 0.1240 - val_loss: 0.9721 - val_root_mean_squared_error: 0.9859 - val_mean_absolute_error: 0.7679 - val_r_square: 0.1355
# Epoch 9/25
# 156147/156147 [==============================] - 370s 2ms/step - loss: 0.9852 - root_mean_squared_error: 0.9926 - mean_absolute_error: 0.7739 - r_square: 0.1242 - val_loss: 0.9645 - val_root_mean_squared_error: 0.9821 - val_mean_absolute_error: 0.7694 - val_r_square: 0.1422
# Epoch 10/25
# 156147/156147 [==============================] - 368s 2ms/step - loss: 0.9850 - root_mean_squared_error: 0.9925 - mean_absolute_error: 0.7738 - r_square: 0.1241 - val_loss: 0.9664 - val_root_mean_squared_error: 0.9830 - val_mean_absolute_error: 0.7616 - val_r_square: 0.1406
# Epoch 11/25
# 156147/156147 [==============================] - 368s 2ms/step - loss: 0.9845 - root_mean_squared_error: 0.9922 - mean_absolute_error: 0.7736 - r_square: 0.1248 - val_loss: 0.9653 - val_root_mean_squared_error: 0.9825 - val_mean_absolute_error: 0.7628 - val_r_square: 0.1415
# Epoch 12/25
# 156147/156147 [==============================] - 368s 2ms/step - loss: 0.9842 - root_mean_squared_error: 0.9921 - mean_absolute_error: 0.7734 - r_square: 0.1248 - val_loss: 0.9726 - val_root_mean_squared_error: 0.9862 - val_mean_absolute_error: 0.7691 - val_r_square: 0.1350
# Epoch 13/25
# 156147/156147 [==============================] - 369s 2ms/step - loss: 0.9841 - root_mean_squared_error: 0.9920 - mean_absolute_error: 0.7734 - r_square: 0.1250 - val_loss: 0.9635 - val_root_mean_squared_error: 0.9816 - val_mean_absolute_error: 0.7583 - val_r_square: 0.1431
# Epoch 14/25
# 156147/156147 [==============================] - 369s 2ms/step - loss: 0.9848 - root_mean_squared_error: 0.9924 - mean_absolute_error: 0.7738 - r_square: 0.1244 - val_loss: 0.9793 - val_root_mean_squared_error: 0.9896 - val_mean_absolute_error: 0.7819 - val_r_square: 0.1291
# Epoch 15/25
# 156147/156147 [==============================] - 369s 2ms/step - loss: 0.9855 - root_mean_squared_error: 0.9927 - mean_absolute_error: 0.7741 - r_square: 0.1238 - val_loss: 0.9634 - val_root_mean_squared_error: 0.9815 - val_mean_absolute_error: 0.7625 - val_r_square: 0.1432
# Epoch 16/25
# 156147/156147 [==============================] - 369s 2ms/step - loss: 0.9851 - root_mean_squared_error: 0.9925 - mean_absolute_error: 0.7739 - r_square: 0.1244 - val_loss: 0.9668 - val_root_mean_squared_error: 0.9832 - val_mean_absolute_error: 0.7706 - val_r_square: 0.1402
# Epoch 17/25
# 156147/156147 [==============================] - 368s 2ms/step - loss: 0.9852 - root_mean_squared_error: 0.9926 - mean_absolute_error: 0.7740 - r_square: 0.1241 - val_loss: 0.9689 - val_root_mean_squared_error: 0.9843 - val_mean_absolute_error: 0.7657 - val_r_square: 0.1383
# Epoch 18/25
# 156147/156147 [==============================] - 369s 2ms/step - loss: 0.9852 - root_mean_squared_error: 0.9926 - mean_absolute_error: 0.7739 - r_square: 0.1240 - val_loss: 0.9651 - val_root_mean_squared_error: 0.9824 - val_mean_absolute_error: 0.7600 - val_r_square: 0.1417
# Epoch 19/25
# 156147/156147 [==============================] - 369s 2ms/step - loss: 0.9861 - root_mean_squared_error: 0.9930 - mean_absolute_error: 0.7739 - r_square: 0.1231 - val_loss: 0.9638 - val_root_mean_squared_error: 0.9817 - val_mean_absolute_error: 0.7626 - val_r_square: 0.1429
# Epoch 20/25
# 156147/156147 [==============================] - 370s 2ms/step - loss: 0.9853 - root_mean_squared_error: 0.9926 - mean_absolute_error: 0.7736 - r_square: 0.1242 - val_loss: 0.9654 - val_root_mean_squared_error: 0.9825 - val_mean_absolute_error: 0.7603 - val_r_square: 0.1414
# Epoch 21/25
# 156147/156147 [==============================] - 371s 2ms/step - loss: 0.9852 - root_mean_squared_error: 0.9926 - mean_absolute_error: 0.7736 - r_square: 0.1241 - val_loss: 0.9701 - val_root_mean_squared_error: 0.9849 - val_mean_absolute_error: 0.7709 - val_r_square: 0.1372
# Epoch 22/25
# 156147/156147 [==============================] - 371s 2ms/step - loss: 0.9852 - root_mean_squared_error: 0.9926 - mean_absolute_error: 0.7735 - r_square: 0.1242 - val_loss: 0.9615 - val_root_mean_squared_error: 0.9806 - val_mean_absolute_error: 0.7596 - val_r_square: 0.1449
# Epoch 23/25
# 156147/156147 [==============================] - 371s 2ms/step - loss: 0.9858 - root_mean_squared_error: 0.9929 - mean_absolute_error: 0.7739 - r_square: 0.1235 - val_loss: 0.9624 - val_root_mean_squared_error: 0.9810 - val_mean_absolute_error: 0.7642 - val_r_square: 0.1441
# Epoch 24/25
# 156147/156147 [==============================] - 371s 2ms/step - loss: 0.9862 - root_mean_squared_error: 0.9931 - mean_absolute_error: 0.7741 - r_square: 0.1234 - val_loss: 0.9700 - val_root_mean_squared_error: 0.9849 - val_mean_absolute_error: 0.7739 - val_r_square: 0.1374
# Epoch 25/25
# 156147/156147 [==============================] - 371s 2ms/step - loss: 0.9858 - root_mean_squared_error: 0.9929 - mean_absolute_error: 0.7738 - r_square: 0.1235 - val_loss: 0.9602 - val_root_mean_squared_error: 0.9799 - val_mean_absolute_error: 0.7657 - val_r_square: 0.1461

# %% [markdown]
# #### After fitting

# %%
metric_name = ['Loss', 'RootMSE', 'MAE', 'R2']
train_metric = ['loss', 'root_mean_squared_error', 'mean_absolute_error', 'r_square']
val_metric = ['val_loss', 'val_root_mean_squared_error', 'val_mean_absolute_error', 'val_r_square']

for i in range(len(metric_name)):

  print(f"\n----------- {metric_name[i]} chart -----------\n")

  # matplotlib chart
  plt.plot(trained_model.history[train_metric[i]], label=f"Train {metric_name[i]}")
  plt.plot(trained_model.history[val_metric[i]], label=f"Val {metric_name[i]}")
  plt.legend()
  plt.show()
# Out:
# ----------- Loss chart -----------
# ----------- RootMSE chart -----------
# ----------- MAE chart -----------
# ----------- R2 chart -----------

# %%
# Validation data values in the last epoch
print("number of epochs:", trained_model.epoch[-1] + 1)
print("val_loss:", trained_model.history['val_loss'][-1])
print("val_root_mean_squared_error:", trained_model.history['val_root_mean_squared_error'][-1])
print("val_mean_absolute_error:", trained_model.history['val_mean_absolute_error'][-1])
print("val_r2_score:", trained_model.history['val_r_square'][-1])
# Out:
# number of epochs: 25
# val_loss: 0.9601964950561523
# val_root_mean_squared_error: 0.9798961877822876
# val_mean_absolute_error: 0.7656582593917847
# val_r2_score: 0.14605319499969482

# %%
# Evaluate the model on the test data
print("Evaluate on test data")
test_loss, test_mean_squared_error, test_mean_absolute_error, test_r2_score = my_model.evaluate(test_data, test_target_ratings)
print("Test_loss:", test_loss)
print("Test_root_mean_squared_error:", test_mean_squared_error)
print("Test_mean_absolute_error:", test_mean_absolute_error)
print("Test_r2_score:", test_r2_score)
print('\n')

print("Generate predictions for 10 samples")
predictions = my_model.predict(test_data)
test_y_comparison = pd.DataFrame({'test_y_true': test_target_ratings, 'test_y_pred': [x for x in predictions]})

print(test_y_comparison.head(10))
# Out:
# Evaluate on test data
# 78074/78074 [==============================] - 108s 1ms/step - loss: 0.9654 - root_mean_squared_error: 0.9825 - mean_absolute_error: 0.7666 - r_square: 0.1428
# Test_loss: 0.965388298034668
# Test_root_mean_squared_error: 0.9825417399406433
# Test_mean_absolute_error: 0.7666254043579102
# Test_r2_score: 0.14281076192855835
#
#
# Generate predictions for 10 samples
# 78074/78074 [==============================] - 60s 772us/step
#    test_y_true  test_y_pred
# 0          4.0   [3.362205]
# 1          4.5   [3.838008]
# 2          2.5  [2.9997141]
# 3          4.5  [3.5724404]
# 4          3.5  [3.9833295]
# 5          3.5   [3.313796]
# 6          3.0   [3.778243]
# 7          3.0  [3.0840256]
# 8          4.0  [4.0356135]
# 9          1.5   [3.343229]

# %%
if wandb_log:
  wandb.finish()
# Out:
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch/epoch</td><td>▁▁▂▂▂▂▃▃▃▄▄▄▅▅▅▅▆▆▆▇▇▇▇██</td></tr><tr><td>epoch/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/loss</td><td>█▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/mean_absolute_error</td><td>█▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/r_square</td><td>▁▆▇▇█████████████████████</td></tr><tr><td>epoch/root_mean_squared_error</td><td>█▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/val_loss</td><td>█▆▃▃▃▂▂▄▂▂▂▄▂▅▂▃▃▂▂▂▃▁▂▃▁</td></tr><tr><td>epoch/val_mean_absolute_error</td><td>▆▅▃▄▃▃▃▄▄▂▂▄▁█▂▅▃▂▂▂▅▁▃▆▃</td></tr><tr><td>epoch/val_r_square</td><td>▁▃▆▆▆▇▇▅▇▇▇▅▇▄▇▆▆▇▇▇▆█▇▆█</td></tr><tr><td>epoch/val_root_mean_squared_error</td><td>█▆▃▃▃▂▂▄▂▂▂▄▂▅▂▃▃▂▂▂▃▁▂▃▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/epoch</td><td>24</td></tr><tr><td>epoch/learning_rate</td><td>0.001</td></tr><tr><td>epoch/loss</td><td>0.98578</td></tr><tr><td>epoch/mean_absolute_error</td><td>0.77383</td></tr><tr><td>epoch/r_square</td><td>0.12345</td></tr><tr><td>epoch/root_mean_squared_error</td><td>0.99286</td></tr><tr><td>epoch/val_loss</td><td>0.9602</td></tr><tr><td>epoch/val_mean_absolute_error</td><td>0.76566</td></tr><tr><td>epoch/val_r_square</td><td>0.14605</td></tr><tr><td>epoch/val_root_mean_squared_error</td><td>0.9799</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">arch5_25m_added_imdb_context_max_abs_scaler_gn</strong> at: <a href='https://wandb.ai/xbarantomik/dp/runs/8lhaoqw4' target="_blank">https://wandb.ai/xbarantomik/dp/runs/8lhaoqw4</a><br/> View project at: <a href='https://wandb.ai/xbarantomik/dp' target="_blank">https://wandb.ai/xbarantomik/dp</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240512_130242-8lhaoqw4/logs</code>
