# %% [markdown]
# ## Experiment 4 - 1m - MovieLens Context model

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import load_model
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json
# Out:
# 2024-05-03 13:25:11.441246: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-03 13:25:11.562068: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-03 13:25:12.059767: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/baran-tomik/bin/miniconda3/envs/tf/lib/
# 2024-05-03 13:25:12.059838: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/baran-tomik/bin/miniconda3/envs/tf/lib/
# 2024-05-03 13:25:12.059845: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
checkpoint_model_filepath = 'checkpoints/'
trained_model_filepath = 'trained_models/'
training_data_path = 'data_1m/'
nn_config_path = '../config/nn_config_exp4.json'
wandb_config_path = '../config/wandb_config.json'

print('Training data path:', training_data_path)

import nn_model
# Out:
# Training data path: data_1m/
# /home/baran-tomik/bin/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# /home/baran-tomik/bin/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.13.0 and strictly below 2.16.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.10.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
try:
  with open(wandb_config_path, 'r') as f:
    wandb_config = json.load(f)

  wandb_log = True
  wandb_run_name = wandb_config["wandb_run_name"]
  wandb_group_name = wandb_config["wandb_group_name"]
  wandb_entity = wandb_config["wandb_entity"]
  wandb_project_name = wandb_config["wandb_project_name"]
  if wandb_config["new_model"] == 'false':
    new_model = False
  else:
    new_model = True
  run_name_before = wandb_config["run_name_before"]   # Model to be loaded
  if wandb_config["eval_only"] == 'false':
    eval_only = False
  else:
    eval_only = True

  print('wandb_log:', wandb_log)
  print('wandb_run_name:', wandb_run_name)
  print('wandb_group_name:', wandb_group_name)
  print('wandb_entity:', wandb_entity)
  print('wandb_project_name:', wandb_project_name)
  print('new_model:', new_model)
  print('run_name_before:', run_name_before)
  print('eval_only:', eval_only)

except OSError as e:
  print('\nERROR loading wandb_config file')
  print(e)
  # quit()
# Out:
# wandb_log: True
# wandb_run_name: arch5_1m_movielens_context_max_abs_scaler_gn_2
# wandb_group_name: 1m_deep_dense
# wandb_entity: xbarantomik
# wandb_project_name: DP
# new_model: True
# run_name_before: -
# eval_only: False

# %%
try:
  with open(nn_config_path, 'r') as f:
    nn_config = json.load(f)

  epochs = int(nn_config['epochs'])
  batch_size = int(nn_config['batch_size'])
  patience = int(nn_config['patience'])
  learning_rate = float(nn_config['learning_rate'])
  architecture = int(nn_config['architecture'])
  training_data_file = nn_config['training_data_file'] + '/'

  print('epochs:', epochs)
  print('batch_size:', batch_size)
  print('patience:', patience)
  print('learning_rate:', learning_rate)
  print('architecture:', architecture)
  print('training_data_file:', training_data_file)

except OSError as e:
  print('\nERROR loading nn_config file')
  print(e)
# Out:
# epochs: 25
# batch_size: 128
# patience: 15
# learning_rate: 0.001
# architecture: 5
# training_data_file: movielens_context_max_abs_scaler/

# %% [markdown]
# #### Load training data

# %%
try:
  train_data = np.load(training_data_path + training_data_file + 'train_data.npy')
  val_data = np.load(training_data_path + training_data_file + 'val_data.npy')
  test_data = np.load(training_data_path + training_data_file + 'test_data.npy')
  train_target_ratings = np.load(training_data_path + training_data_file + 'train_target_ratings.npy')
  val_target_ratings = np.load(training_data_path + training_data_file + 'val_target_ratings.npy')
  test_target_ratings = np.load(training_data_path + training_data_file + 'test_target_ratings.npy')

except OSError as e:
  print('\nERROR loading training data')
  print(e)
  quit()

# %%
if wandb_log:
  import wandb
  from wandb.keras import WandbMetricsLogger, WandbModelCheckpoint

  wandb.login()

  wandb.init(
    config=nn_config,
    entity=wandb_entity,
    project=wandb_project_name,
    name=wandb_run_name,
    group=wandb_group_name
  )
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: xbarantomik. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/home/baran-tomik/projects/DP/training/wandb/run-20240503_132514-ajs0w3fr</code>
# Syncing run <strong><a href='https://wandb.ai/xbarantomik/dp/runs/ajs0w3fr' target="_blank">arch5_1m_movielens_context_max_abs_scaler_gn_2</a></strong> to <a href='https://wandb.ai/xbarantomik/dp' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/xbarantomik/dp' target="_blank">https://wandb.ai/xbarantomik/dp</a>
#  View run at <a href='https://wandb.ai/xbarantomik/dp/runs/ajs0w3fr' target="_blank">https://wandb.ai/xbarantomik/dp/runs/ajs0w3fr</a>

# %% [markdown]
# #### NN MODEL

# %%
early_stopping = EarlyStopping(patience=patience, monitor='val_loss')

# %%
checkpoint_filepath = checkpoint_model_filepath + f"{wandb_run_name}_checkpoint.h5"
checkpoint_callback = ModelCheckpoint(filepath=checkpoint_filepath, monitor='val_loss', save_best_only=True, mode='min', save_weights_only=False, save_format='tf')

if wandb_log:
  callbacks = [early_stopping, checkpoint_callback, WandbMetricsLogger()]
else:
  callbacks = [early_stopping, checkpoint_callback]

# %% [markdown]
# #### Create model

# %%
if new_model:
  my_model = nn_model.create_model(architecture=architecture, lr=learning_rate, train_data_shape=train_data.shape[1])
  print('\nCreated a new model')
else:
  my_model = load_model(checkpoint_model_filepath + run_name_before + '_checkpoint.h5')
  print('\nLoaded a model')

if my_model != None:
  my_model.summary()
else:
  print('\nERROR loading NN model')
  quit()
# Out:
# Model 5
#
# Created a new model
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               15872
#
#  activation (Activation)     (None, 512)               0
#
#  dropout (Dropout)           (None, 512)               0
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  activation_1 (Activation)   (None, 512)               0
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 512)               262656
#
#  activation_2 (Activation)   (None, 512)               0
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 256)               131328
#
#  activation_3 (Activation)   (None, 256)               0
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 256)               65792
#
#  activation_4 (Activation)   (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 738,561
# Trainable params: 738,561
# Non-trainable params: 0
# _________________________________________________________________
# 2024-05-03 13:25:18.744606: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-03 13:25:18.770570: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-03 13:25:18.770740: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-03 13:25:18.771147: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-03 13:25:18.771614: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-03 13:25:18.771744: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-03 13:25:18.771859: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-03 13:25:18.834669: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-03 13:25:18.834850: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-03 13:25:18.834983: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-03 13:25:18.835088: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7511 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1070, pci bus id: 0000:01:00.0, compute capability: 6.1

# %% [markdown]
# ## Model fitting

# %%
if not eval_only:
  print('Training model')
  trained_model = my_model.fit(train_data, train_target_ratings, batch_size, epochs, validation_data=(val_data, val_target_ratings), callbacks=callbacks, verbose=1)
  my_model.save(trained_model_filepath + f"{wandb_run_name}_trained.keras")
else:
  print('Only evaluating model')
# Out:
# Training model
# Epoch 1/25
# 6252/6252 [==============================] - 16s 2ms/step - loss: 1.2192 - root_mean_squared_error: 1.1042 - mean_absolute_error: 0.8972 - r_square: 0.0219 - val_loss: 1.1427 - val_root_mean_squared_error: 1.0690 - val_mean_absolute_error: 0.8661 - val_r_square: 0.0900
# Epoch 2/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.1565 - root_mean_squared_error: 1.0754 - mean_absolute_error: 0.8726 - r_square: 0.0721 - val_loss: 1.1268 - val_root_mean_squared_error: 1.0615 - val_mean_absolute_error: 0.8652 - val_r_square: 0.1027
# Epoch 3/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.1401 - root_mean_squared_error: 1.0677 - mean_absolute_error: 0.8660 - r_square: 0.0853 - val_loss: 1.1132 - val_root_mean_squared_error: 1.0551 - val_mean_absolute_error: 0.8567 - val_r_square: 0.1135
# Epoch 4/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.1290 - root_mean_squared_error: 1.0626 - mean_absolute_error: 0.8614 - r_square: 0.0942 - val_loss: 1.1108 - val_root_mean_squared_error: 1.0539 - val_mean_absolute_error: 0.8516 - val_r_square: 0.1155
# Epoch 5/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.1222 - root_mean_squared_error: 1.0594 - mean_absolute_error: 0.8586 - r_square: 0.0996 - val_loss: 1.1062 - val_root_mean_squared_error: 1.0518 - val_mean_absolute_error: 0.8512 - val_r_square: 0.1191
# Epoch 6/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.1179 - root_mean_squared_error: 1.0573 - mean_absolute_error: 0.8572 - r_square: 0.1031 - val_loss: 1.1021 - val_root_mean_squared_error: 1.0498 - val_mean_absolute_error: 0.8467 - val_r_square: 0.1224
# Epoch 7/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.1123 - root_mean_squared_error: 1.0547 - mean_absolute_error: 0.8547 - r_square: 0.1076 - val_loss: 1.0957 - val_root_mean_squared_error: 1.0467 - val_mean_absolute_error: 0.8470 - val_r_square: 0.1275
# Epoch 8/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.1076 - root_mean_squared_error: 1.0524 - mean_absolute_error: 0.8525 - r_square: 0.1114 - val_loss: 1.0926 - val_root_mean_squared_error: 1.0453 - val_mean_absolute_error: 0.8466 - val_r_square: 0.1299
# Epoch 9/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.1043 - root_mean_squared_error: 1.0508 - mean_absolute_error: 0.8515 - r_square: 0.1141 - val_loss: 1.0931 - val_root_mean_squared_error: 1.0455 - val_mean_absolute_error: 0.8485 - val_r_square: 0.1295
# Epoch 10/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.1010 - root_mean_squared_error: 1.0493 - mean_absolute_error: 0.8495 - r_square: 0.1167 - val_loss: 1.0917 - val_root_mean_squared_error: 1.0448 - val_mean_absolute_error: 0.8478 - val_r_square: 0.1306
# Epoch 11/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0980 - root_mean_squared_error: 1.0479 - mean_absolute_error: 0.8482 - r_square: 0.1191 - val_loss: 1.0888 - val_root_mean_squared_error: 1.0434 - val_mean_absolute_error: 0.8442 - val_r_square: 0.1330
# Epoch 12/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0964 - root_mean_squared_error: 1.0471 - mean_absolute_error: 0.8471 - r_square: 0.1204 - val_loss: 1.0913 - val_root_mean_squared_error: 1.0447 - val_mean_absolute_error: 0.8473 - val_r_square: 0.1309
# Epoch 13/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0953 - root_mean_squared_error: 1.0466 - mean_absolute_error: 0.8461 - r_square: 0.1212 - val_loss: 1.0908 - val_root_mean_squared_error: 1.0444 - val_mean_absolute_error: 0.8380 - val_r_square: 0.1313
# Epoch 14/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0938 - root_mean_squared_error: 1.0459 - mean_absolute_error: 0.8455 - r_square: 0.1224 - val_loss: 1.0880 - val_root_mean_squared_error: 1.0431 - val_mean_absolute_error: 0.8405 - val_r_square: 0.1336
# Epoch 15/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0921 - root_mean_squared_error: 1.0451 - mean_absolute_error: 0.8444 - r_square: 0.1238 - val_loss: 1.0872 - val_root_mean_squared_error: 1.0427 - val_mean_absolute_error: 0.8429 - val_r_square: 0.1342
# Epoch 16/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0910 - root_mean_squared_error: 1.0445 - mean_absolute_error: 0.8445 - r_square: 0.1247 - val_loss: 1.0836 - val_root_mean_squared_error: 1.0410 - val_mean_absolute_error: 0.8412 - val_r_square: 0.1371
# Epoch 17/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0903 - root_mean_squared_error: 1.0442 - mean_absolute_error: 0.8439 - r_square: 0.1252 - val_loss: 1.0818 - val_root_mean_squared_error: 1.0401 - val_mean_absolute_error: 0.8364 - val_r_square: 0.1385
# Epoch 18/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0894 - root_mean_squared_error: 1.0437 - mean_absolute_error: 0.8437 - r_square: 0.1260 - val_loss: 1.0827 - val_root_mean_squared_error: 1.0405 - val_mean_absolute_error: 0.8410 - val_r_square: 0.1378
# Epoch 19/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0878 - root_mean_squared_error: 1.0430 - mean_absolute_error: 0.8427 - r_square: 0.1273 - val_loss: 1.0824 - val_root_mean_squared_error: 1.0404 - val_mean_absolute_error: 0.8361 - val_r_square: 0.1380
# Epoch 20/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0871 - root_mean_squared_error: 1.0426 - mean_absolute_error: 0.8429 - r_square: 0.1279 - val_loss: 1.0778 - val_root_mean_squared_error: 1.0382 - val_mean_absolute_error: 0.8385 - val_r_square: 0.1417
# Epoch 21/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0860 - root_mean_squared_error: 1.0421 - mean_absolute_error: 0.8424 - r_square: 0.1287 - val_loss: 1.0835 - val_root_mean_squared_error: 1.0409 - val_mean_absolute_error: 0.8415 - val_r_square: 0.1372
# Epoch 22/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0862 - root_mean_squared_error: 1.0422 - mean_absolute_error: 0.8424 - r_square: 0.1286 - val_loss: 1.0812 - val_root_mean_squared_error: 1.0398 - val_mean_absolute_error: 0.8398 - val_r_square: 0.1390
# Epoch 23/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0847 - root_mean_squared_error: 1.0415 - mean_absolute_error: 0.8420 - r_square: 0.1298 - val_loss: 1.0782 - val_root_mean_squared_error: 1.0384 - val_mean_absolute_error: 0.8366 - val_r_square: 0.1414
# Epoch 24/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0839 - root_mean_squared_error: 1.0411 - mean_absolute_error: 0.8415 - r_square: 0.1304 - val_loss: 1.0847 - val_root_mean_squared_error: 1.0415 - val_mean_absolute_error: 0.8466 - val_r_square: 0.1362
# Epoch 25/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0827 - root_mean_squared_error: 1.0405 - mean_absolute_error: 0.8410 - r_square: 0.1314 - val_loss: 1.0828 - val_root_mean_squared_error: 1.0406 - val_mean_absolute_error: 0.8381 - val_r_square: 0.1378

# %% [markdown]
# #### After fitting

# %%
metric_name = ['Loss', 'RootMSE', 'MAE', 'R2']
train_metric = ['loss', 'root_mean_squared_error', 'mean_absolute_error', 'r_square']
val_metric = ['val_loss', 'val_root_mean_squared_error', 'val_mean_absolute_error', 'val_r_square']

for i in range(len(metric_name)):

  print(f"\n----------- {metric_name[i]} chart -----------\n")

  # matplotlib chart
  plt.plot(trained_model.history[train_metric[i]], label=f"Train {metric_name[i]}")
  plt.plot(trained_model.history[val_metric[i]], label=f"Val {metric_name[i]}")
  plt.legend()
  plt.show()
# Out:
# ----------- Loss chart -----------
# ----------- RootMSE chart -----------
# ----------- MAE chart -----------
# ----------- R2 chart -----------

# %%
# Validation data values in the last epoch
print("number of epochs:", trained_model.epoch[-1] + 1)
print("val_loss:", trained_model.history['val_loss'][-1])
print("val_root_mean_squared_error:", trained_model.history['val_root_mean_squared_error'][-1])
print("val_mean_absolute_error:", trained_model.history['val_mean_absolute_error'][-1])
print("val_r2_score:", trained_model.history['val_r_square'][-1])
# Out:
# number of epochs: 25
# val_loss: 1.0827518701553345
# val_root_mean_squared_error: 1.0405535697937012
# val_mean_absolute_error: 0.8380976915359497
# val_r2_score: 0.13776999711990356

# %%
# Evaluate the model on the test data
print("Evaluate on test data")
test_loss, test_mean_squared_error, test_mean_absolute_error, test_r2_score = my_model.evaluate(test_data, test_target_ratings)
print("Test_loss:", test_loss)
print("Test_root_mean_squared_error:", test_mean_squared_error)
print("Test_mean_absolute_error:", test_mean_absolute_error)
print("Test_r2_score:", test_r2_score)
print('\n')

print("Generate predictions for 10 samples")
predictions = my_model.predict(test_data)
test_y_comparison = pd.DataFrame({'test_y_true': test_target_ratings, 'test_y_pred': [x for x in predictions]})

print(test_y_comparison.head(10))
# Out:
# Evaluate on test data
# 3126/3126 [==============================] - 4s 1ms/step - loss: 1.0851 - root_mean_squared_error: 1.0417 - mean_absolute_error: 0.8396 - r_square: 0.1332
# Test_loss: 1.0850639343261719
# Test_root_mean_squared_error: 1.0416640043258667
# Test_mean_absolute_error: 0.8396384119987488
# Test_r2_score: 0.13321495056152344
#
#
# Generate predictions for 10 samples
# 3126/3126 [==============================] - 2s 768us/step
#    test_y_true  test_y_pred
# 0            4    [3.71202]
# 1            3  [2.9986966]
# 2            5   [3.873549]
# 3            5    [4.08083]
# 4            4  [3.9357443]
# 5            4  [3.7851467]
# 6            4  [4.2342796]
# 7            3  [3.8511796]
# 8            1  [3.3551173]
# 9            5  [3.9376285]

# %%
if wandb_log:
  wandb.finish()
# Out:
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch/epoch</td><td>▁▁▂▂▂▂▃▃▃▄▄▄▅▅▅▅▆▆▆▇▇▇▇██</td></tr><tr><td>epoch/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/loss</td><td>█▅▄▃▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/mean_absolute_error</td><td>█▅▄▄▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/r_square</td><td>▁▄▅▆▆▆▆▇▇▇▇▇▇▇███████████</td></tr><tr><td>epoch/root_mean_squared_error</td><td>█▅▄▃▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/val_loss</td><td>█▆▅▅▄▄▃▃▃▃▂▂▂▂▂▂▁▂▂▁▂▁▁▂▂</td></tr><tr><td>epoch/val_mean_absolute_error</td><td>██▆▅▅▃▄▃▄▄▃▄▁▂▃▂▁▂▁▂▂▂▁▃▁</td></tr><tr><td>epoch/val_r_square</td><td>▁▃▄▄▅▅▆▆▆▆▇▇▇▇▇▇█▇▇█▇██▇▇</td></tr><tr><td>epoch/val_root_mean_squared_error</td><td>█▆▅▅▄▄▃▃▃▃▂▂▂▂▂▂▁▂▂▁▂▁▁▂▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/epoch</td><td>24</td></tr><tr><td>epoch/learning_rate</td><td>0.001</td></tr><tr><td>epoch/loss</td><td>1.08268</td></tr><tr><td>epoch/mean_absolute_error</td><td>0.84102</td></tr><tr><td>epoch/r_square</td><td>0.13138</td></tr><tr><td>epoch/root_mean_squared_error</td><td>1.04052</td></tr><tr><td>epoch/val_loss</td><td>1.08275</td></tr><tr><td>epoch/val_mean_absolute_error</td><td>0.8381</td></tr><tr><td>epoch/val_r_square</td><td>0.13777</td></tr><tr><td>epoch/val_root_mean_squared_error</td><td>1.04055</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">arch5_1m_movielens_context_max_abs_scaler_gn_2</strong> at: <a href='https://wandb.ai/xbarantomik/dp/runs/ajs0w3fr' target="_blank">https://wandb.ai/xbarantomik/dp/runs/ajs0w3fr</a><br/> View project at: <a href='https://wandb.ai/xbarantomik/dp' target="_blank">https://wandb.ai/xbarantomik/dp</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240503_132514-ajs0w3fr/logs</code>
