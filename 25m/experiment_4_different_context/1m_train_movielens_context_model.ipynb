# %% [markdown]
# ## Experiment 4 - 1m - MovieLens Context model

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import load_model
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json

# %%
checkpoint_model_filepath = 'checkpoints/'
trained_model_filepath = 'trained_models/'
training_data_path = 'data_1m/'
nn_config_path = '../config/nn_config.json'
wandb_config_path = '../config/wandb_config.json'

print('Training data path:', training_data_path)

import nn_model
# Out:
# Training data path: data_1m/

# %%
try:
  with open(wandb_config_path, 'r') as f:
    wandb_config = json.load(f)

  wandb_log = True
  wandb_run_name = wandb_config["wandb_run_name"]
  wandb_group_name = wandb_config["wandb_group_name"]
  wandb_entity = wandb_config["wandb_entity"]
  wandb_project_name = wandb_config["wandb_project_name"]
  if wandb_config["new_model"] == 'false':
    new_model = False
  else:
    new_model = True
  run_name_before = wandb_config["run_name_before"]   # Model to be loaded
  if wandb_config["eval_only"] == 'false':
    eval_only = False
  else:
    eval_only = True

  print('wandb_log:', wandb_log)
  print('wandb_run_name:', wandb_run_name)
  print('wandb_group_name:', wandb_group_name)
  print('wandb_entity:', wandb_entity)
  print('wandb_project_name:', wandb_project_name)
  print('new_model:', new_model)
  print('run_name_before:', run_name_before)
  print('eval_only:', eval_only)

except OSError as e:
  print('\nERROR loading wandb_config file')
  print(e)
  # quit()
# Out:
# wandb_log: True
# wandb_run_name: arch5_1m_movielens_context_max_abs_scaler_gn
# wandb_group_name: 1m_deep_dense
# wandb_entity: xbarantomik
# wandb_project_name: DP
# new_model: True
# run_name_before: -
# eval_only: False

# %%
try:
  with open(nn_config_path, 'r') as f:
    nn_config = json.load(f)

  epochs = int(nn_config['epochs'])
  batch_size = int(nn_config['batch_size'])
  patience = int(nn_config['patience'])
  learning_rate = float(nn_config['learning_rate'])
  architecture = int(nn_config['architecture'])
  training_data_file = nn_config['training_data_file'] + '/'

  print('epochs:', epochs)
  print('batch_size:', batch_size)
  print('patience:', patience)
  print('learning_rate:', learning_rate)
  print('architecture:', architecture)
  print('training_data_file:', training_data_file)

except OSError as e:
  print('\nERROR loading nn_config file')
  print(e)
# Out:
# epochs: 25
# batch_size: 128
# patience: 15
# learning_rate: 0.001
# architecture: 5
# training_data_file: movielens_context_max_abs_scaler/

# %% [markdown]
# #### Load training data

# %%
try:
  train_data = np.load(training_data_path + training_data_file + 'train_data.npy')
  val_data = np.load(training_data_path + training_data_file + 'val_data.npy')
  test_data = np.load(training_data_path + training_data_file + 'test_data.npy')
  train_target_ratings = np.load(training_data_path + training_data_file + 'train_target_ratings.npy')
  val_target_ratings = np.load(training_data_path + training_data_file + 'val_target_ratings.npy')
  test_target_ratings = np.load(training_data_path + training_data_file + 'test_target_ratings.npy')

except OSError as e:
  print('\nERROR loading training data')
  print(e)
  quit()

# %%
if wandb_log:
  import wandb
  from wandb.keras import WandbMetricsLogger, WandbModelCheckpoint

  wandb.login()

  wandb.init(
    config=nn_config,
    entity=wandb_entity,
    project=wandb_project_name,
    name=wandb_run_name,
    group=wandb_group_name
  )
# Out:
# wandb version 0.17.0 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/home/baran-tomik/projects/DP/training/wandb/run-20240511_190309-m95d4jz6</code>
# Syncing run <strong><a href='https://wandb.ai/xbarantomik/dp/runs/m95d4jz6' target="_blank">arch5_1m_movielens_context_max_abs_scaler_gn</a></strong> to <a href='https://wandb.ai/xbarantomik/dp' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/xbarantomik/dp' target="_blank">https://wandb.ai/xbarantomik/dp</a>
#  View run at <a href='https://wandb.ai/xbarantomik/dp/runs/m95d4jz6' target="_blank">https://wandb.ai/xbarantomik/dp/runs/m95d4jz6</a>

# %% [markdown]
# #### NN MODEL

# %%
early_stopping = EarlyStopping(patience=patience, monitor='val_loss')

# %%
checkpoint_filepath = checkpoint_model_filepath + f"{wandb_run_name}_checkpoint.h5"
checkpoint_callback = ModelCheckpoint(filepath=checkpoint_filepath, monitor='val_loss', save_best_only=True, mode='min', save_weights_only=False, save_format='tf')

if wandb_log:
  callbacks = [early_stopping, checkpoint_callback, WandbMetricsLogger()]
else:
  callbacks = [early_stopping, checkpoint_callback]

# %% [markdown]
# #### Create model

# %%
if new_model:
  my_model = nn_model.create_model(architecture=architecture, lr=learning_rate, train_data_shape=train_data.shape[1])
  print('\nCreated a new model')
else:
  my_model = load_model(checkpoint_model_filepath + run_name_before + '_checkpoint.h5')
  print('\nLoaded a model')

if my_model != None:
  my_model.summary()
else:
  print('\nERROR loading NN model')
  quit()
# Out:
# Model 5
#
# Created a new model
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_18 (Dense)            (None, 512)               15872
#
#  activation_15 (Activation)  (None, 512)               0
#
#  dropout_15 (Dropout)        (None, 512)               0
#
#  flatten_3 (Flatten)         (None, 512)               0
#
#  dense_19 (Dense)            (None, 512)               262656
#
#  activation_16 (Activation)  (None, 512)               0
#
#  dropout_16 (Dropout)        (None, 512)               0
#
#  dense_20 (Dense)            (None, 512)               262656
#
#  activation_17 (Activation)  (None, 512)               0
#
#  dropout_17 (Dropout)        (None, 512)               0
#
#  dense_21 (Dense)            (None, 256)               131328
#
#  activation_18 (Activation)  (None, 256)               0
#
#  dropout_18 (Dropout)        (None, 256)               0
#
#  dense_22 (Dense)            (None, 256)               65792
#
#  activation_19 (Activation)  (None, 256)               0
#
#  dropout_19 (Dropout)        (None, 256)               0
#
#  dense_23 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 738,561
# Trainable params: 738,561
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Model fitting

# %%
if not eval_only:
  print('Training model')
  trained_model = my_model.fit(train_data, train_target_ratings, batch_size, epochs, validation_data=(val_data, val_target_ratings), callbacks=callbacks, verbose=1)
  my_model.save(trained_model_filepath + f"{wandb_run_name}_trained.keras")
else:
  print('Only evaluating model')
# Out:
# Training model
# Epoch 1/25
# 6252/6252 [==============================] - 16s 2ms/step - loss: 1.2220 - root_mean_squared_error: 1.1054 - mean_absolute_error: 0.8984 - r_square: 0.0196 - val_loss: 1.1594 - val_root_mean_squared_error: 1.0768 - val_mean_absolute_error: 0.8743 - val_r_square: 0.0767
# Epoch 2/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.1576 - root_mean_squared_error: 1.0759 - mean_absolute_error: 0.8734 - r_square: 0.0713 - val_loss: 1.1292 - val_root_mean_squared_error: 1.0626 - val_mean_absolute_error: 0.8714 - val_r_square: 0.1008
# Epoch 3/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.1413 - root_mean_squared_error: 1.0683 - mean_absolute_error: 0.8663 - r_square: 0.0844 - val_loss: 1.1242 - val_root_mean_squared_error: 1.0603 - val_mean_absolute_error: 0.8727 - val_r_square: 0.1048
# Epoch 4/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.1296 - root_mean_squared_error: 1.0628 - mean_absolute_error: 0.8613 - r_square: 0.0938 - val_loss: 1.1108 - val_root_mean_squared_error: 1.0539 - val_mean_absolute_error: 0.8636 - val_r_square: 0.1154
# Epoch 5/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.1226 - root_mean_squared_error: 1.0595 - mean_absolute_error: 0.8582 - r_square: 0.0993 - val_loss: 1.1059 - val_root_mean_squared_error: 1.0516 - val_mean_absolute_error: 0.8519 - val_r_square: 0.1194
# Epoch 6/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.1165 - root_mean_squared_error: 1.0566 - mean_absolute_error: 0.8560 - r_square: 0.1043 - val_loss: 1.0987 - val_root_mean_squared_error: 1.0482 - val_mean_absolute_error: 0.8495 - val_r_square: 0.1251
# Epoch 7/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.1115 - root_mean_squared_error: 1.0543 - mean_absolute_error: 0.8543 - r_square: 0.1083 - val_loss: 1.0979 - val_root_mean_squared_error: 1.0478 - val_mean_absolute_error: 0.8553 - val_r_square: 0.1257
# Epoch 8/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.1077 - root_mean_squared_error: 1.0525 - mean_absolute_error: 0.8529 - r_square: 0.1113 - val_loss: 1.0937 - val_root_mean_squared_error: 1.0458 - val_mean_absolute_error: 0.8468 - val_r_square: 0.1291
# Epoch 9/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.1035 - root_mean_squared_error: 1.0505 - mean_absolute_error: 0.8509 - r_square: 0.1147 - val_loss: 1.0913 - val_root_mean_squared_error: 1.0447 - val_mean_absolute_error: 0.8433 - val_r_square: 0.1309
# Epoch 10/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.1008 - root_mean_squared_error: 1.0492 - mean_absolute_error: 0.8495 - r_square: 0.1168 - val_loss: 1.0924 - val_root_mean_squared_error: 1.0452 - val_mean_absolute_error: 0.8399 - val_r_square: 0.1301
# Epoch 11/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0990 - root_mean_squared_error: 1.0483 - mean_absolute_error: 0.8485 - r_square: 0.1183 - val_loss: 1.0944 - val_root_mean_squared_error: 1.0461 - val_mean_absolute_error: 0.8515 - val_r_square: 0.1285
# Epoch 12/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0974 - root_mean_squared_error: 1.0476 - mean_absolute_error: 0.8472 - r_square: 0.1195 - val_loss: 1.1007 - val_root_mean_squared_error: 1.0491 - val_mean_absolute_error: 0.8575 - val_r_square: 0.1235
# Epoch 13/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0957 - root_mean_squared_error: 1.0467 - mean_absolute_error: 0.8460 - r_square: 0.1210 - val_loss: 1.0859 - val_root_mean_squared_error: 1.0421 - val_mean_absolute_error: 0.8442 - val_r_square: 0.1353
# Epoch 14/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0947 - root_mean_squared_error: 1.0463 - mean_absolute_error: 0.8456 - r_square: 0.1218 - val_loss: 1.0860 - val_root_mean_squared_error: 1.0421 - val_mean_absolute_error: 0.8429 - val_r_square: 0.1352
# Epoch 15/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0934 - root_mean_squared_error: 1.0456 - mean_absolute_error: 0.8450 - r_square: 0.1228 - val_loss: 1.0860 - val_root_mean_squared_error: 1.0421 - val_mean_absolute_error: 0.8414 - val_r_square: 0.1352
# Epoch 16/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0923 - root_mean_squared_error: 1.0451 - mean_absolute_error: 0.8446 - r_square: 0.1236 - val_loss: 1.0879 - val_root_mean_squared_error: 1.0430 - val_mean_absolute_error: 0.8477 - val_r_square: 0.1337
# Epoch 17/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0911 - root_mean_squared_error: 1.0446 - mean_absolute_error: 0.8441 - r_square: 0.1246 - val_loss: 1.0847 - val_root_mean_squared_error: 1.0415 - val_mean_absolute_error: 0.8366 - val_r_square: 0.1362
# Epoch 18/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0899 - root_mean_squared_error: 1.0440 - mean_absolute_error: 0.8435 - r_square: 0.1256 - val_loss: 1.0854 - val_root_mean_squared_error: 1.0418 - val_mean_absolute_error: 0.8435 - val_r_square: 0.1356
# Epoch 19/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0882 - root_mean_squared_error: 1.0431 - mean_absolute_error: 0.8430 - r_square: 0.1270 - val_loss: 1.0814 - val_root_mean_squared_error: 1.0399 - val_mean_absolute_error: 0.8416 - val_r_square: 0.1388
# Epoch 20/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0879 - root_mean_squared_error: 1.0430 - mean_absolute_error: 0.8430 - r_square: 0.1272 - val_loss: 1.0866 - val_root_mean_squared_error: 1.0424 - val_mean_absolute_error: 0.8455 - val_r_square: 0.1347
# Epoch 21/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0871 - root_mean_squared_error: 1.0426 - mean_absolute_error: 0.8428 - r_square: 0.1279 - val_loss: 1.0775 - val_root_mean_squared_error: 1.0380 - val_mean_absolute_error: 0.8398 - val_r_square: 0.1420
# Epoch 22/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0858 - root_mean_squared_error: 1.0420 - mean_absolute_error: 0.8418 - r_square: 0.1289 - val_loss: 1.0777 - val_root_mean_squared_error: 1.0381 - val_mean_absolute_error: 0.8397 - val_r_square: 0.1418
# Epoch 23/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0856 - root_mean_squared_error: 1.0419 - mean_absolute_error: 0.8420 - r_square: 0.1290 - val_loss: 1.0832 - val_root_mean_squared_error: 1.0408 - val_mean_absolute_error: 0.8435 - val_r_square: 0.1374
# Epoch 24/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0841 - root_mean_squared_error: 1.0412 - mean_absolute_error: 0.8413 - r_square: 0.1302 - val_loss: 1.0735 - val_root_mean_squared_error: 1.0361 - val_mean_absolute_error: 0.8377 - val_r_square: 0.1451
# Epoch 25/25
# 6252/6252 [==============================] - 15s 2ms/step - loss: 1.0838 - root_mean_squared_error: 1.0410 - mean_absolute_error: 0.8411 - r_square: 0.1305 - val_loss: 1.0861 - val_root_mean_squared_error: 1.0421 - val_mean_absolute_error: 0.8466 - val_r_square: 0.1351

# %% [markdown]
# #### After fitting

# %%
metric_name = ['Loss', 'RootMSE', 'MAE', 'R2']
train_metric = ['loss', 'root_mean_squared_error', 'mean_absolute_error', 'r_square']
val_metric = ['val_loss', 'val_root_mean_squared_error', 'val_mean_absolute_error', 'val_r_square']

for i in range(len(metric_name)):

  print(f"\n----------- {metric_name[i]} chart -----------\n")

  # matplotlib chart
  plt.plot(trained_model.history[train_metric[i]], label=f"Train {metric_name[i]}")
  plt.plot(trained_model.history[val_metric[i]], label=f"Val {metric_name[i]}")
  plt.legend()
  plt.show()
# Out:
# ----------- Loss chart -----------
# ----------- RootMSE chart -----------
# ----------- MAE chart -----------
# ----------- R2 chart -----------

# %%
# Validation data values in the last epoch
print("number of epochs:", trained_model.epoch[-1] + 1)
print("val_loss:", trained_model.history['val_loss'][-1])
print("val_root_mean_squared_error:", trained_model.history['val_root_mean_squared_error'][-1])
print("val_mean_absolute_error:", trained_model.history['val_mean_absolute_error'][-1])
print("val_r2_score:", trained_model.history['val_r_square'][-1])
# Out:
# number of epochs: 25
# val_loss: 1.0860519409179688
# val_root_mean_squared_error: 1.0421380996704102
# val_mean_absolute_error: 0.8466249704360962
# val_r2_score: 0.1351420283317566

# %%
# Evaluate the model on the test data
print("Evaluate on test data")
test_loss, test_mean_squared_error, test_mean_absolute_error, test_r2_score = my_model.evaluate(test_data, test_target_ratings)
print("Test_loss:", test_loss)
print("Test_root_mean_squared_error:", test_mean_squared_error)
print("Test_mean_absolute_error:", test_mean_absolute_error)
print("Test_r2_score:", test_r2_score)
print('\n')

print("Generate predictions for 10 samples")
predictions = my_model.predict(test_data)
test_y_comparison = pd.DataFrame({'test_y_true': test_target_ratings, 'test_y_pred': [x for x in predictions]})

print(test_y_comparison.head(10))
# Out:
# Evaluate on test data
# 3126/3126 [==============================] - 4s 1ms/step - loss: 1.0877 - root_mean_squared_error: 1.0429 - mean_absolute_error: 0.8480 - r_square: 0.1311
# Test_loss: 1.087689757347107
# Test_root_mean_squared_error: 1.0429236888885498
# Test_mean_absolute_error: 0.8479633331298828
# Test_r2_score: 0.13111740350723267
#
#
# Generate predictions for 10 samples
# 3126/3126 [==============================] - 2s 754us/step
#    test_y_true  test_y_pred
# 0            4   [3.716761]
# 1            3   [3.051689]
# 2            5  [3.7635086]
# 3            5  [3.9659224]
# 4            4  [3.9003944]
# 5            4  [3.7277133]
# 6            4  [4.0859323]
# 7            3   [3.950295]
# 8            1  [3.2888803]
# 9            5  [3.8992777]

# %%
if wandb_log:
  wandb.finish()
# Out:
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch/epoch</td><td>▁▁▂▂▂▂▃▃▃▄▄▄▅▅▅▅▆▆▆▇▇▇▇██</td></tr><tr><td>epoch/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/loss</td><td>█▅▄▃▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/mean_absolute_error</td><td>█▅▄▃▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/r_square</td><td>▁▄▅▆▆▆▇▇▇▇▇▇▇▇███████████</td></tr><tr><td>epoch/root_mean_squared_error</td><td>█▅▄▃▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/val_loss</td><td>█▆▅▄▄▃▃▃▂▃▃▃▂▂▂▂▂▂▂▂▁▁▂▁▂</td></tr><tr><td>epoch/val_mean_absolute_error</td><td>█▇█▆▄▃▄▃▂▂▄▅▂▂▂▃▁▂▂▃▂▂▂▁▃</td></tr><tr><td>epoch/val_r_square</td><td>▁▃▄▅▅▆▆▆▇▆▆▆▇▇▇▇▇▇▇▇██▇█▇</td></tr><tr><td>epoch/val_root_mean_squared_error</td><td>█▆▅▄▄▃▃▃▂▃▃▃▂▂▂▂▂▂▂▂▁▁▂▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/epoch</td><td>24</td></tr><tr><td>epoch/learning_rate</td><td>0.001</td></tr><tr><td>epoch/loss</td><td>1.08378</td></tr><tr><td>epoch/mean_absolute_error</td><td>0.84105</td></tr><tr><td>epoch/r_square</td><td>0.1305</td></tr><tr><td>epoch/root_mean_squared_error</td><td>1.04105</td></tr><tr><td>epoch/val_loss</td><td>1.08605</td></tr><tr><td>epoch/val_mean_absolute_error</td><td>0.84662</td></tr><tr><td>epoch/val_r_square</td><td>0.13514</td></tr><tr><td>epoch/val_root_mean_squared_error</td><td>1.04214</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">arch5_1m_movielens_context_max_abs_scaler_gn</strong> at: <a href='https://wandb.ai/xbarantomik/dp/runs/m95d4jz6' target="_blank">https://wandb.ai/xbarantomik/dp/runs/m95d4jz6</a><br/> View project at: <a href='https://wandb.ai/xbarantomik/dp' target="_blank">https://wandb.ai/xbarantomik/dp</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240511_190309-m95d4jz6/logs</code>
