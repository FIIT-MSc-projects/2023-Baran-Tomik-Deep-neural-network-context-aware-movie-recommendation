# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import load_model
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json
# Out:
# 2024-05-03 13:10:01.716531: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-03 13:10:01.834563: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-03 13:10:02.333433: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/baran-tomik/bin/miniconda3/envs/tf/lib/
# 2024-05-03 13:10:02.333532: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/baran-tomik/bin/miniconda3/envs/tf/lib/
# 2024-05-03 13:10:02.333539: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
checkpoint_model_filepath = 'checkpoints/'
trained_model_filepath = 'trained_models/'
training_data_path = 'data_25m/'
nn_config_path = '../config/nn_config.json'
wandb_config_path = '../config/wandb_config.json'

print('Training data path:', training_data_path)

import nn_model
# Out:
# Training data path: data_25m/
# /home/baran-tomik/bin/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# /home/baran-tomik/bin/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.13.0 and strictly below 2.16.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.10.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
try:
  with open(wandb_config_path, 'r') as f:
    wandb_config = json.load(f)

  wandb_log = True
  wandb_run_name = wandb_config["wandb_run_name"]
  wandb_group_name = wandb_config["wandb_group_name"]
  wandb_entity = wandb_config["wandb_entity"]
  wandb_project_name = wandb_config["wandb_project_name"]
  if wandb_config["new_model"] == 'false':
    new_model = False
  else:
    new_model = True
  run_name_before = wandb_config["run_name_before"]   # Model to be loaded
  if wandb_config["eval_only"] == 'false':
    eval_only = False
  else:
    eval_only = True

  print('wandb_log:', wandb_log)
  print('wandb_run_name:', wandb_run_name)
  print('wandb_group_name:', wandb_group_name)
  print('wandb_entity:', wandb_entity)
  print('wandb_project_name:', wandb_project_name)
  print('new_model:', new_model)
  print('run_name_before:', run_name_before)
  print('eval_only:', eval_only)

except OSError as e:
  print('\nERROR loading wandb_config file')
  print(e)
  # quit()
# Out:
# wandb_log: True
# wandb_run_name: arch10_25m_profile_3_gn
# wandb_group_name: 25m_deep_dense
# wandb_entity: xbarantomik
# wandb_project_name: DP
# new_model: True
# run_name_before: -
# eval_only: False

# %%
try:
  with open(nn_config_path, 'r') as f:
    nn_config = json.load(f)

  epochs = int(nn_config['epochs'])
  batch_size = int(nn_config['batch_size'])
  patience = int(nn_config['patience'])
  learning_rate = float(nn_config['learning_rate'])
  architecture = int(nn_config['architecture'])
  training_data_file = nn_config['training_data_file'] + '/'

  print('epochs:', epochs)
  print('batch_size:', batch_size)
  print('patience:', patience)
  print('learning_rate:', learning_rate)
  print('architecture:', architecture)
  print('training_data_file:', training_data_file)

except OSError as e:
  print('\nERROR loading nn_config file')
  print(e)
# Out:
# epochs: 40
# batch_size: 64
# patience: 8
# learning_rate: 0.02609
# architecture: 10
# training_data_file: profile_3/

# %% [markdown]
# #### Load training data

# %%
try:
  train_data = np.load(training_data_path + training_data_file + 'train_data.npy')
  val_data = np.load(training_data_path + training_data_file + 'val_data.npy')
  test_data = np.load(training_data_path + training_data_file + 'test_data.npy')
  train_target_ratings = np.load(training_data_path + training_data_file + 'train_target_ratings.npy')
  val_target_ratings = np.load(training_data_path + training_data_file + 'val_target_ratings.npy')
  test_target_ratings = np.load(training_data_path + training_data_file + 'test_target_ratings.npy')

except OSError as e:
  print('\nERROR loading training data')
  print(e)
  quit()

# %%
if wandb_log:
  import wandb
  from wandb.keras import WandbMetricsLogger, WandbModelCheckpoint

  wandb.login()

  wandb.init(
    config=nn_config,
    entity=wandb_entity,
    project=wandb_project_name,
    name=wandb_run_name,
    group=wandb_group_name
  )
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: xbarantomik. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/home/baran-tomik/projects/DP/training/wandb/run-20240503_131004-fhg14veb</code>
# Syncing run <strong><a href='https://wandb.ai/xbarantomik/dp/runs/fhg14veb' target="_blank">arch10_25m_profile_3_gn</a></strong> to <a href='https://wandb.ai/xbarantomik/dp' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/xbarantomik/dp' target="_blank">https://wandb.ai/xbarantomik/dp</a>
#  View run at <a href='https://wandb.ai/xbarantomik/dp/runs/fhg14veb' target="_blank">https://wandb.ai/xbarantomik/dp/runs/fhg14veb</a>

# %% [markdown]
# #### NN MODEL

# %%
early_stopping = EarlyStopping(patience=patience, monitor='val_loss')

# %%
checkpoint_filepath = checkpoint_model_filepath + f"{wandb_run_name}_checkpoint.h5"
checkpoint_callback = ModelCheckpoint(filepath=checkpoint_filepath, monitor='val_loss', save_best_only=True, mode='min', save_weights_only=False, save_format='tf')

if wandb_log:
  callbacks = [early_stopping, checkpoint_callback, WandbMetricsLogger()]
else:
  callbacks = [early_stopping, checkpoint_callback]

# %% [markdown]
# #### Create model

# %%
if new_model:
  my_model = nn_model.create_model(architecture=architecture, lr=learning_rate, train_data_shape=train_data.shape[1])
  print('\nCreated a new model')
else:
  my_model = load_model(checkpoint_model_filepath + run_name_before + '_checkpoint.h5')
  print('\nLoaded a model')

if my_model != None:
  my_model.summary()
else:
  print('\nERROR loading NN model')
  quit()
# Out:
# Model 10
#
# Created a new model
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               21504
#
#  activation (Activation)     (None, 512)               0
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 128)               65664
#
#  activation_1 (Activation)   (None, 128)               0
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_2 (Dense)             (None, 256)               33024
#
#  activation_2 (Activation)   (None, 256)               0
#
#  dense_3 (Dense)             (None, 512)               131584
#
#  activation_3 (Activation)   (None, 512)               0
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_4 (Dense)             (None, 128)               65664
#
#  activation_4 (Activation)   (None, 128)               0
#
#  dense_5 (Dense)             (None, 1)                 129
#
#  activation_5 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 317,569
# Trainable params: 317,569
# Non-trainable params: 0
# _________________________________________________________________
# 2024-05-03 13:10:08.962734: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-03 13:10:08.994674: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-03 13:10:08.994842: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-03 13:10:08.995222: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-03 13:10:08.995715: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-03 13:10:08.995849: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-03 13:10:08.995960: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-03 13:10:09.046477: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-03 13:10:09.046652: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-03 13:10:09.046769: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-03 13:10:09.046865: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7511 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1070, pci bus id: 0000:01:00.0, compute capability: 6.1

# %% [markdown]
# ## Model fitting

# %%
if not eval_only:
  print('Training model')
  trained_model = my_model.fit(train_data, train_target_ratings, batch_size, epochs, validation_data=(val_data, val_target_ratings), callbacks=callbacks, verbose=1)
  my_model.save(trained_model_filepath + f"{wandb_run_name}_trained.keras")
else:
  print('Only evaluating model')
# Out:
# Training model
# Epoch 1/40
# 55/55 [==============================] - 1s 6ms/step - loss: 1.6948 - root_mean_squared_error: 1.3018 - mean_absolute_error: 0.9588 - r_square: -1.7524 - val_loss: 0.6061 - val_root_mean_squared_error: 0.7785 - val_mean_absolute_error: 0.6118 - val_r_square: -0.0589
# Epoch 2/40
# 55/55 [==============================] - 0s 3ms/step - loss: 0.6515 - root_mean_squared_error: 0.8072 - mean_absolute_error: 0.6352 - r_square: -0.0581 - val_loss: 0.5611 - val_root_mean_squared_error: 0.7491 - val_mean_absolute_error: 0.5903 - val_r_square: 0.0197
# Epoch 3/40
# 55/55 [==============================] - 0s 2ms/step - loss: 0.6150 - root_mean_squared_error: 0.7842 - mean_absolute_error: 0.6167 - r_square: 0.0012 - val_loss: 0.5784 - val_root_mean_squared_error: 0.7605 - val_mean_absolute_error: 0.5962 - val_r_square: -0.0105
# Epoch 4/40
# 55/55 [==============================] - 0s 2ms/step - loss: 0.6007 - root_mean_squared_error: 0.7751 - mean_absolute_error: 0.6080 - r_square: 0.0244 - val_loss: 0.5840 - val_root_mean_squared_error: 0.7642 - val_mean_absolute_error: 0.6097 - val_r_square: -0.0203
# Epoch 5/40
# 55/55 [==============================] - 0s 3ms/step - loss: 0.5995 - root_mean_squared_error: 0.7743 - mean_absolute_error: 0.6085 - r_square: 0.0264 - val_loss: 0.5483 - val_root_mean_squared_error: 0.7405 - val_mean_absolute_error: 0.5817 - val_r_square: 0.0422
# Epoch 6/40
# 55/55 [==============================] - 0s 3ms/step - loss: 0.5826 - root_mean_squared_error: 0.7633 - mean_absolute_error: 0.6020 - r_square: 0.0539 - val_loss: 0.5327 - val_root_mean_squared_error: 0.7298 - val_mean_absolute_error: 0.5768 - val_r_square: 0.0695
# Epoch 7/40
# 55/55 [==============================] - 0s 3ms/step - loss: 0.5868 - root_mean_squared_error: 0.7660 - mean_absolute_error: 0.5995 - r_square: 0.0470 - val_loss: 0.5304 - val_root_mean_squared_error: 0.7283 - val_mean_absolute_error: 0.5742 - val_r_square: 0.0733
# Epoch 8/40
# 55/55 [==============================] - 0s 3ms/step - loss: 0.5793 - root_mean_squared_error: 0.7611 - mean_absolute_error: 0.5989 - r_square: 0.0592 - val_loss: 0.5273 - val_root_mean_squared_error: 0.7262 - val_mean_absolute_error: 0.5748 - val_r_square: 0.0787
# Epoch 9/40
# 55/55 [==============================] - 0s 2ms/step - loss: 0.5733 - root_mean_squared_error: 0.7571 - mean_absolute_error: 0.5959 - r_square: 0.0690 - val_loss: 0.5284 - val_root_mean_squared_error: 0.7269 - val_mean_absolute_error: 0.5727 - val_r_square: 0.0769
# Epoch 10/40
# 55/55 [==============================] - 0s 2ms/step - loss: 0.5739 - root_mean_squared_error: 0.7576 - mean_absolute_error: 0.5946 - r_square: 0.0680 - val_loss: 0.5846 - val_root_mean_squared_error: 0.7646 - val_mean_absolute_error: 0.5987 - val_r_square: -0.0213
# Epoch 11/40
# 55/55 [==============================] - 0s 2ms/step - loss: 0.5659 - root_mean_squared_error: 0.7523 - mean_absolute_error: 0.5888 - r_square: 0.0810 - val_loss: 0.5295 - val_root_mean_squared_error: 0.7277 - val_mean_absolute_error: 0.5726 - val_r_square: 0.0750
# Epoch 12/40
# 55/55 [==============================] - 0s 3ms/step - loss: 0.5639 - root_mean_squared_error: 0.7509 - mean_absolute_error: 0.5881 - r_square: 0.0842 - val_loss: 0.5266 - val_root_mean_squared_error: 0.7257 - val_mean_absolute_error: 0.5751 - val_r_square: 0.0800
# Epoch 13/40
# 55/55 [==============================] - 0s 2ms/step - loss: 0.5585 - root_mean_squared_error: 0.7474 - mean_absolute_error: 0.5879 - r_square: 0.0929 - val_loss: 0.5889 - val_root_mean_squared_error: 0.7674 - val_mean_absolute_error: 0.6011 - val_r_square: -0.0287
# Epoch 14/40
# 55/55 [==============================] - 0s 3ms/step - loss: 0.5603 - root_mean_squared_error: 0.7486 - mean_absolute_error: 0.5887 - r_square: 0.0900 - val_loss: 0.5235 - val_root_mean_squared_error: 0.7235 - val_mean_absolute_error: 0.5727 - val_r_square: 0.0855
# Epoch 15/40
# 55/55 [==============================] - 0s 2ms/step - loss: 0.5547 - root_mean_squared_error: 0.7448 - mean_absolute_error: 0.5869 - r_square: 0.0991 - val_loss: 0.5264 - val_root_mean_squared_error: 0.7256 - val_mean_absolute_error: 0.5753 - val_r_square: 0.0803
# Epoch 16/40
# 55/55 [==============================] - 0s 2ms/step - loss: 0.5610 - root_mean_squared_error: 0.7490 - mean_absolute_error: 0.5909 - r_square: 0.0890 - val_loss: 0.5248 - val_root_mean_squared_error: 0.7244 - val_mean_absolute_error: 0.5741 - val_r_square: 0.0831
# Epoch 17/40
# 55/55 [==============================] - 0s 2ms/step - loss: 0.5569 - root_mean_squared_error: 0.7462 - mean_absolute_error: 0.5859 - r_square: 0.0956 - val_loss: 0.5576 - val_root_mean_squared_error: 0.7468 - val_mean_absolute_error: 0.5947 - val_r_square: 0.0258
# Epoch 18/40
# 55/55 [==============================] - 0s 2ms/step - loss: 0.5534 - root_mean_squared_error: 0.7439 - mean_absolute_error: 0.5859 - r_square: 0.1013 - val_loss: 0.5243 - val_root_mean_squared_error: 0.7241 - val_mean_absolute_error: 0.5740 - val_r_square: 0.0840
# Epoch 19/40
# 55/55 [==============================] - 0s 3ms/step - loss: 0.5566 - root_mean_squared_error: 0.7461 - mean_absolute_error: 0.5873 - r_square: 0.0960 - val_loss: 0.5226 - val_root_mean_squared_error: 0.7229 - val_mean_absolute_error: 0.5728 - val_r_square: 0.0871
# Epoch 20/40
# 55/55 [==============================] - 0s 2ms/step - loss: 0.5488 - root_mean_squared_error: 0.7408 - mean_absolute_error: 0.5811 - r_square: 0.1087 - val_loss: 0.5235 - val_root_mean_squared_error: 0.7235 - val_mean_absolute_error: 0.5723 - val_r_square: 0.0854
# Epoch 21/40
# 55/55 [==============================] - 0s 2ms/step - loss: 0.5510 - root_mean_squared_error: 0.7423 - mean_absolute_error: 0.5848 - r_square: 0.1052 - val_loss: 0.5231 - val_root_mean_squared_error: 0.7233 - val_mean_absolute_error: 0.5726 - val_r_square: 0.0861
# Epoch 22/40
# 55/55 [==============================] - 0s 2ms/step - loss: 0.5461 - root_mean_squared_error: 0.7390 - mean_absolute_error: 0.5796 - r_square: 0.1132 - val_loss: 0.5231 - val_root_mean_squared_error: 0.7232 - val_mean_absolute_error: 0.5728 - val_r_square: 0.0862
# Epoch 23/40
# 55/55 [==============================] - 0s 2ms/step - loss: 0.5463 - root_mean_squared_error: 0.7391 - mean_absolute_error: 0.5810 - r_square: 0.1127 - val_loss: 0.5299 - val_root_mean_squared_error: 0.7280 - val_mean_absolute_error: 0.5741 - val_r_square: 0.0742
# Epoch 24/40
# 55/55 [==============================] - 0s 2ms/step - loss: 0.5469 - root_mean_squared_error: 0.7395 - mean_absolute_error: 0.5795 - r_square: 0.1118 - val_loss: 0.5350 - val_root_mean_squared_error: 0.7315 - val_mean_absolute_error: 0.5807 - val_r_square: 0.0653
# Epoch 25/40
# 55/55 [==============================] - 0s 3ms/step - loss: 0.5450 - root_mean_squared_error: 0.7383 - mean_absolute_error: 0.5819 - r_square: 0.1149 - val_loss: 0.5225 - val_root_mean_squared_error: 0.7228 - val_mean_absolute_error: 0.5726 - val_r_square: 0.0873
# Epoch 26/40
# 55/55 [==============================] - 0s 2ms/step - loss: 0.5393 - root_mean_squared_error: 0.7344 - mean_absolute_error: 0.5769 - r_square: 0.1241 - val_loss: 0.5359 - val_root_mean_squared_error: 0.7320 - val_mean_absolute_error: 0.5808 - val_r_square: 0.0638
# Epoch 27/40
# 55/55 [==============================] - 0s 2ms/step - loss: 0.5430 - root_mean_squared_error: 0.7369 - mean_absolute_error: 0.5792 - r_square: 0.1182 - val_loss: 0.5236 - val_root_mean_squared_error: 0.7236 - val_mean_absolute_error: 0.5737 - val_r_square: 0.0853
# Epoch 28/40
# 55/55 [==============================] - 0s 2ms/step - loss: 0.5423 - root_mean_squared_error: 0.7364 - mean_absolute_error: 0.5805 - r_square: 0.1193 - val_loss: 0.5244 - val_root_mean_squared_error: 0.7242 - val_mean_absolute_error: 0.5744 - val_r_square: 0.0838
# Epoch 29/40
# 55/55 [==============================] - 0s 2ms/step - loss: 0.5354 - root_mean_squared_error: 0.7317 - mean_absolute_error: 0.5754 - r_square: 0.1305 - val_loss: 0.5269 - val_root_mean_squared_error: 0.7259 - val_mean_absolute_error: 0.5745 - val_r_square: 0.0795
# Epoch 30/40
# 55/55 [==============================] - 0s 2ms/step - loss: 0.5394 - root_mean_squared_error: 0.7345 - mean_absolute_error: 0.5789 - r_square: 0.1240 - val_loss: 0.5241 - val_root_mean_squared_error: 0.7239 - val_mean_absolute_error: 0.5742 - val_r_square: 0.0845
# Epoch 31/40
# 55/55 [==============================] - 0s 2ms/step - loss: 0.5412 - root_mean_squared_error: 0.7356 - mean_absolute_error: 0.5787 - r_square: 0.1211 - val_loss: 0.5287 - val_root_mean_squared_error: 0.7271 - val_mean_absolute_error: 0.5752 - val_r_square: 0.0764
# Epoch 32/40
# 55/55 [==============================] - 0s 2ms/step - loss: 0.5346 - root_mean_squared_error: 0.7311 - mean_absolute_error: 0.5738 - r_square: 0.1319 - val_loss: 0.5289 - val_root_mean_squared_error: 0.7272 - val_mean_absolute_error: 0.5762 - val_r_square: 0.0760
# Epoch 33/40
# 55/55 [==============================] - 0s 3ms/step - loss: 0.5368 - root_mean_squared_error: 0.7327 - mean_absolute_error: 0.5750 - r_square: 0.1282 - val_loss: 0.5277 - val_root_mean_squared_error: 0.7264 - val_mean_absolute_error: 0.5762 - val_r_square: 0.0781

# %% [markdown]
# #### After fitting

# %%
metric_name = ['Loss', 'RootMSE', 'MAE', 'R2']
train_metric = ['loss', 'root_mean_squared_error', 'mean_absolute_error', 'r_square']
val_metric = ['val_loss', 'val_root_mean_squared_error', 'val_mean_absolute_error', 'val_r_square']

for i in range(len(metric_name)):

  print(f"\n----------- {metric_name[i]} chart -----------\n")

  # matplotlib chart
  plt.plot(trained_model.history[train_metric[i]], label=f"Train {metric_name[i]}")
  plt.plot(trained_model.history[val_metric[i]], label=f"Val {metric_name[i]}")
  plt.legend()
  plt.show()
# Out:
# ----------- Loss chart -----------
# ----------- RootMSE chart -----------
# ----------- MAE chart -----------
# ----------- R2 chart -----------

# %%
# Validation data values in the last epoch
print("number of epochs:", trained_model.epoch[-1] + 1)
print("val_loss:", trained_model.history['val_loss'][-1])
print("val_root_mean_squared_error:", trained_model.history['val_root_mean_squared_error'][-1])
print("val_mean_absolute_error:", trained_model.history['val_mean_absolute_error'][-1])
print("val_r2_score:", trained_model.history['val_r_square'][-1])
# Out:
# number of epochs: 33
# val_loss: 0.5277150273323059
# val_root_mean_squared_error: 0.7264399528503418
# val_mean_absolute_error: 0.5762110352516174
# val_r2_score: 0.07807552814483643

# %%
# Evaluate the model on the test data
print("Evaluate on test data")
test_loss, test_mean_squared_error, test_mean_absolute_error, test_r2_score = my_model.evaluate(test_data, test_target_ratings)
print("Test_loss:", test_loss)
print("Test_root_mean_squared_error:", test_mean_squared_error)
print("Test_mean_absolute_error:", test_mean_absolute_error)
print("Test_r2_score:", test_r2_score)
print('\n')

print("Generate predictions for 10 samples")
predictions = my_model.predict(test_data)
test_y_comparison = pd.DataFrame({'test_y_true': test_target_ratings, 'test_y_pred': [x for x in predictions]})

print(test_y_comparison.head(10))
# Out:
# Evaluate on test data
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5817 - root_mean_squared_error: 0.7627 - mean_absolute_error: 0.6038 - r_square: 0.0930
# Test_loss: 0.5816836357116699
# Test_root_mean_squared_error: 0.7626818418502808
# Test_mean_absolute_error: 0.6038201451301575
# Test_r2_score: 0.09301042556762695
#
#
# Generate predictions for 10 samples
# 14/14 [==============================] - 0s 890us/step
#    test_y_true  test_y_pred
# 0          2.0  [3.1731567]
# 1          2.0   [3.068872]
# 2          3.5  [3.2109466]
# 3          3.5  [2.7775645]
# 4          2.0  [2.7795954]
# 5          2.0  [3.0008016]
# 6          1.5   [2.697826]
# 7          4.0  [3.1846695]
# 8          2.0  [2.9555988]
# 9          3.5   [2.756783]

# %%
if wandb_log:
  wandb.finish()
# Out:
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch/epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇███</td></tr><tr><td>epoch/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/mean_absolute_error</td><td>█▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/r_square</td><td>▁▇███████████████████████████████</td></tr><tr><td>epoch/root_mean_squared_error</td><td>█▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/val_loss</td><td>█▄▆▆▃▂▂▁▁▆▂▁▇▁▁▁▄▁▁▁▁▁▂▂▁▂▁▁▁▁▂▂▁</td></tr><tr><td>epoch/val_mean_absolute_error</td><td>█▄▅█▃▂▁▁▁▆▁▁▆▁▂▁▅▁▁▁▁▁▁▂▁▃▁▁▁▁▂▂▂</td></tr><tr><td>epoch/val_r_square</td><td>▁▅▃▃▆▇▇██▃▇█▂███▅█████▇▇█▇████▇▇█</td></tr><tr><td>epoch/val_root_mean_squared_error</td><td>█▄▆▆▃▂▂▁▂▆▂▁▇▁▁▁▄▁▁▁▁▁▂▂▁▂▁▁▁▁▂▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/epoch</td><td>32</td></tr><tr><td>epoch/learning_rate</td><td>0.01</td></tr><tr><td>epoch/loss</td><td>0.53684</td></tr><tr><td>epoch/mean_absolute_error</td><td>0.575</td></tr><tr><td>epoch/r_square</td><td>0.12816</td></tr><tr><td>epoch/root_mean_squared_error</td><td>0.7327</td></tr><tr><td>epoch/val_loss</td><td>0.52772</td></tr><tr><td>epoch/val_mean_absolute_error</td><td>0.57621</td></tr><tr><td>epoch/val_r_square</td><td>0.07808</td></tr><tr><td>epoch/val_root_mean_squared_error</td><td>0.72644</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">arch10_25m_profile_3_gn</strong> at: <a href='https://wandb.ai/xbarantomik/dp/runs/fhg14veb' target="_blank">https://wandb.ai/xbarantomik/dp/runs/fhg14veb</a><br/> View project at: <a href='https://wandb.ai/xbarantomik/dp' target="_blank">https://wandb.ai/xbarantomik/dp</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240503_131004-fhg14veb/logs</code>
