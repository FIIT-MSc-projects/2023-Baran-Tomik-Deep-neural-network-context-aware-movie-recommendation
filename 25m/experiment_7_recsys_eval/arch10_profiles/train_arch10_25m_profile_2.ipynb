# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import load_model
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json
# Out:
# 2024-05-03 13:09:07.065775: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-03 13:09:07.183186: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-03 13:09:07.675903: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/baran-tomik/bin/miniconda3/envs/tf/lib/
# 2024-05-03 13:09:07.675975: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/baran-tomik/bin/miniconda3/envs/tf/lib/
# 2024-05-03 13:09:07.675982: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
checkpoint_model_filepath = 'checkpoints/'
trained_model_filepath = 'trained_models/'
training_data_path = 'data_25m/'
nn_config_path = '../config/nn_config.json'
wandb_config_path = '../config/wandb_config.json'

print('Training data path:', training_data_path)

import nn_model
# Out:
# Training data path: data_25m/
# /home/baran-tomik/bin/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# /home/baran-tomik/bin/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.13.0 and strictly below 2.16.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.10.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
try:
  with open(wandb_config_path, 'r') as f:
    wandb_config = json.load(f)

  wandb_log = True
  wandb_run_name = wandb_config["wandb_run_name"]
  wandb_group_name = wandb_config["wandb_group_name"]
  wandb_entity = wandb_config["wandb_entity"]
  wandb_project_name = wandb_config["wandb_project_name"]
  if wandb_config["new_model"] == 'false':
    new_model = False
  else:
    new_model = True
  run_name_before = wandb_config["run_name_before"]   # Model to be loaded
  if wandb_config["eval_only"] == 'false':
    eval_only = False
  else:
    eval_only = True

  print('wandb_log:', wandb_log)
  print('wandb_run_name:', wandb_run_name)
  print('wandb_group_name:', wandb_group_name)
  print('wandb_entity:', wandb_entity)
  print('wandb_project_name:', wandb_project_name)
  print('new_model:', new_model)
  print('run_name_before:', run_name_before)
  print('eval_only:', eval_only)

except OSError as e:
  print('\nERROR loading wandb_config file')
  print(e)
  # quit()
# Out:
# wandb_log: True
# wandb_run_name: arch10_25m_profile_2_gn
# wandb_group_name: 25m_deep_dense
# wandb_entity: xbarantomik
# wandb_project_name: DP
# new_model: True
# run_name_before: -
# eval_only: False

# %%
try:
  with open(nn_config_path, 'r') as f:
    nn_config = json.load(f)

  epochs = int(nn_config['epochs'])
  batch_size = int(nn_config['batch_size'])
  patience = int(nn_config['patience'])
  learning_rate = float(nn_config['learning_rate'])
  architecture = int(nn_config['architecture'])
  training_data_file = nn_config['training_data_file'] + '/'

  print('epochs:', epochs)
  print('batch_size:', batch_size)
  print('patience:', patience)
  print('learning_rate:', learning_rate)
  print('architecture:', architecture)
  print('training_data_file:', training_data_file)

except OSError as e:
  print('\nERROR loading nn_config file')
  print(e)
# Out:
# epochs: 40
# batch_size: 64
# patience: 8
# learning_rate: 0.02609
# architecture: 10
# training_data_file: profile_2/

# %% [markdown]
# #### Load training data

# %%
try:
  train_data = np.load(training_data_path + training_data_file + 'train_data.npy')
  val_data = np.load(training_data_path + training_data_file + 'val_data.npy')
  test_data = np.load(training_data_path + training_data_file + 'test_data.npy')
  train_target_ratings = np.load(training_data_path + training_data_file + 'train_target_ratings.npy')
  val_target_ratings = np.load(training_data_path + training_data_file + 'val_target_ratings.npy')
  test_target_ratings = np.load(training_data_path + training_data_file + 'test_target_ratings.npy')

except OSError as e:
  print('\nERROR loading training data')
  print(e)
  quit()

# %%
if wandb_log:
  import wandb
  from wandb.keras import WandbMetricsLogger, WandbModelCheckpoint

  wandb.login()

  wandb.init(
    config=nn_config,
    entity=wandb_entity,
    project=wandb_project_name,
    name=wandb_run_name,
    group=wandb_group_name
  )
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: xbarantomik. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/home/baran-tomik/projects/DP/training/wandb/run-20240503_130909-ildt7d52</code>
# Syncing run <strong><a href='https://wandb.ai/xbarantomik/dp/runs/ildt7d52' target="_blank">arch10_25m_profile_2_gn</a></strong> to <a href='https://wandb.ai/xbarantomik/dp' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/xbarantomik/dp' target="_blank">https://wandb.ai/xbarantomik/dp</a>
#  View run at <a href='https://wandb.ai/xbarantomik/dp/runs/ildt7d52' target="_blank">https://wandb.ai/xbarantomik/dp/runs/ildt7d52</a>

# %% [markdown]
# #### NN MODEL

# %%
early_stopping = EarlyStopping(patience=patience, monitor='val_loss')

# %%
checkpoint_filepath = checkpoint_model_filepath + f"{wandb_run_name}_checkpoint.h5"
checkpoint_callback = ModelCheckpoint(filepath=checkpoint_filepath, monitor='val_loss', save_best_only=True, mode='min', save_weights_only=False, save_format='tf')

if wandb_log:
  callbacks = [early_stopping, checkpoint_callback, WandbMetricsLogger()]
else:
  callbacks = [early_stopping, checkpoint_callback]

# %% [markdown]
# #### Create model

# %%
if new_model:
  my_model = nn_model.create_model(architecture=architecture, lr=learning_rate, train_data_shape=train_data.shape[1])
  print('\nCreated a new model')
else:
  my_model = load_model(checkpoint_model_filepath + run_name_before + '_checkpoint.h5')
  print('\nLoaded a model')

if my_model != None:
  my_model.summary()
else:
  print('\nERROR loading NN model')
  quit()
# Out:
# Model 10
#
# Created a new model
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# 2024-05-03 13:09:14.344491: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-03 13:09:14.370993: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-03 13:09:14.371178: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-03 13:09:14.371851: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-03 13:09:14.372418: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-03 13:09:14.372585: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-03 13:09:14.372710: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-03 13:09:14.424432: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-03 13:09:14.424602: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-03 13:09:14.424745: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-03 13:09:14.424840: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7511 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1070, pci bus id: 0000:01:00.0, compute capability: 6.1
#  dense (Dense)               (None, 512)               21504
#
#  activation (Activation)     (None, 512)               0
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 128)               65664
#
#  activation_1 (Activation)   (None, 128)               0
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_2 (Dense)             (None, 256)               33024
#
#  activation_2 (Activation)   (None, 256)               0
#
#  dense_3 (Dense)             (None, 512)               131584
#
#  activation_3 (Activation)   (None, 512)               0
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_4 (Dense)             (None, 128)               65664
#
#  activation_4 (Activation)   (None, 128)               0
#
#  dense_5 (Dense)             (None, 1)                 129
#
#  activation_5 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 317,569
# Trainable params: 317,569
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Model fitting

# %%
if not eval_only:
  print('Training model')
  trained_model = my_model.fit(train_data, train_target_ratings, batch_size, epochs, validation_data=(val_data, val_target_ratings), callbacks=callbacks, verbose=1)
  my_model.save(trained_model_filepath + f"{wandb_run_name}_trained.keras")
else:
  print('Only evaluating model')
# Out:
# Training model
# Epoch 1/40
# 115/115 [==============================] - 1s 4ms/step - loss: 0.7944 - root_mean_squared_error: 0.8913 - mean_absolute_error: 0.6206 - r_square: -1.5280 - val_loss: 0.3072 - val_root_mean_squared_error: 0.5543 - val_mean_absolute_error: 0.4307 - val_r_square: -0.0097
# Epoch 2/40
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3450 - root_mean_squared_error: 0.5873 - mean_absolute_error: 0.4716 - r_square: -0.0978 - val_loss: 0.3470 - val_root_mean_squared_error: 0.5890 - val_mean_absolute_error: 0.4597 - val_r_square: -0.1402
# Epoch 3/40
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3192 - root_mean_squared_error: 0.5650 - mean_absolute_error: 0.4510 - r_square: -0.0159 - val_loss: 0.2757 - val_root_mean_squared_error: 0.5250 - val_mean_absolute_error: 0.4152 - val_r_square: 0.0941
# Epoch 4/40
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3080 - root_mean_squared_error: 0.5550 - mean_absolute_error: 0.4426 - r_square: 0.0197 - val_loss: 0.2805 - val_root_mean_squared_error: 0.5296 - val_mean_absolute_error: 0.4157 - val_r_square: 0.0782
# Epoch 5/40
# 115/115 [==============================] - 0s 2ms/step - loss: 0.2975 - root_mean_squared_error: 0.5454 - mean_absolute_error: 0.4366 - r_square: 0.0534 - val_loss: 0.2735 - val_root_mean_squared_error: 0.5230 - val_mean_absolute_error: 0.4115 - val_r_square: 0.1011
# Epoch 6/40
# 115/115 [==============================] - 0s 2ms/step - loss: 0.2893 - root_mean_squared_error: 0.5379 - mean_absolute_error: 0.4308 - r_square: 0.0794 - val_loss: 0.2660 - val_root_mean_squared_error: 0.5158 - val_mean_absolute_error: 0.4081 - val_r_square: 0.1259
# Epoch 7/40
# 115/115 [==============================] - 0s 2ms/step - loss: 0.2852 - root_mean_squared_error: 0.5340 - mean_absolute_error: 0.4274 - r_square: 0.0925 - val_loss: 0.2808 - val_root_mean_squared_error: 0.5299 - val_mean_absolute_error: 0.4147 - val_r_square: 0.0773
# Epoch 8/40
# 115/115 [==============================] - 0s 2ms/step - loss: 0.2802 - root_mean_squared_error: 0.5294 - mean_absolute_error: 0.4248 - r_square: 0.1082 - val_loss: 0.2636 - val_root_mean_squared_error: 0.5135 - val_mean_absolute_error: 0.4055 - val_r_square: 0.1336
# Epoch 9/40
# 115/115 [==============================] - 0s 2ms/step - loss: 0.2787 - root_mean_squared_error: 0.5279 - mean_absolute_error: 0.4228 - r_square: 0.1131 - val_loss: 0.2634 - val_root_mean_squared_error: 0.5133 - val_mean_absolute_error: 0.4056 - val_r_square: 0.1342
# Epoch 10/40
# 115/115 [==============================] - 0s 2ms/step - loss: 0.2766 - root_mean_squared_error: 0.5259 - mean_absolute_error: 0.4223 - r_square: 0.1197 - val_loss: 0.2634 - val_root_mean_squared_error: 0.5132 - val_mean_absolute_error: 0.4066 - val_r_square: 0.1344
# Epoch 11/40
# 115/115 [==============================] - 0s 2ms/step - loss: 0.2754 - root_mean_squared_error: 0.5248 - mean_absolute_error: 0.4194 - r_square: 0.1237 - val_loss: 0.2631 - val_root_mean_squared_error: 0.5129 - val_mean_absolute_error: 0.4038 - val_r_square: 0.1354
# Epoch 12/40
# 115/115 [==============================] - 0s 2ms/step - loss: 0.2709 - root_mean_squared_error: 0.5204 - mean_absolute_error: 0.4174 - r_square: 0.1380 - val_loss: 0.2649 - val_root_mean_squared_error: 0.5147 - val_mean_absolute_error: 0.4046 - val_r_square: 0.1295
# Epoch 13/40
# 115/115 [==============================] - 0s 2ms/step - loss: 0.2765 - root_mean_squared_error: 0.5258 - mean_absolute_error: 0.4210 - r_square: 0.1200 - val_loss: 0.2632 - val_root_mean_squared_error: 0.5130 - val_mean_absolute_error: 0.4035 - val_r_square: 0.1351
# Epoch 14/40
# 115/115 [==============================] - 0s 2ms/step - loss: 0.2667 - root_mean_squared_error: 0.5165 - mean_absolute_error: 0.4130 - r_square: 0.1512 - val_loss: 0.2809 - val_root_mean_squared_error: 0.5300 - val_mean_absolute_error: 0.4143 - val_r_square: 0.0770
# Epoch 15/40
# 115/115 [==============================] - 0s 2ms/step - loss: 0.2696 - root_mean_squared_error: 0.5192 - mean_absolute_error: 0.4154 - r_square: 0.1422 - val_loss: 0.2624 - val_root_mean_squared_error: 0.5122 - val_mean_absolute_error: 0.4028 - val_r_square: 0.1377
# Epoch 16/40
# 115/115 [==============================] - 0s 2ms/step - loss: 0.2680 - root_mean_squared_error: 0.5177 - mean_absolute_error: 0.4141 - r_square: 0.1471 - val_loss: 0.2608 - val_root_mean_squared_error: 0.5107 - val_mean_absolute_error: 0.4023 - val_r_square: 0.1428
# Epoch 17/40
# 115/115 [==============================] - 0s 2ms/step - loss: 0.2661 - root_mean_squared_error: 0.5158 - mean_absolute_error: 0.4124 - r_square: 0.1533 - val_loss: 0.2624 - val_root_mean_squared_error: 0.5122 - val_mean_absolute_error: 0.4027 - val_r_square: 0.1378
# Epoch 18/40
# 115/115 [==============================] - 0s 2ms/step - loss: 0.2664 - root_mean_squared_error: 0.5161 - mean_absolute_error: 0.4118 - r_square: 0.1523 - val_loss: 0.2676 - val_root_mean_squared_error: 0.5173 - val_mean_absolute_error: 0.4056 - val_r_square: 0.1205
# Epoch 19/40
# 115/115 [==============================] - 0s 2ms/step - loss: 0.2648 - root_mean_squared_error: 0.5146 - mean_absolute_error: 0.4108 - r_square: 0.1573 - val_loss: 0.2612 - val_root_mean_squared_error: 0.5110 - val_mean_absolute_error: 0.4022 - val_r_square: 0.1417
# Epoch 20/40
# 115/115 [==============================] - 0s 2ms/step - loss: 0.2638 - root_mean_squared_error: 0.5136 - mean_absolute_error: 0.4103 - r_square: 0.1605 - val_loss: 0.2587 - val_root_mean_squared_error: 0.5086 - val_mean_absolute_error: 0.4018 - val_r_square: 0.1500
# Epoch 21/40
# 115/115 [==============================] - 0s 2ms/step - loss: 0.2636 - root_mean_squared_error: 0.5134 - mean_absolute_error: 0.4107 - r_square: 0.1610 - val_loss: 0.2610 - val_root_mean_squared_error: 0.5109 - val_mean_absolute_error: 0.4022 - val_r_square: 0.1423
# Epoch 22/40
# 115/115 [==============================] - 0s 2ms/step - loss: 0.2626 - root_mean_squared_error: 0.5124 - mean_absolute_error: 0.4099 - r_square: 0.1644 - val_loss: 0.2594 - val_root_mean_squared_error: 0.5094 - val_mean_absolute_error: 0.4015 - val_r_square: 0.1474
# Epoch 23/40
# 115/115 [==============================] - 0s 2ms/step - loss: 0.2628 - root_mean_squared_error: 0.5127 - mean_absolute_error: 0.4089 - r_square: 0.1636 - val_loss: 0.2594 - val_root_mean_squared_error: 0.5094 - val_mean_absolute_error: 0.4025 - val_r_square: 0.1474
# Epoch 24/40
# 115/115 [==============================] - 0s 2ms/step - loss: 0.2638 - root_mean_squared_error: 0.5137 - mean_absolute_error: 0.4104 - r_square: 0.1603 - val_loss: 0.2580 - val_root_mean_squared_error: 0.5080 - val_mean_absolute_error: 0.4010 - val_r_square: 0.1520
# Epoch 25/40
# 115/115 [==============================] - 0s 2ms/step - loss: 0.2609 - root_mean_squared_error: 0.5108 - mean_absolute_error: 0.4071 - r_square: 0.1698 - val_loss: 0.2587 - val_root_mean_squared_error: 0.5086 - val_mean_absolute_error: 0.4013 - val_r_square: 0.1499
# Epoch 26/40
# 115/115 [==============================] - 0s 2ms/step - loss: 0.2622 - root_mean_squared_error: 0.5120 - mean_absolute_error: 0.4079 - r_square: 0.1656 - val_loss: 0.2587 - val_root_mean_squared_error: 0.5086 - val_mean_absolute_error: 0.4026 - val_r_square: 0.1498
# Epoch 27/40
# 115/115 [==============================] - 0s 2ms/step - loss: 0.2589 - root_mean_squared_error: 0.5088 - mean_absolute_error: 0.4069 - r_square: 0.1761 - val_loss: 0.2583 - val_root_mean_squared_error: 0.5082 - val_mean_absolute_error: 0.4015 - val_r_square: 0.1511
# Epoch 28/40
# 115/115 [==============================] - 0s 2ms/step - loss: 0.2586 - root_mean_squared_error: 0.5086 - mean_absolute_error: 0.4058 - r_square: 0.1769 - val_loss: 0.2584 - val_root_mean_squared_error: 0.5083 - val_mean_absolute_error: 0.4010 - val_r_square: 0.1508
# Epoch 29/40
# 115/115 [==============================] - 0s 2ms/step - loss: 0.2576 - root_mean_squared_error: 0.5075 - mean_absolute_error: 0.4042 - r_square: 0.1804 - val_loss: 0.2642 - val_root_mean_squared_error: 0.5140 - val_mean_absolute_error: 0.4056 - val_r_square: 0.1319
# Epoch 30/40
# 115/115 [==============================] - 0s 2ms/step - loss: 0.2587 - root_mean_squared_error: 0.5086 - mean_absolute_error: 0.4060 - r_square: 0.1768 - val_loss: 0.2571 - val_root_mean_squared_error: 0.5070 - val_mean_absolute_error: 0.4009 - val_r_square: 0.1552
# Epoch 31/40
# 115/115 [==============================] - 0s 2ms/step - loss: 0.2581 - root_mean_squared_error: 0.5080 - mean_absolute_error: 0.4048 - r_square: 0.1788 - val_loss: 0.2572 - val_root_mean_squared_error: 0.5071 - val_mean_absolute_error: 0.4010 - val_r_square: 0.1549
# Epoch 32/40
# 115/115 [==============================] - 0s 2ms/step - loss: 0.2562 - root_mean_squared_error: 0.5061 - mean_absolute_error: 0.4042 - r_square: 0.1847 - val_loss: 0.2568 - val_root_mean_squared_error: 0.5068 - val_mean_absolute_error: 0.4003 - val_r_square: 0.1560
# Epoch 33/40
# 115/115 [==============================] - 0s 2ms/step - loss: 0.2583 - root_mean_squared_error: 0.5083 - mean_absolute_error: 0.4051 - r_square: 0.1778 - val_loss: 0.2567 - val_root_mean_squared_error: 0.5067 - val_mean_absolute_error: 0.3996 - val_r_square: 0.1564
# Epoch 34/40
# 115/115 [==============================] - 0s 2ms/step - loss: 0.2553 - root_mean_squared_error: 0.5052 - mean_absolute_error: 0.4011 - r_square: 0.1876 - val_loss: 0.2564 - val_root_mean_squared_error: 0.5064 - val_mean_absolute_error: 0.3997 - val_r_square: 0.1573
# Epoch 35/40
# 115/115 [==============================] - 0s 2ms/step - loss: 0.2558 - root_mean_squared_error: 0.5058 - mean_absolute_error: 0.4020 - r_square: 0.1860 - val_loss: 0.2608 - val_root_mean_squared_error: 0.5107 - val_mean_absolute_error: 0.4023 - val_r_square: 0.1430
# Epoch 36/40
# 115/115 [==============================] - 0s 2ms/step - loss: 0.2542 - root_mean_squared_error: 0.5042 - mean_absolute_error: 0.4024 - r_square: 0.1909 - val_loss: 0.2566 - val_root_mean_squared_error: 0.5065 - val_mean_absolute_error: 0.4002 - val_r_square: 0.1568
# Epoch 37/40
# 115/115 [==============================] - 0s 2ms/step - loss: 0.2543 - root_mean_squared_error: 0.5043 - mean_absolute_error: 0.4008 - r_square: 0.1907 - val_loss: 0.2576 - val_root_mean_squared_error: 0.5076 - val_mean_absolute_error: 0.4008 - val_r_square: 0.1534
# Epoch 38/40
# 115/115 [==============================] - 0s 2ms/step - loss: 0.2542 - root_mean_squared_error: 0.5042 - mean_absolute_error: 0.4013 - r_square: 0.1911 - val_loss: 0.2587 - val_root_mean_squared_error: 0.5086 - val_mean_absolute_error: 0.4010 - val_r_square: 0.1498
# Epoch 39/40
# 115/115 [==============================] - 0s 2ms/step - loss: 0.2525 - root_mean_squared_error: 0.5025 - mean_absolute_error: 0.4013 - r_square: 0.1963 - val_loss: 0.2575 - val_root_mean_squared_error: 0.5075 - val_mean_absolute_error: 0.4011 - val_r_square: 0.1538
# Epoch 40/40
# 115/115 [==============================] - 0s 2ms/step - loss: 0.2532 - root_mean_squared_error: 0.5031 - mean_absolute_error: 0.4012 - r_square: 0.1943 - val_loss: 0.2672 - val_root_mean_squared_error: 0.5169 - val_mean_absolute_error: 0.4064 - val_r_square: 0.1219

# %% [markdown]
# #### After fitting

# %%
metric_name = ['Loss', 'RootMSE', 'MAE', 'R2']
train_metric = ['loss', 'root_mean_squared_error', 'mean_absolute_error', 'r_square']
val_metric = ['val_loss', 'val_root_mean_squared_error', 'val_mean_absolute_error', 'val_r_square']

for i in range(len(metric_name)):

  print(f"\n----------- {metric_name[i]} chart -----------\n")

  # matplotlib chart
  plt.plot(trained_model.history[train_metric[i]], label=f"Train {metric_name[i]}")
  plt.plot(trained_model.history[val_metric[i]], label=f"Val {metric_name[i]}")
  plt.legend()
  plt.show()
# Out:
# ----------- Loss chart -----------
# ----------- RootMSE chart -----------
# ----------- MAE chart -----------
# ----------- R2 chart -----------

# %%
# Validation data values in the last epoch
print("number of epochs:", trained_model.epoch[-1] + 1)
print("val_loss:", trained_model.history['val_loss'][-1])
print("val_root_mean_squared_error:", trained_model.history['val_root_mean_squared_error'][-1])
print("val_mean_absolute_error:", trained_model.history['val_mean_absolute_error'][-1])
print("val_r2_score:", trained_model.history['val_r_square'][-1])
# Out:
# number of epochs: 40
# val_loss: 0.2672004699707031
# val_root_mean_squared_error: 0.5169143676757812
# val_mean_absolute_error: 0.4064384698867798
# val_r2_score: 0.1219140887260437

# %%
# Evaluate the model on the test data
print("Evaluate on test data")
test_loss, test_mean_squared_error, test_mean_absolute_error, test_r2_score = my_model.evaluate(test_data, test_target_ratings)
print("Test_loss:", test_loss)
print("Test_root_mean_squared_error:", test_mean_squared_error)
print("Test_mean_absolute_error:", test_mean_absolute_error)
print("Test_r2_score:", test_r2_score)
print('\n')

print("Generate predictions for 10 samples")
predictions = my_model.predict(test_data)
test_y_comparison = pd.DataFrame({'test_y_true': test_target_ratings, 'test_y_pred': [x for x in predictions]})

print(test_y_comparison.head(10))
# Out:
# Evaluate on test data
# 29/29 [==============================] - 0s 1ms/step - loss: 0.2727 - root_mean_squared_error: 0.5222 - mean_absolute_error: 0.4107 - r_square: 0.1471
# Test_loss: 0.27269452810287476
# Test_root_mean_squared_error: 0.5222015976905823
# Test_mean_absolute_error: 0.41070589423179626
# Test_r2_score: 0.14713996648788452
#
#
# Generate predictions for 10 samples
# 29/29 [==============================] - 0s 831us/step
#    test_y_true  test_y_pred
# 0          4.0  [3.5499904]
# 1          3.0  [3.0557983]
# 2          3.0  [3.2792444]
# 3          3.0   [3.298938]
# 4          4.0  [3.6991904]
# 5          4.0   [3.819903]
# 6          4.0  [3.5332792]
# 7          4.0  [3.6166759]
# 8          3.0  [3.0680332]
# 9          2.5  [2.8369966]

# %%
if wandb_log:
  wandb.finish()
# Out:
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch/epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>epoch/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/loss</td><td>█▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/mean_absolute_error</td><td>█▃▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/r_square</td><td>▁▇▇▇▇███████████████████████████████████</td></tr><tr><td>epoch/root_mean_squared_error</td><td>█▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/val_loss</td><td>▅█▂▃▂▂▃▂▂▂▂▂▂▃▁▁▁▂▁▁▁▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▂</td></tr><tr><td>epoch/val_mean_absolute_error</td><td>▅█▃▃▂▂▃▂▂▂▁▂▁▃▁▁▁▂▁▁▁▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▂</td></tr><tr><td>epoch/val_r_square</td><td>▄▁▇▆▇▇▆▇▇▇▇▇▇▆███▇██████████▇██████████▇</td></tr><tr><td>epoch/val_root_mean_squared_error</td><td>▅█▃▃▂▂▃▂▂▂▂▂▂▃▁▁▁▂▁▁▁▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/epoch</td><td>39</td></tr><tr><td>epoch/learning_rate</td><td>0.01</td></tr><tr><td>epoch/loss</td><td>0.25316</td></tr><tr><td>epoch/mean_absolute_error</td><td>0.40119</td></tr><tr><td>epoch/r_square</td><td>0.19434</td></tr><tr><td>epoch/root_mean_squared_error</td><td>0.50315</td></tr><tr><td>epoch/val_loss</td><td>0.2672</td></tr><tr><td>epoch/val_mean_absolute_error</td><td>0.40644</td></tr><tr><td>epoch/val_r_square</td><td>0.12191</td></tr><tr><td>epoch/val_root_mean_squared_error</td><td>0.51691</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">arch10_25m_profile_2_gn</strong> at: <a href='https://wandb.ai/xbarantomik/dp/runs/ildt7d52' target="_blank">https://wandb.ai/xbarantomik/dp/runs/ildt7d52</a><br/> View project at: <a href='https://wandb.ai/xbarantomik/dp' target="_blank">https://wandb.ai/xbarantomik/dp</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240503_130909-ildt7d52/logs</code>
