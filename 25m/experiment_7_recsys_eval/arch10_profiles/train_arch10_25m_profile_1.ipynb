# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import load_model
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json
# Out:
# 2024-05-03 13:07:24.319808: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-03 13:07:24.436893: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-03 13:07:24.975326: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/baran-tomik/bin/miniconda3/envs/tf/lib/
# 2024-05-03 13:07:24.975429: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/baran-tomik/bin/miniconda3/envs/tf/lib/
# 2024-05-03 13:07:24.975437: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
checkpoint_model_filepath = 'checkpoints/'
trained_model_filepath = 'trained_models/'
training_data_path = 'data_25m/'
nn_config_path = '../config/nn_config.json'
wandb_config_path = '../config/wandb_config.json'

print('Training data path:', training_data_path)

import nn_model
# Out:
# Training data path: data_25m/
# /home/baran-tomik/bin/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# /home/baran-tomik/bin/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.13.0 and strictly below 2.16.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.10.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
try:
  with open(wandb_config_path, 'r') as f:
    wandb_config = json.load(f)

  wandb_log = True
  wandb_run_name = wandb_config["wandb_run_name"]
  wandb_group_name = wandb_config["wandb_group_name"]
  wandb_entity = wandb_config["wandb_entity"]
  wandb_project_name = wandb_config["wandb_project_name"]
  if wandb_config["new_model"] == 'false':
    new_model = False
  else:
    new_model = True
  run_name_before = wandb_config["run_name_before"]   # Model to be loaded
  if wandb_config["eval_only"] == 'false':
    eval_only = False
  else:
    eval_only = True

  print('wandb_log:', wandb_log)
  print('wandb_run_name:', wandb_run_name)
  print('wandb_group_name:', wandb_group_name)
  print('wandb_entity:', wandb_entity)
  print('wandb_project_name:', wandb_project_name)
  print('new_model:', new_model)
  print('run_name_before:', run_name_before)
  print('eval_only:', eval_only)

except OSError as e:
  print('\nERROR loading wandb_config file')
  print(e)
  # quit()
# Out:
# wandb_log: True
# wandb_run_name: arch10_25m_profile_1_gn
# wandb_group_name: 25m_deep_dense
# wandb_entity: xbarantomik
# wandb_project_name: DP
# new_model: True
# run_name_before: -
# eval_only: False

# %%
try:
  with open(nn_config_path, 'r') as f:
    nn_config = json.load(f)

  epochs = int(nn_config['epochs'])
  batch_size = int(nn_config['batch_size'])
  patience = int(nn_config['patience'])
  learning_rate = float(nn_config['learning_rate'])
  architecture = int(nn_config['architecture'])
  training_data_file = nn_config['training_data_file'] + '/'

  print('epochs:', epochs)
  print('batch_size:', batch_size)
  print('patience:', patience)
  print('learning_rate:', learning_rate)
  print('architecture:', architecture)
  print('training_data_file:', training_data_file)

except OSError as e:
  print('\nERROR loading nn_config file')
  print(e)
# Out:
# epochs: 40
# batch_size: 64
# patience: 8
# learning_rate: 0.02609
# architecture: 10
# training_data_file: profile_1/

# %% [markdown]
# #### Load training data

# %%
try:
  train_data = np.load(training_data_path + training_data_file + 'train_data.npy')
  val_data = np.load(training_data_path + training_data_file + 'val_data.npy')
  test_data = np.load(training_data_path + training_data_file + 'test_data.npy')
  train_target_ratings = np.load(training_data_path + training_data_file + 'train_target_ratings.npy')
  val_target_ratings = np.load(training_data_path + training_data_file + 'val_target_ratings.npy')
  test_target_ratings = np.load(training_data_path + training_data_file + 'test_target_ratings.npy')

except OSError as e:
  print('\nERROR loading training data')
  print(e)
  quit()

# %%
if wandb_log:
  import wandb
  from wandb.keras import WandbMetricsLogger, WandbModelCheckpoint

  wandb.login()

  wandb.init(
    config=nn_config,
    entity=wandb_entity,
    project=wandb_project_name,
    name=wandb_run_name,
    group=wandb_group_name
  )
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: xbarantomik. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/home/baran-tomik/projects/DP/training/wandb/run-20240503_130727-74g5ilsr</code>
# Syncing run <strong><a href='https://wandb.ai/xbarantomik/dp/runs/74g5ilsr' target="_blank">arch10_25m_profile_1_gn</a></strong> to <a href='https://wandb.ai/xbarantomik/dp' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/xbarantomik/dp' target="_blank">https://wandb.ai/xbarantomik/dp</a>
#  View run at <a href='https://wandb.ai/xbarantomik/dp/runs/74g5ilsr' target="_blank">https://wandb.ai/xbarantomik/dp/runs/74g5ilsr</a>

# %% [markdown]
# #### NN MODEL

# %%
early_stopping = EarlyStopping(patience=patience, monitor='val_loss')

# %%
checkpoint_filepath = checkpoint_model_filepath + f"{wandb_run_name}_checkpoint.h5"
checkpoint_callback = ModelCheckpoint(filepath=checkpoint_filepath, monitor='val_loss', save_best_only=True, mode='min', save_weights_only=False, save_format='tf')

if wandb_log:
  callbacks = [early_stopping, checkpoint_callback, WandbMetricsLogger()]
else:
  callbacks = [early_stopping, checkpoint_callback]

# %% [markdown]
# #### Create model

# %%
if new_model:
  my_model = nn_model.create_model(architecture=architecture, lr=learning_rate, train_data_shape=train_data.shape[1])
  print('\nCreated a new model')
else:
  my_model = load_model(checkpoint_model_filepath + run_name_before + '_checkpoint.h5')
  print('\nLoaded a model')

if my_model != None:
  my_model.summary()
else:
  print('\nERROR loading NN model')
  quit()
# Out:
# Model 10
#
# Created a new model
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               21504
#
#  activation (Activation)     (None, 512)               0
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 128)               65664
#
#  activation_1 (Activation)   (None, 128)               0
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_2 (Dense)             (None, 256)               33024
#
#  activation_2 (Activation)   (None, 256)               0
#
#  dense_3 (Dense)             (None, 512)               131584
#
#  activation_3 (Activation)   (None, 512)               0
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_4 (Dense)             (None, 128)               65664
#
#  activation_4 (Activation)   (None, 128)               0
#
#  dense_5 (Dense)             (None, 1)                 129
#
#  activation_5 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 317,569
# Trainable params: 317,569
# Non-trainable params: 0
# _________________________________________________________________
# 2024-05-03 13:07:31.819802: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-03 13:07:31.847237: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-03 13:07:31.847411: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-03 13:07:31.847795: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-03 13:07:31.848232: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-03 13:07:31.848366: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-03 13:07:31.848481: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-03 13:07:31.927122: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-03 13:07:31.927286: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-03 13:07:31.927404: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-03 13:07:31.927498: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7511 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1070, pci bus id: 0000:01:00.0, compute capability: 6.1

# %% [markdown]
# ## Model fitting

# %%
if not eval_only:
  print('Training model')
  trained_model = my_model.fit(train_data, train_target_ratings, batch_size, epochs, validation_data=(val_data, val_target_ratings), callbacks=callbacks, verbose=1)
  my_model.save(trained_model_filepath + f"{wandb_run_name}_trained.keras")
else:
  print('Only evaluating model')
# Out:
# Training model
# Epoch 1/40
# 403/403 [==============================] - 2s 3ms/step - loss: 0.6762 - root_mean_squared_error: 0.8223 - mean_absolute_error: 0.6056 - r_square: -0.2094 - val_loss: 0.4653 - val_root_mean_squared_error: 0.6822 - val_mean_absolute_error: 0.5156 - val_r_square: 0.1074
# Epoch 2/40
# 403/403 [==============================] - 1s 2ms/step - loss: 0.5199 - root_mean_squared_error: 0.7210 - mean_absolute_error: 0.5417 - r_square: 0.0701 - val_loss: 0.4694 - val_root_mean_squared_error: 0.6852 - val_mean_absolute_error: 0.5177 - val_r_square: 0.0996
# Epoch 3/40
# 403/403 [==============================] - 1s 2ms/step - loss: 0.5108 - root_mean_squared_error: 0.7147 - mean_absolute_error: 0.5352 - r_square: 0.0864 - val_loss: 0.4745 - val_root_mean_squared_error: 0.6888 - val_mean_absolute_error: 0.5215 - val_r_square: 0.0899
# Epoch 4/40
# 403/403 [==============================] - 1s 2ms/step - loss: 0.5031 - root_mean_squared_error: 0.7093 - mean_absolute_error: 0.5296 - r_square: 0.1003 - val_loss: 0.4810 - val_root_mean_squared_error: 0.6935 - val_mean_absolute_error: 0.5289 - val_r_square: 0.0774
# Epoch 5/40
# 403/403 [==============================] - 1s 2ms/step - loss: 0.4987 - root_mean_squared_error: 0.7062 - mean_absolute_error: 0.5255 - r_square: 0.1081 - val_loss: 0.4873 - val_root_mean_squared_error: 0.6980 - val_mean_absolute_error: 0.5345 - val_r_square: 0.0654
# Epoch 6/40
# 403/403 [==============================] - 1s 2ms/step - loss: 0.4963 - root_mean_squared_error: 0.7045 - mean_absolute_error: 0.5242 - r_square: 0.1124 - val_loss: 0.5252 - val_root_mean_squared_error: 0.7247 - val_mean_absolute_error: 0.5617 - val_r_square: -0.0073
# Epoch 7/40
# 403/403 [==============================] - 1s 2ms/step - loss: 0.4931 - root_mean_squared_error: 0.7022 - mean_absolute_error: 0.5224 - r_square: 0.1181 - val_loss: 0.4654 - val_root_mean_squared_error: 0.6822 - val_mean_absolute_error: 0.5160 - val_r_square: 0.1073
# Epoch 8/40
# 403/403 [==============================] - 1s 2ms/step - loss: 0.4905 - root_mean_squared_error: 0.7003 - mean_absolute_error: 0.5198 - r_square: 0.1227 - val_loss: 0.4563 - val_root_mean_squared_error: 0.6755 - val_mean_absolute_error: 0.5080 - val_r_square: 0.1247
# Epoch 9/40
# 403/403 [==============================] - 1s 2ms/step - loss: 0.4877 - root_mean_squared_error: 0.6984 - mean_absolute_error: 0.5179 - r_square: 0.1277 - val_loss: 0.4479 - val_root_mean_squared_error: 0.6692 - val_mean_absolute_error: 0.5018 - val_r_square: 0.1409
# Epoch 10/40
# 403/403 [==============================] - 1s 2ms/step - loss: 0.4858 - root_mean_squared_error: 0.6970 - mean_absolute_error: 0.5164 - r_square: 0.1312 - val_loss: 0.4463 - val_root_mean_squared_error: 0.6681 - val_mean_absolute_error: 0.4998 - val_r_square: 0.1439
# Epoch 11/40
# 403/403 [==============================] - 1s 2ms/step - loss: 0.4838 - root_mean_squared_error: 0.6955 - mean_absolute_error: 0.5149 - r_square: 0.1347 - val_loss: 0.4613 - val_root_mean_squared_error: 0.6792 - val_mean_absolute_error: 0.5098 - val_r_square: 0.1152
# Epoch 12/40
# 403/403 [==============================] - 1s 2ms/step - loss: 0.4814 - root_mean_squared_error: 0.6938 - mean_absolute_error: 0.5130 - r_square: 0.1390 - val_loss: 0.4474 - val_root_mean_squared_error: 0.6689 - val_mean_absolute_error: 0.5004 - val_r_square: 0.1419
# Epoch 13/40
# 403/403 [==============================] - 1s 2ms/step - loss: 0.4799 - root_mean_squared_error: 0.6927 - mean_absolute_error: 0.5123 - r_square: 0.1417 - val_loss: 0.4585 - val_root_mean_squared_error: 0.6771 - val_mean_absolute_error: 0.5119 - val_r_square: 0.1206
# Epoch 14/40
# 403/403 [==============================] - 1s 2ms/step - loss: 0.4802 - root_mean_squared_error: 0.6930 - mean_absolute_error: 0.5126 - r_square: 0.1411 - val_loss: 0.4425 - val_root_mean_squared_error: 0.6652 - val_mean_absolute_error: 0.4971 - val_r_square: 0.1513
# Epoch 15/40
# 403/403 [==============================] - 1s 2ms/step - loss: 0.4763 - root_mean_squared_error: 0.6901 - mean_absolute_error: 0.5106 - r_square: 0.1481 - val_loss: 0.4527 - val_root_mean_squared_error: 0.6728 - val_mean_absolute_error: 0.5031 - val_r_square: 0.1317
# Epoch 16/40
# 403/403 [==============================] - 1s 2ms/step - loss: 0.4766 - root_mean_squared_error: 0.6904 - mean_absolute_error: 0.5095 - r_square: 0.1475 - val_loss: 0.4392 - val_root_mean_squared_error: 0.6627 - val_mean_absolute_error: 0.4958 - val_r_square: 0.1576
# Epoch 17/40
# 403/403 [==============================] - 1s 2ms/step - loss: 0.4753 - root_mean_squared_error: 0.6894 - mean_absolute_error: 0.5086 - r_square: 0.1499 - val_loss: 0.4874 - val_root_mean_squared_error: 0.6981 - val_mean_absolute_error: 0.5371 - val_r_square: 0.0652
# Epoch 18/40
# 403/403 [==============================] - 1s 2ms/step - loss: 0.4736 - root_mean_squared_error: 0.6882 - mean_absolute_error: 0.5085 - r_square: 0.1529 - val_loss: 0.4587 - val_root_mean_squared_error: 0.6773 - val_mean_absolute_error: 0.5059 - val_r_square: 0.1202
# Epoch 19/40
# 403/403 [==============================] - 1s 2ms/step - loss: 0.4736 - root_mean_squared_error: 0.6882 - mean_absolute_error: 0.5080 - r_square: 0.1530 - val_loss: 0.4461 - val_root_mean_squared_error: 0.6679 - val_mean_absolute_error: 0.5053 - val_r_square: 0.1444
# Epoch 20/40
# 403/403 [==============================] - 1s 2ms/step - loss: 0.4718 - root_mean_squared_error: 0.6869 - mean_absolute_error: 0.5071 - r_square: 0.1561 - val_loss: 0.4704 - val_root_mean_squared_error: 0.6859 - val_mean_absolute_error: 0.5240 - val_r_square: 0.0977
# Epoch 21/40
# 403/403 [==============================] - 1s 2ms/step - loss: 0.4704 - root_mean_squared_error: 0.6859 - mean_absolute_error: 0.5056 - r_square: 0.1586 - val_loss: 0.4553 - val_root_mean_squared_error: 0.6747 - val_mean_absolute_error: 0.5122 - val_r_square: 0.1268
# Epoch 22/40
# 403/403 [==============================] - 1s 2ms/step - loss: 0.4704 - root_mean_squared_error: 0.6858 - mean_absolute_error: 0.5061 - r_square: 0.1587 - val_loss: 0.4384 - val_root_mean_squared_error: 0.6621 - val_mean_absolute_error: 0.4970 - val_r_square: 0.1591
# Epoch 23/40
# 403/403 [==============================] - 1s 2ms/step - loss: 0.4685 - root_mean_squared_error: 0.6845 - mean_absolute_error: 0.5047 - r_square: 0.1621 - val_loss: 0.4730 - val_root_mean_squared_error: 0.6877 - val_mean_absolute_error: 0.5125 - val_r_square: 0.0928
# Epoch 24/40
# 403/403 [==============================] - 1s 2ms/step - loss: 0.4682 - root_mean_squared_error: 0.6842 - mean_absolute_error: 0.5041 - r_square: 0.1626 - val_loss: 0.4434 - val_root_mean_squared_error: 0.6659 - val_mean_absolute_error: 0.4942 - val_r_square: 0.1496
# Epoch 25/40
# 403/403 [==============================] - 1s 2ms/step - loss: 0.4653 - root_mean_squared_error: 0.6821 - mean_absolute_error: 0.5027 - r_square: 0.1677 - val_loss: 0.4394 - val_root_mean_squared_error: 0.6629 - val_mean_absolute_error: 0.4983 - val_r_square: 0.1572
# Epoch 26/40
# 403/403 [==============================] - 1s 2ms/step - loss: 0.4662 - root_mean_squared_error: 0.6828 - mean_absolute_error: 0.5034 - r_square: 0.1663 - val_loss: 0.4362 - val_root_mean_squared_error: 0.6604 - val_mean_absolute_error: 0.4944 - val_r_square: 0.1634
# Epoch 27/40
# 403/403 [==============================] - 1s 2ms/step - loss: 0.4645 - root_mean_squared_error: 0.6815 - mean_absolute_error: 0.5021 - r_square: 0.1692 - val_loss: 0.4669 - val_root_mean_squared_error: 0.6833 - val_mean_absolute_error: 0.5086 - val_r_square: 0.1045
# Epoch 28/40
# 403/403 [==============================] - 1s 2ms/step - loss: 0.4649 - root_mean_squared_error: 0.6819 - mean_absolute_error: 0.5023 - r_square: 0.1685 - val_loss: 0.4973 - val_root_mean_squared_error: 0.7052 - val_mean_absolute_error: 0.5417 - val_r_square: 0.0462
# Epoch 29/40
# 403/403 [==============================] - 1s 2ms/step - loss: 0.4633 - root_mean_squared_error: 0.6807 - mean_absolute_error: 0.5025 - r_square: 0.1713 - val_loss: 0.4467 - val_root_mean_squared_error: 0.6684 - val_mean_absolute_error: 0.4961 - val_r_square: 0.1432
# Epoch 30/40
# 403/403 [==============================] - 1s 2ms/step - loss: 0.4636 - root_mean_squared_error: 0.6809 - mean_absolute_error: 0.5015 - r_square: 0.1708 - val_loss: 0.4350 - val_root_mean_squared_error: 0.6595 - val_mean_absolute_error: 0.4891 - val_r_square: 0.1656
# Epoch 31/40
# 403/403 [==============================] - 1s 2ms/step - loss: 0.4611 - root_mean_squared_error: 0.6790 - mean_absolute_error: 0.5001 - r_square: 0.1753 - val_loss: 0.4454 - val_root_mean_squared_error: 0.6674 - val_mean_absolute_error: 0.4973 - val_r_square: 0.1458
# Epoch 32/40
# 403/403 [==============================] - 1s 2ms/step - loss: 0.4609 - root_mean_squared_error: 0.6789 - mean_absolute_error: 0.5009 - r_square: 0.1756 - val_loss: 0.4362 - val_root_mean_squared_error: 0.6604 - val_mean_absolute_error: 0.4963 - val_r_square: 0.1634
# Epoch 33/40
# 403/403 [==============================] - 1s 2ms/step - loss: 0.4616 - root_mean_squared_error: 0.6794 - mean_absolute_error: 0.5000 - r_square: 0.1744 - val_loss: 0.4370 - val_root_mean_squared_error: 0.6611 - val_mean_absolute_error: 0.4975 - val_r_square: 0.1617
# Epoch 34/40
# 403/403 [==============================] - 1s 2ms/step - loss: 0.4610 - root_mean_squared_error: 0.6790 - mean_absolute_error: 0.5007 - r_square: 0.1754 - val_loss: 0.4602 - val_root_mean_squared_error: 0.6784 - val_mean_absolute_error: 0.5031 - val_r_square: 0.1174
# Epoch 35/40
# 403/403 [==============================] - 1s 2ms/step - loss: 0.4606 - root_mean_squared_error: 0.6787 - mean_absolute_error: 0.5001 - r_square: 0.1762 - val_loss: 0.4849 - val_root_mean_squared_error: 0.6963 - val_mean_absolute_error: 0.5173 - val_r_square: 0.0699
# Epoch 36/40
# 403/403 [==============================] - 1s 2ms/step - loss: 0.4609 - root_mean_squared_error: 0.6789 - mean_absolute_error: 0.5005 - r_square: 0.1756 - val_loss: 0.4481 - val_root_mean_squared_error: 0.6694 - val_mean_absolute_error: 0.4950 - val_r_square: 0.1405
# Epoch 37/40
# 403/403 [==============================] - 1s 2ms/step - loss: 0.4589 - root_mean_squared_error: 0.6774 - mean_absolute_error: 0.4985 - r_square: 0.1793 - val_loss: 0.4332 - val_root_mean_squared_error: 0.6582 - val_mean_absolute_error: 0.4904 - val_r_square: 0.1691
# Epoch 38/40
# 403/403 [==============================] - 1s 2ms/step - loss: 0.4601 - root_mean_squared_error: 0.6783 - mean_absolute_error: 0.4997 - r_square: 0.1770 - val_loss: 0.4434 - val_root_mean_squared_error: 0.6659 - val_mean_absolute_error: 0.4937 - val_r_square: 0.1496
# Epoch 39/40
# 403/403 [==============================] - 1s 2ms/step - loss: 0.4591 - root_mean_squared_error: 0.6776 - mean_absolute_error: 0.4991 - r_square: 0.1788 - val_loss: 0.4414 - val_root_mean_squared_error: 0.6643 - val_mean_absolute_error: 0.5020 - val_r_square: 0.1534
# Epoch 40/40
# 403/403 [==============================] - 1s 2ms/step - loss: 0.4574 - root_mean_squared_error: 0.6763 - mean_absolute_error: 0.4982 - r_square: 0.1818 - val_loss: 0.5795 - val_root_mean_squared_error: 0.7613 - val_mean_absolute_error: 0.5726 - val_r_square: -0.1116

# %% [markdown]
# #### After fitting

# %%
metric_name = ['Loss', 'RootMSE', 'MAE', 'R2']
train_metric = ['loss', 'root_mean_squared_error', 'mean_absolute_error', 'r_square']
val_metric = ['val_loss', 'val_root_mean_squared_error', 'val_mean_absolute_error', 'val_r_square']

for i in range(len(metric_name)):

  print(f"\n----------- {metric_name[i]} chart -----------\n")

  # matplotlib chart
  plt.plot(trained_model.history[train_metric[i]], label=f"Train {metric_name[i]}")
  plt.plot(trained_model.history[val_metric[i]], label=f"Val {metric_name[i]}")
  plt.legend()
  plt.show()
# Out:
# ----------- Loss chart -----------
# ----------- RootMSE chart -----------
# ----------- MAE chart -----------
# ----------- R2 chart -----------

# %%
# Validation data values in the last epoch
print("number of epochs:", trained_model.epoch[-1] + 1)
print("val_loss:", trained_model.history['val_loss'][-1])
print("val_root_mean_squared_error:", trained_model.history['val_root_mean_squared_error'][-1])
print("val_mean_absolute_error:", trained_model.history['val_mean_absolute_error'][-1])
print("val_r2_score:", trained_model.history['val_r_square'][-1])
# Out:
# number of epochs: 40
# val_loss: 0.5795337557792664
# val_root_mean_squared_error: 0.7612711191177368
# val_mean_absolute_error: 0.5725815296173096
# val_r2_score: -0.11158359050750732

# %%
# Evaluate the model on the test data
print("Evaluate on test data")
test_loss, test_mean_squared_error, test_mean_absolute_error, test_r2_score = my_model.evaluate(test_data, test_target_ratings)
print("Test_loss:", test_loss)
print("Test_root_mean_squared_error:", test_mean_squared_error)
print("Test_mean_absolute_error:", test_mean_absolute_error)
print("Test_r2_score:", test_r2_score)
print('\n')

print("Generate predictions for 10 samples")
predictions = my_model.predict(test_data)
test_y_comparison = pd.DataFrame({'test_y_true': test_target_ratings, 'test_y_pred': [x for x in predictions]})

print(test_y_comparison.head(10))
# Out:
# Evaluate on test data
# 101/101 [==============================] - 0s 1ms/step - loss: 0.6344 - root_mean_squared_error: 0.7965 - mean_absolute_error: 0.5814 - r_square: -0.1554
# Test_loss: 0.6344470381736755
# Test_root_mean_squared_error: 0.7965218424797058
# Test_mean_absolute_error: 0.581412136554718
# Test_r2_score: -0.15537190437316895
#
#
# Generate predictions for 10 samples
# 101/101 [==============================] - 0s 735us/step
#    test_y_true  test_y_pred
# 0          3.5  [2.8098698]
# 1          3.5  [3.8795295]
# 2          3.5   [3.961372]
# 3          3.5  [3.1624904]
# 4          3.5  [3.6687727]
# 5          3.0   [3.180923]
# 6          3.0  [3.4393854]
# 7          2.0  [2.9364958]
# 8          3.5   [3.840711]
# 9          3.5  [3.9759974]

# %%
if wandb_log:
  wandb.finish()
# Out:
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch/epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>epoch/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/loss</td><td>█▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/mean_absolute_error</td><td>█▄▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/r_square</td><td>▁▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇█████████████████████</td></tr><tr><td>epoch/root_mean_squared_error</td><td>█▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/val_loss</td><td>▃▃▃▃▄▅▃▂▂▂▂▂▂▁▂▁▄▂▂▃▂▁▃▁▁▁▃▄▂▁▂▁▁▂▃▂▁▁▁█</td></tr><tr><td>epoch/val_mean_absolute_error</td><td>▃▃▄▄▅▇▃▃▂▂▃▂▃▂▂▂▅▂▂▄▃▂▃▁▂▁▃▅▂▁▂▂▂▂▃▂▁▁▂█</td></tr><tr><td>epoch/val_r_square</td><td>▆▆▆▆▅▄▆▇▇▇▇▇▇█▇█▅▇▇▆▇█▆███▆▅▇█▇██▇▆▇███▁</td></tr><tr><td>epoch/val_root_mean_squared_error</td><td>▃▃▃▃▄▆▃▂▂▂▂▂▂▁▂▁▄▂▂▃▂▁▃▂▁▁▃▄▂▁▂▁▁▂▄▂▁▂▁█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/epoch</td><td>39</td></tr><tr><td>epoch/learning_rate</td><td>0.01</td></tr><tr><td>epoch/loss</td><td>0.45744</td></tr><tr><td>epoch/mean_absolute_error</td><td>0.49822</td></tr><tr><td>epoch/r_square</td><td>0.18184</td></tr><tr><td>epoch/root_mean_squared_error</td><td>0.67634</td></tr><tr><td>epoch/val_loss</td><td>0.57953</td></tr><tr><td>epoch/val_mean_absolute_error</td><td>0.57258</td></tr><tr><td>epoch/val_r_square</td><td>-0.11158</td></tr><tr><td>epoch/val_root_mean_squared_error</td><td>0.76127</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">arch10_25m_profile_1_gn</strong> at: <a href='https://wandb.ai/xbarantomik/dp/runs/74g5ilsr' target="_blank">https://wandb.ai/xbarantomik/dp/runs/74g5ilsr</a><br/> View project at: <a href='https://wandb.ai/xbarantomik/dp' target="_blank">https://wandb.ai/xbarantomik/dp</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240503_130727-74g5ilsr/logs</code>
