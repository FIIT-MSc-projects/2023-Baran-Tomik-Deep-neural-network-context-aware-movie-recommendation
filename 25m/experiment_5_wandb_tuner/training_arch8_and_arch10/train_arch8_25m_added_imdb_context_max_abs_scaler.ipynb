# %% [markdown]
# ## Experiment 5 - 25 ml - Training Architecture 8 on parameters from Hyperparameter tuning

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import load_model
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json
# Out:
# 2024-05-03 01:59:00.302078: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-03 01:59:00.418936: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-03 01:59:00.911619: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/baran-tomik/bin/miniconda3/envs/tf/lib/
# 2024-05-03 01:59:00.911716: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/baran-tomik/bin/miniconda3/envs/tf/lib/
# 2024-05-03 01:59:00.911722: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
checkpoint_model_filepath = 'checkpoints/'
trained_model_filepath = 'trained_models/'
training_data_path = 'data_25m/'
nn_config_path = '../config/nn_config.json'
wandb_config_path = '../config/wandb_config.json'

print('Training data path:', training_data_path)

import nn_model
# Out:
# Training data path: data_25m/
# /home/baran-tomik/bin/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# /home/baran-tomik/bin/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.13.0 and strictly below 2.16.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.10.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
try:
  with open(wandb_config_path, 'r') as f:
    wandb_config = json.load(f)

  wandb_log = True
  wandb_run_name = wandb_config["wandb_run_name"]
  wandb_group_name = wandb_config["wandb_group_name"]
  wandb_entity = wandb_config["wandb_entity"]
  wandb_project_name = wandb_config["wandb_project_name"]
  if wandb_config["new_model"] == 'false':
    new_model = False
  else:
    new_model = True
  run_name_before = wandb_config["run_name_before"]   # Model to be loaded
  if wandb_config["eval_only"] == 'false':
    eval_only = False
  else:
    eval_only = True

  print('wandb_log:', wandb_log)
  print('wandb_run_name:', wandb_run_name)
  print('wandb_group_name:', wandb_group_name)
  print('wandb_entity:', wandb_entity)
  print('wandb_project_name:', wandb_project_name)
  print('new_model:', new_model)
  print('run_name_before:', run_name_before)
  print('eval_only:', eval_only)

except OSError as e:
  print('\nERROR loading wandb_config file')
  print(e)
  # quit()
# Out:
# wandb_log: True
# wandb_run_name: arch8_25m_added_imdb_context_max_abs_scaler_gn
# wandb_group_name: 25m_deep_dense
# wandb_entity: xbarantomik
# wandb_project_name: DP
# new_model: True
# run_name_before: -
# eval_only: False

# %%
try:
  with open(nn_config_path, 'r') as f:
    nn_config = json.load(f)

  epochs = int(nn_config['epochs'])
  batch_size = int(nn_config['batch_size'])
  patience = int(nn_config['patience'])
  learning_rate = float(nn_config['learning_rate'])
  architecture = int(nn_config['architecture'])
  training_data_file = nn_config['training_data_file'] + '/'

  print('epochs:', epochs)
  print('batch_size:', batch_size)
  print('patience:', patience)
  print('learning_rate:', learning_rate)
  print('architecture:', architecture)
  print('training_data_file:', training_data_file)

except OSError as e:
  print('\nERROR loading nn_config file')
  print(e)
# Out:
# epochs: 40
# batch_size: 64
# patience: 8
# learning_rate: 0.02609
# architecture: 8
# training_data_file: added_imdb_context_max_abs_scaler/

# %% [markdown]
# #### Load training data

# %%
try:
  train_data = np.load(training_data_path + training_data_file + 'train_data.npy')
  val_data = np.load(training_data_path + training_data_file + 'val_data.npy')
  test_data = np.load(training_data_path + training_data_file + 'test_data.npy')
  train_target_ratings = np.load(training_data_path + training_data_file + 'train_target_ratings.npy')
  val_target_ratings = np.load(training_data_path + training_data_file + 'val_target_ratings.npy')
  test_target_ratings = np.load(training_data_path + training_data_file + 'test_target_ratings.npy')

except OSError as e:
  print('\nERROR loading training data')
  print(e)
  quit()

# %%
if wandb_log:
  import wandb
  from wandb.keras import WandbMetricsLogger, WandbModelCheckpoint

  wandb.login()

  wandb.init(
    config=nn_config,
    entity=wandb_entity,
    project=wandb_project_name,
    name=wandb_run_name,
    group=wandb_group_name
  )
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: xbarantomik. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/home/baran-tomik/projects/DP/training/wandb/run-20240503_015904-2olyjqsh</code>
# Syncing run <strong><a href='https://wandb.ai/xbarantomik/dp/runs/2olyjqsh' target="_blank">arch8_25m_added_imdb_context_max_abs_scaler_gn</a></strong> to <a href='https://wandb.ai/xbarantomik/dp' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/xbarantomik/dp' target="_blank">https://wandb.ai/xbarantomik/dp</a>
#  View run at <a href='https://wandb.ai/xbarantomik/dp/runs/2olyjqsh' target="_blank">https://wandb.ai/xbarantomik/dp/runs/2olyjqsh</a>

# %% [markdown]
# #### NN MODEL

# %%
early_stopping = EarlyStopping(patience=patience, monitor='val_loss')

# %%
checkpoint_filepath = checkpoint_model_filepath + f"{wandb_run_name}_checkpoint.h5"
checkpoint_callback = ModelCheckpoint(filepath=checkpoint_filepath, monitor='val_loss', save_best_only=True, mode='min', save_weights_only=False, save_format='tf')

if wandb_log:
  callbacks = [early_stopping, checkpoint_callback, WandbMetricsLogger()]
else:
  callbacks = [early_stopping, checkpoint_callback]

# %% [markdown]
# #### Create model

# %%
if new_model:
  my_model = nn_model.create_model(architecture=architecture, lr=learning_rate, train_data_shape=train_data.shape[1])
  print('\nCreated a new model')
else:
  my_model = load_model(checkpoint_model_filepath + run_name_before + '_checkpoint.h5')
  print('\nLoaded a model')

if my_model != None:
  my_model.summary()
else:
  print('\nERROR loading NN model')
  quit()
# Out:
# Model 8
#
# Created a new model
# Model: "sequential"
# 2024-05-03 01:59:08.858619: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-03 01:59:08.884742: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-03 01:59:08.884912: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-03 01:59:08.885558: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-03 01:59:08.886120: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-03 01:59:08.886302: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-03 01:59:08.886430: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-03 01:59:08.949606: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-03 01:59:08.949776: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-03 01:59:08.949893: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-03 01:59:08.949988: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7511 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1070, pci bus id: 0000:01:00.0, compute capability: 6.1
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               21504
#
#  activation (Activation)     (None, 512)               0
#
#  dropout (Dropout)           (None, 512)               0
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  activation_1 (Activation)   (None, 512)               0
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 512)               262656
#
#  activation_2 (Activation)   (None, 512)               0
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 256)               131328
#
#  activation_3 (Activation)   (None, 256)               0
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 256)               65792
#
#  activation_4 (Activation)   (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 1)                 257
#
#  activation_5 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 744,193
# Trainable params: 744,193
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Model fitting

# %%
if not eval_only:
  print('Training model')
  trained_model = my_model.fit(train_data, train_target_ratings, batch_size, epochs, validation_data=(val_data, val_target_ratings), callbacks=callbacks, verbose=1)
  my_model.save(trained_model_filepath + f"{wandb_run_name}_trained.keras")
else:
  print('Only evaluating model')
# Out:
# Training model
# 2024-05-03 01:59:10.212283: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 3277831100 exceeds 10% of free system memory.
# 2024-05-03 01:59:12.173544: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 3277831100 exceeds 10% of free system memory.
# Epoch 1/40
# 312294/312294 [==============================] - 728s 2ms/step - loss: 1.0276 - root_mean_squared_error: 1.0137 - mean_absolute_error: 0.7945 - r_square: 0.0863 - val_loss: 0.9850 - val_root_mean_squared_error: 0.9925 - val_mean_absolute_error: 0.7753 - val_r_square: 0.1241
# Epoch 2/40
# 312294/312294 [==============================] - 730s 2ms/step - loss: 0.9890 - root_mean_squared_error: 0.9945 - mean_absolute_error: 0.7761 - r_square: 0.1206 - val_loss: 0.9692 - val_root_mean_squared_error: 0.9845 - val_mean_absolute_error: 0.7653 - val_r_square: 0.1382
# Epoch 3/40
# 312294/312294 [==============================] - 729s 2ms/step - loss: 0.9786 - root_mean_squared_error: 0.9892 - mean_absolute_error: 0.7712 - r_square: 0.1302 - val_loss: 0.9631 - val_root_mean_squared_error: 0.9814 - val_mean_absolute_error: 0.7603 - val_r_square: 0.1436
# Epoch 4/40
# 312294/312294 [==============================] - 730s 2ms/step - loss: 0.9726 - root_mean_squared_error: 0.9862 - mean_absolute_error: 0.7683 - r_square: 0.1355 - val_loss: 0.9561 - val_root_mean_squared_error: 0.9778 - val_mean_absolute_error: 0.7593 - val_r_square: 0.1498
# Epoch 5/40
# 312294/312294 [==============================] - 730s 2ms/step - loss: 0.9688 - root_mean_squared_error: 0.9843 - mean_absolute_error: 0.7664 - r_square: 0.1385 - val_loss: 0.9549 - val_root_mean_squared_error: 0.9772 - val_mean_absolute_error: 0.7600 - val_r_square: 0.1509
# Epoch 6/40
# 312294/312294 [==============================] - 730s 2ms/step - loss: 0.9662 - root_mean_squared_error: 0.9829 - mean_absolute_error: 0.7649 - r_square: 0.1410 - val_loss: 0.9513 - val_root_mean_squared_error: 0.9753 - val_mean_absolute_error: 0.7563 - val_r_square: 0.1541
# Epoch 7/40
# 312294/312294 [==============================] - 730s 2ms/step - loss: 0.9643 - root_mean_squared_error: 0.9820 - mean_absolute_error: 0.7640 - r_square: 0.1427 - val_loss: 0.9490 - val_root_mean_squared_error: 0.9742 - val_mean_absolute_error: 0.7574 - val_r_square: 0.1561
# Epoch 8/40
# 312294/312294 [==============================] - 731s 2ms/step - loss: 0.9630 - root_mean_squared_error: 0.9813 - mean_absolute_error: 0.7634 - r_square: 0.1442 - val_loss: 0.9511 - val_root_mean_squared_error: 0.9753 - val_mean_absolute_error: 0.7609 - val_r_square: 0.1542
# Epoch 9/40
# 312294/312294 [==============================] - 731s 2ms/step - loss: 0.9621 - root_mean_squared_error: 0.9809 - mean_absolute_error: 0.7630 - r_square: 0.1444 - val_loss: 0.9485 - val_root_mean_squared_error: 0.9739 - val_mean_absolute_error: 0.7590 - val_r_square: 0.1565
# Epoch 10/40
# 312294/312294 [==============================] - 731s 2ms/step - loss: 0.9615 - root_mean_squared_error: 0.9806 - mean_absolute_error: 0.7625 - r_square: 0.1453 - val_loss: 0.9477 - val_root_mean_squared_error: 0.9735 - val_mean_absolute_error: 0.7541 - val_r_square: 0.1573
# Epoch 11/40
# 312294/312294 [==============================] - 730s 2ms/step - loss: 0.9612 - root_mean_squared_error: 0.9804 - mean_absolute_error: 0.7624 - r_square: 0.1451 - val_loss: 0.9468 - val_root_mean_squared_error: 0.9730 - val_mean_absolute_error: 0.7556 - val_r_square: 0.1581
# Epoch 12/40
# 312294/312294 [==============================] - 730s 2ms/step - loss: 0.9609 - root_mean_squared_error: 0.9803 - mean_absolute_error: 0.7622 - r_square: 0.1457 - val_loss: 0.9470 - val_root_mean_squared_error: 0.9731 - val_mean_absolute_error: 0.7569 - val_r_square: 0.1579
# Epoch 13/40
# 312294/312294 [==============================] - 731s 2ms/step - loss: 0.9607 - root_mean_squared_error: 0.9802 - mean_absolute_error: 0.7621 - r_square: 0.1461 - val_loss: 0.9480 - val_root_mean_squared_error: 0.9736 - val_mean_absolute_error: 0.7552 - val_r_square: 0.1570
# Epoch 14/40
# 312294/312294 [==============================] - 731s 2ms/step - loss: 0.9607 - root_mean_squared_error: 0.9802 - mean_absolute_error: 0.7620 - r_square: 0.1457 - val_loss: 0.9471 - val_root_mean_squared_error: 0.9732 - val_mean_absolute_error: 0.7588 - val_r_square: 0.1578
# Epoch 15/40
# 312294/312294 [==============================] - 731s 2ms/step - loss: 0.9607 - root_mean_squared_error: 0.9801 - mean_absolute_error: 0.7620 - r_square: 0.1458 - val_loss: 0.9468 - val_root_mean_squared_error: 0.9730 - val_mean_absolute_error: 0.7570 - val_r_square: 0.1581
# Epoch 16/40
# 312294/312294 [==============================] - 731s 2ms/step - loss: 0.9609 - root_mean_squared_error: 0.9802 - mean_absolute_error: 0.7621 - r_square: 0.1458 - val_loss: 0.9466 - val_root_mean_squared_error: 0.9729 - val_mean_absolute_error: 0.7580 - val_r_square: 0.1582
# Epoch 17/40
# 312294/312294 [==============================] - 731s 2ms/step - loss: 0.9610 - root_mean_squared_error: 0.9803 - mean_absolute_error: 0.7621 - r_square: 0.1455 - val_loss: 0.9496 - val_root_mean_squared_error: 0.9745 - val_mean_absolute_error: 0.7597 - val_r_square: 0.1556
# Epoch 18/40
# 312294/312294 [==============================] - 731s 2ms/step - loss: 0.9611 - root_mean_squared_error: 0.9804 - mean_absolute_error: 0.7623 - r_square: 0.1453 - val_loss: 0.9486 - val_root_mean_squared_error: 0.9740 - val_mean_absolute_error: 0.7596 - val_r_square: 0.1564
# Epoch 19/40
# 312294/312294 [==============================] - 731s 2ms/step - loss: 0.9615 - root_mean_squared_error: 0.9806 - mean_absolute_error: 0.7623 - r_square: 0.1452 - val_loss: 0.9480 - val_root_mean_squared_error: 0.9736 - val_mean_absolute_error: 0.7603 - val_r_square: 0.1570
# Epoch 20/40
# 312294/312294 [==============================] - 731s 2ms/step - loss: 0.9615 - root_mean_squared_error: 0.9806 - mean_absolute_error: 0.7623 - r_square: 0.1455 - val_loss: 0.9475 - val_root_mean_squared_error: 0.9734 - val_mean_absolute_error: 0.7567 - val_r_square: 0.1575
# Epoch 21/40
# 312294/312294 [==============================] - 731s 2ms/step - loss: 0.9618 - root_mean_squared_error: 0.9807 - mean_absolute_error: 0.7625 - r_square: 0.1449 - val_loss: 0.9493 - val_root_mean_squared_error: 0.9743 - val_mean_absolute_error: 0.7602 - val_r_square: 0.1558
# Epoch 22/40
# 312294/312294 [==============================] - 731s 2ms/step - loss: 0.9624 - root_mean_squared_error: 0.9810 - mean_absolute_error: 0.7628 - r_square: 0.1444 - val_loss: 0.9487 - val_root_mean_squared_error: 0.9740 - val_mean_absolute_error: 0.7601 - val_r_square: 0.1564
# Epoch 23/40
# 312294/312294 [==============================] - 731s 2ms/step - loss: 0.9626 - root_mean_squared_error: 0.9811 - mean_absolute_error: 0.7629 - r_square: 0.1443 - val_loss: 0.9474 - val_root_mean_squared_error: 0.9733 - val_mean_absolute_error: 0.7561 - val_r_square: 0.1575
# Epoch 24/40
# 312294/312294 [==============================] - 732s 2ms/step - loss: 0.9628 - root_mean_squared_error: 0.9812 - mean_absolute_error: 0.7629 - r_square: 0.1438 - val_loss: 0.9487 - val_root_mean_squared_error: 0.9740 - val_mean_absolute_error: 0.7592 - val_r_square: 0.1563

# %% [markdown]
# #### After fitting

# %%
metric_name = ['Loss', 'RootMSE', 'MAE', 'R2']
train_metric = ['loss', 'root_mean_squared_error', 'mean_absolute_error', 'r_square']
val_metric = ['val_loss', 'val_root_mean_squared_error', 'val_mean_absolute_error', 'val_r_square']

for i in range(len(metric_name)):

  print(f"\n----------- {metric_name[i]} chart -----------\n")

  # matplotlib chart
  plt.plot(trained_model.history[train_metric[i]], label=f"Train {metric_name[i]}")
  plt.plot(trained_model.history[val_metric[i]], label=f"Val {metric_name[i]}")
  plt.legend()
  plt.show()
# Out:
# ----------- Loss chart -----------
# ----------- RootMSE chart -----------
# ----------- MAE chart -----------
# ----------- R2 chart -----------

# %%
# Validation data values in the last epoch
print("number of epochs:", trained_model.epoch[-1] + 1)
print("val_loss:", trained_model.history['val_loss'][-1])
print("val_root_mean_squared_error:", trained_model.history['val_root_mean_squared_error'][-1])
print("val_mean_absolute_error:", trained_model.history['val_mean_absolute_error'][-1])
print("val_r2_score:", trained_model.history['val_r_square'][-1])
# Out:
# number of epochs: 24
# val_loss: 0.9487316012382507
# val_root_mean_squared_error: 0.9740285277366638
# val_mean_absolute_error: 0.7592328786849976
# val_r2_score: 0.15634554624557495

# %%
# Evaluate the model on the test data
print("Evaluate on test data")
test_loss, test_mean_squared_error, test_mean_absolute_error, test_r2_score = my_model.evaluate(test_data, test_target_ratings)
print("Test_loss:", test_loss)
print("Test_root_mean_squared_error:", test_mean_squared_error)
print("Test_mean_absolute_error:", test_mean_absolute_error)
print("Test_r2_score:", test_r2_score)
print('\n')

print("Generate predictions for 10 samples")
predictions = my_model.predict(test_data)
test_y_comparison = pd.DataFrame({'test_y_true': test_target_ratings, 'test_y_pred': [x for x in predictions]})

print(test_y_comparison.head(10))
# Out:
# Evaluate on test data
# 78074/78074 [==============================] - 108s 1ms/step - loss: 0.9573 - root_mean_squared_error: 0.9784 - mean_absolute_error: 0.7622 - r_square: 0.1500
# Test_loss: 0.9572539329528809
# Test_root_mean_squared_error: 0.9783935546875
# Test_mean_absolute_error: 0.7622326612472534
# Test_r2_score: 0.15003347396850586
#
#
# Generate predictions for 10 samples
# 78074/78074 [==============================] - 61s 779us/step
#    test_y_true  test_y_pred
# 0          4.0  [3.4930189]
# 1          4.5  [3.9038682]
# 2          2.5    [3.00188]
# 3          4.5  [3.6684377]
# 4          3.5  [3.9607472]
# 5          3.5  [3.3448663]
# 6          3.0    [3.78931]
# 7          3.0  [3.0129628]
# 8          4.0  [3.9815407]
# 9          1.5  [3.3850276]

# %%
if wandb_log:
  wandb.finish()
# Out:
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch/epoch</td><td>▁▁▂▂▂▃▃▃▃▄▄▄▅▅▅▆▆▆▆▇▇▇██</td></tr><tr><td>epoch/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/loss</td><td>█▄▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/mean_absolute_error</td><td>█▄▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/r_square</td><td>▁▅▆▇▇▇██████████████████</td></tr><tr><td>epoch/root_mean_squared_error</td><td>█▄▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/val_loss</td><td>█▅▄▃▃▂▁▂▁▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁</td></tr><tr><td>epoch/val_mean_absolute_error</td><td>█▅▃▃▃▂▂▃▃▁▂▂▁▃▂▂▃▃▃▂▃▃▂▃</td></tr><tr><td>epoch/val_r_square</td><td>▁▄▅▆▆▇█▇████████▇███████</td></tr><tr><td>epoch/val_root_mean_squared_error</td><td>█▅▄▃▃▂▁▂▁▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/epoch</td><td>23</td></tr><tr><td>epoch/learning_rate</td><td>0.001</td></tr><tr><td>epoch/loss</td><td>0.96278</td></tr><tr><td>epoch/mean_absolute_error</td><td>0.76285</td></tr><tr><td>epoch/r_square</td><td>0.14383</td></tr><tr><td>epoch/root_mean_squared_error</td><td>0.98121</td></tr><tr><td>epoch/val_loss</td><td>0.94873</td></tr><tr><td>epoch/val_mean_absolute_error</td><td>0.75923</td></tr><tr><td>epoch/val_r_square</td><td>0.15635</td></tr><tr><td>epoch/val_root_mean_squared_error</td><td>0.97403</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">arch8_25m_added_imdb_context_max_abs_scaler_gn</strong> at: <a href='https://wandb.ai/xbarantomik/dp/runs/2olyjqsh' target="_blank">https://wandb.ai/xbarantomik/dp/runs/2olyjqsh</a><br/> View project at: <a href='https://wandb.ai/xbarantomik/dp' target="_blank">https://wandb.ai/xbarantomik/dp</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240503_015904-2olyjqsh/logs</code>
