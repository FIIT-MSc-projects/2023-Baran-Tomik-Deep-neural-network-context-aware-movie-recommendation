# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import load_model
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json
# Out:
# 2024-05-02 02:29:14.117426: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-02 02:29:14.287377: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-02 02:29:15.244056: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/baran-tomik/bin/miniconda3/envs/tf/lib/
# 2024-05-02 02:29:15.244153: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/baran-tomik/bin/miniconda3/envs/tf/lib/
# 2024-05-02 02:29:15.244159: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
checkpoint_model_filepath = 'checkpoints/'
trained_model_filepath = 'trained_models/'
training_data_path = 'data_25m/'
nn_config_path = '../config/nn_config.json'
wandb_config_path = '../config/wandb_config.json'

print('Training data path:', training_data_path)

import nn_model
# Out:
# Training data path: data_25m/
# /home/baran-tomik/bin/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# /home/baran-tomik/bin/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.13.0 and strictly below 2.16.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.10.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
try:
  with open(wandb_config_path, 'r') as f:
    wandb_config = json.load(f)

  wandb_log = True
  wandb_run_name = wandb_config["wandb_run_name"]
  wandb_group_name = wandb_config["wandb_group_name"]
  wandb_entity = wandb_config["wandb_entity"]
  wandb_project_name = wandb_config["wandb_project_name"]
  if wandb_config["new_model"] == 'false':
    new_model = False
  else:
    new_model = True
  run_name_before = wandb_config["run_name_before"]   # Model to be loaded
  if wandb_config["eval_only"] == 'false':
    eval_only = False
  else:
    eval_only = True

  print('wandb_log:', wandb_log)
  print('wandb_run_name:', wandb_run_name)
  print('wandb_group_name:', wandb_group_name)
  print('wandb_entity:', wandb_entity)
  print('wandb_project_name:', wandb_project_name)
  print('new_model:', new_model)
  print('run_name_before:', run_name_before)
  print('eval_only:', eval_only)

except OSError as e:
  print('\nERROR loading wandb_config file')
  print(e)
  # quit()
# Out:
# wandb_log: True
# wandb_run_name: arch10_25m_dded_imdb_context_max_abs_scaler_gc_4
# wandb_group_name: 25m_deep_dense
# wandb_entity: xbarantomik
# wandb_project_name: DP
# new_model: True
# run_name_before: -
# eval_only: False

# %%
try:
  with open(nn_config_path, 'r') as f:
    nn_config = json.load(f)

  epochs = int(nn_config['epochs'])
  batch_size = int(nn_config['batch_size'])
  patience = int(nn_config['patience'])
  learning_rate = float(nn_config['learning_rate'])
  architecture = int(nn_config['architecture'])
  training_data_file = nn_config['training_data_file'] + '/'

  print('epochs:', epochs)
  print('batch_size:', batch_size)
  print('patience:', patience)
  print('learning_rate:', learning_rate)
  print('architecture:', architecture)
  print('training_data_file:', training_data_file)

except OSError as e:
  print('\nERROR loading nn_config file')
  print(e)
# Out:
# epochs: 40
# batch_size: 64
# patience: 8
# learning_rate: 0.02609
# architecture: 10
# training_data_file: added_imdb_context_max_abs_scaler/

# %% [markdown]
# #### Load training data

# %%
try:
  train_data = np.load(training_data_path + training_data_file + 'train_data.npy')
  val_data = np.load(training_data_path + training_data_file + 'val_data.npy')
  test_data = np.load(training_data_path + training_data_file + 'test_data.npy')
  train_target_ratings = np.load(training_data_path + training_data_file + 'train_target_ratings.npy')
  val_target_ratings = np.load(training_data_path + training_data_file + 'val_target_ratings.npy')
  test_target_ratings = np.load(training_data_path + training_data_file + 'test_target_ratings.npy')

except OSError as e:
  print('\nERROR loading training data')
  print(e)
  quit()

# %%
if wandb_log:
  import wandb
  from wandb.keras import WandbMetricsLogger, WandbModelCheckpoint

  wandb.login()

  wandb.init(
    config=nn_config,
    entity=wandb_entity,
    project=wandb_project_name,
    name=wandb_run_name,
    group=wandb_group_name
  )
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: xbarantomik. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/home/baran-tomik/projects/DP/training/wandb/run-20240502_022924-57v9z8a7</code>
# Syncing run <strong><a href='https://wandb.ai/xbarantomik/dp/runs/57v9z8a7' target="_blank">arch10_25m_dded_imdb_context_max_abs_scaler_gc_4</a></strong> to <a href='https://wandb.ai/xbarantomik/dp' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/xbarantomik/dp' target="_blank">https://wandb.ai/xbarantomik/dp</a>
#  View run at <a href='https://wandb.ai/xbarantomik/dp/runs/57v9z8a7' target="_blank">https://wandb.ai/xbarantomik/dp/runs/57v9z8a7</a>

# %% [markdown]
# #### NN MODEL

# %%
early_stopping = EarlyStopping(patience=patience, monitor='val_loss')

# %%
checkpoint_filepath = checkpoint_model_filepath + f"{wandb_run_name}_checkpoint.h5"
checkpoint_callback = ModelCheckpoint(filepath=checkpoint_filepath, monitor='val_loss', save_best_only=True, mode='min', save_weights_only=False, save_format='tf')

if wandb_log:
  callbacks = [early_stopping, checkpoint_callback, WandbMetricsLogger()]
else:
  callbacks = [early_stopping, checkpoint_callback]

# %% [markdown]
# #### Create model

# %%
if new_model:
  my_model = nn_model.create_model(architecture=architecture, lr=learning_rate, train_data_shape=train_data.shape[1])
  print('\nCreated a new model')
else:
  my_model = load_model(checkpoint_model_filepath + run_name_before + '_checkpoint.h5')
  print('\nLoaded a model')

if my_model != None:
  my_model.summary()
else:
  print('\nERROR loading NN model')
  quit()
# Out:
# Model 10
#
# Created a new model
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               21504
#
#  activation (Activation)     (None, 512)               0
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 128)               65664
#
#  activation_1 (Activation)   (None, 128)               0
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_2 (Dense)             (None, 256)               33024
#
#  activation_2 (Activation)   (None, 256)               0
#
#  dense_3 (Dense)             (None, 512)               131584
#
#  activation_3 (Activation)   (None, 512)               0
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_4 (Dense)             (None, 128)               65664
#
#  activation_4 (Activation)   (None, 128)               0
#
#  dense_5 (Dense)             (None, 1)                 129
#
#  activation_5 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 317,569
# Trainable params: 317,569
# Non-trainable params: 0
# _________________________________________________________________
# 2024-05-02 02:29:29.453427: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-02 02:29:29.528421: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-02 02:29:29.528983: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-02 02:29:29.530767: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-02 02:29:29.532234: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-02 02:29:29.532581: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-02 02:29:29.532880: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-02 02:29:29.602778: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-02 02:29:29.602959: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-02 02:29:29.603140: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-02 02:29:29.603254: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7511 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1070, pci bus id: 0000:01:00.0, compute capability: 6.1

# %% [markdown]
# ## Model fitting

# %%
if not eval_only:
  print('Training model')
  trained_model = my_model.fit(train_data, train_target_ratings, batch_size, epochs, validation_data=(val_data, val_target_ratings), callbacks=callbacks, verbose=1)
  my_model.save(trained_model_filepath + f"{wandb_run_name}_trained.keras")
else:
  print('Only evaluating model')
# Out:
# Training model
# 2024-05-02 02:29:30.990244: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 3277831100 exceeds 10% of free system memory.
# 2024-05-02 02:29:32.903966: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 3277831100 exceeds 10% of free system memory.
# Epoch 1/40
# 312294/312294 [==============================] - 645s 2ms/step - loss: 1.0243 - root_mean_squared_error: 1.0121 - mean_absolute_error: 0.7936 - r_square: 0.0896 - val_loss: 0.9992 - val_root_mean_squared_error: 0.9996 - val_mean_absolute_error: 0.7824 - val_r_square: 0.1115
# Epoch 2/40
# 312294/312294 [==============================] - 646s 2ms/step - loss: 0.9998 - root_mean_squared_error: 0.9999 - mean_absolute_error: 0.7818 - r_square: 0.1113 - val_loss: 0.9896 - val_root_mean_squared_error: 0.9948 - val_mean_absolute_error: 0.7797 - val_r_square: 0.1200
# Epoch 3/40
# 312294/312294 [==============================] - 646s 2ms/step - loss: 0.9904 - root_mean_squared_error: 0.9952 - mean_absolute_error: 0.7770 - r_square: 0.1196 - val_loss: 0.9846 - val_root_mean_squared_error: 0.9923 - val_mean_absolute_error: 0.7809 - val_r_square: 0.1244
# Epoch 4/40
# 312294/312294 [==============================] - 646s 2ms/step - loss: 0.9841 - root_mean_squared_error: 0.9920 - mean_absolute_error: 0.7739 - r_square: 0.1252 - val_loss: 0.9744 - val_root_mean_squared_error: 0.9871 - val_mean_absolute_error: 0.7694 - val_r_square: 0.1335
# Epoch 5/40
# 312294/312294 [==============================] - 646s 2ms/step - loss: 0.9791 - root_mean_squared_error: 0.9895 - mean_absolute_error: 0.7715 - r_square: 0.1294 - val_loss: 0.9743 - val_root_mean_squared_error: 0.9871 - val_mean_absolute_error: 0.7730 - val_r_square: 0.1336
# Epoch 6/40
# 312294/312294 [==============================] - 646s 2ms/step - loss: 0.9749 - root_mean_squared_error: 0.9874 - mean_absolute_error: 0.7694 - r_square: 0.1330 - val_loss: 0.9686 - val_root_mean_squared_error: 0.9842 - val_mean_absolute_error: 0.7724 - val_r_square: 0.1386
# Epoch 7/40
# 312294/312294 [==============================] - 646s 2ms/step - loss: 0.9713 - root_mean_squared_error: 0.9856 - mean_absolute_error: 0.7677 - r_square: 0.1364 - val_loss: 0.9653 - val_root_mean_squared_error: 0.9825 - val_mean_absolute_error: 0.7663 - val_r_square: 0.1416
# Epoch 8/40
# 312294/312294 [==============================] - 647s 2ms/step - loss: 0.9683 - root_mean_squared_error: 0.9840 - mean_absolute_error: 0.7661 - r_square: 0.1391 - val_loss: 0.9597 - val_root_mean_squared_error: 0.9796 - val_mean_absolute_error: 0.7641 - val_r_square: 0.1466
# Epoch 9/40
# 312294/312294 [==============================] - 646s 2ms/step - loss: 0.9657 - root_mean_squared_error: 0.9827 - mean_absolute_error: 0.7649 - r_square: 0.1415 - val_loss: 0.9568 - val_root_mean_squared_error: 0.9782 - val_mean_absolute_error: 0.7639 - val_r_square: 0.1491
# Epoch 10/40
# 312294/312294 [==============================] - 646s 2ms/step - loss: 0.9636 - root_mean_squared_error: 0.9816 - mean_absolute_error: 0.7639 - r_square: 0.1432 - val_loss: 0.9553 - val_root_mean_squared_error: 0.9774 - val_mean_absolute_error: 0.7597 - val_r_square: 0.1505
# Epoch 11/40
# 312294/312294 [==============================] - 647s 2ms/step - loss: 0.9616 - root_mean_squared_error: 0.9806 - mean_absolute_error: 0.7630 - r_square: 0.1451 - val_loss: 0.9545 - val_root_mean_squared_error: 0.9770 - val_mean_absolute_error: 0.7613 - val_r_square: 0.1512
# Epoch 12/40
# 312294/312294 [==============================] - 646s 2ms/step - loss: 0.9599 - root_mean_squared_error: 0.9797 - mean_absolute_error: 0.7621 - r_square: 0.1467 - val_loss: 0.9760 - val_root_mean_squared_error: 0.9879 - val_mean_absolute_error: 0.7762 - val_r_square: 0.1321
# Epoch 13/40
# 312294/312294 [==============================] - 646s 2ms/step - loss: 0.9584 - root_mean_squared_error: 0.9790 - mean_absolute_error: 0.7614 - r_square: 0.1479 - val_loss: 0.9515 - val_root_mean_squared_error: 0.9754 - val_mean_absolute_error: 0.7608 - val_r_square: 0.1539
# Epoch 14/40
# 312294/312294 [==============================] - 646s 2ms/step - loss: 0.9570 - root_mean_squared_error: 0.9783 - mean_absolute_error: 0.7607 - r_square: 0.1491 - val_loss: 0.9702 - val_root_mean_squared_error: 0.9850 - val_mean_absolute_error: 0.7747 - val_r_square: 0.1373
# Epoch 15/40
# 312294/312294 [==============================] - 647s 2ms/step - loss: 0.9558 - root_mean_squared_error: 0.9777 - mean_absolute_error: 0.7601 - r_square: 0.1499 - val_loss: 0.9480 - val_root_mean_squared_error: 0.9736 - val_mean_absolute_error: 0.7554 - val_r_square: 0.1570
# Epoch 16/40
# 312294/312294 [==============================] - 647s 2ms/step - loss: 0.9546 - root_mean_squared_error: 0.9770 - mean_absolute_error: 0.7595 - r_square: 0.1513 - val_loss: 0.9480 - val_root_mean_squared_error: 0.9737 - val_mean_absolute_error: 0.7541 - val_r_square: 0.1570
# Epoch 17/40
# 312294/312294 [==============================] - 647s 2ms/step - loss: 0.9535 - root_mean_squared_error: 0.9765 - mean_absolute_error: 0.7589 - r_square: 0.1524 - val_loss: 0.9466 - val_root_mean_squared_error: 0.9729 - val_mean_absolute_error: 0.7593 - val_r_square: 0.1582
# Epoch 18/40
# 312294/312294 [==============================] - 647s 2ms/step - loss: 0.9526 - root_mean_squared_error: 0.9760 - mean_absolute_error: 0.7585 - r_square: 0.1530 - val_loss: 0.9455 - val_root_mean_squared_error: 0.9724 - val_mean_absolute_error: 0.7560 - val_r_square: 0.1592
# Epoch 19/40
# 312294/312294 [==============================] - 647s 2ms/step - loss: 0.9516 - root_mean_squared_error: 0.9755 - mean_absolute_error: 0.7580 - r_square: 0.1542 - val_loss: 0.9509 - val_root_mean_squared_error: 0.9751 - val_mean_absolute_error: 0.7601 - val_r_square: 0.1544
# Epoch 20/40
# 312294/312294 [==============================] - 647s 2ms/step - loss: 0.9508 - root_mean_squared_error: 0.9751 - mean_absolute_error: 0.7576 - r_square: 0.1548 - val_loss: 0.9443 - val_root_mean_squared_error: 0.9717 - val_mean_absolute_error: 0.7579 - val_r_square: 0.1603
# Epoch 21/40
# 312294/312294 [==============================] - 647s 2ms/step - loss: 0.9501 - root_mean_squared_error: 0.9747 - mean_absolute_error: 0.7572 - r_square: 0.1553 - val_loss: 0.9420 - val_root_mean_squared_error: 0.9706 - val_mean_absolute_error: 0.7547 - val_r_square: 0.1623
# Epoch 22/40
# 312294/312294 [==============================] - 647s 2ms/step - loss: 0.9493 - root_mean_squared_error: 0.9743 - mean_absolute_error: 0.7568 - r_square: 0.1561 - val_loss: 0.9492 - val_root_mean_squared_error: 0.9743 - val_mean_absolute_error: 0.7606 - val_r_square: 0.1559
# Epoch 23/40
# 312294/312294 [==============================] - 647s 2ms/step - loss: 0.9486 - root_mean_squared_error: 0.9740 - mean_absolute_error: 0.7564 - r_square: 0.1567 - val_loss: 0.9466 - val_root_mean_squared_error: 0.9729 - val_mean_absolute_error: 0.7595 - val_r_square: 0.1582
# Epoch 24/40
# 312294/312294 [==============================] - 647s 2ms/step - loss: 0.9479 - root_mean_squared_error: 0.9736 - mean_absolute_error: 0.7561 - r_square: 0.1569 - val_loss: 0.9406 - val_root_mean_squared_error: 0.9698 - val_mean_absolute_error: 0.7548 - val_r_square: 0.1636
# Epoch 25/40
# 312294/312294 [==============================] - 647s 2ms/step - loss: 0.9473 - root_mean_squared_error: 0.9733 - mean_absolute_error: 0.7558 - r_square: 0.1577 - val_loss: 0.9411 - val_root_mean_squared_error: 0.9701 - val_mean_absolute_error: 0.7548 - val_r_square: 0.1631
# Epoch 26/40
# 312294/312294 [==============================] - 645s 2ms/step - loss: 0.9467 - root_mean_squared_error: 0.9730 - mean_absolute_error: 0.7555 - r_square: 0.1581 - val_loss: 0.9421 - val_root_mean_squared_error: 0.9706 - val_mean_absolute_error: 0.7555 - val_r_square: 0.1623
# Epoch 27/40
# 312294/312294 [==============================] - 646s 2ms/step - loss: 0.9461 - root_mean_squared_error: 0.9727 - mean_absolute_error: 0.7552 - r_square: 0.1587 - val_loss: 0.9508 - val_root_mean_squared_error: 0.9751 - val_mean_absolute_error: 0.7612 - val_r_square: 0.1545
# Epoch 28/40
# 312294/312294 [==============================] - 646s 2ms/step - loss: 0.9457 - root_mean_squared_error: 0.9725 - mean_absolute_error: 0.7550 - r_square: 0.1590 - val_loss: 0.9446 - val_root_mean_squared_error: 0.9719 - val_mean_absolute_error: 0.7577 - val_r_square: 0.1600
# Epoch 29/40
# 312294/312294 [==============================] - 646s 2ms/step - loss: 0.9451 - root_mean_squared_error: 0.9722 - mean_absolute_error: 0.7547 - r_square: 0.1596 - val_loss: 0.9414 - val_root_mean_squared_error: 0.9702 - val_mean_absolute_error: 0.7560 - val_r_square: 0.1629
# Epoch 30/40
# 312294/312294 [==============================] - 645s 2ms/step - loss: 0.9447 - root_mean_squared_error: 0.9720 - mean_absolute_error: 0.7545 - r_square: 0.1600 - val_loss: 0.9388 - val_root_mean_squared_error: 0.9689 - val_mean_absolute_error: 0.7512 - val_r_square: 0.1652
# Epoch 31/40
# 312294/312294 [==============================] - 645s 2ms/step - loss: 0.9442 - root_mean_squared_error: 0.9717 - mean_absolute_error: 0.7542 - r_square: 0.1609 - val_loss: 0.9399 - val_root_mean_squared_error: 0.9695 - val_mean_absolute_error: 0.7550 - val_r_square: 0.1642
# Epoch 32/40
# 312294/312294 [==============================] - 646s 2ms/step - loss: 0.9438 - root_mean_squared_error: 0.9715 - mean_absolute_error: 0.7540 - r_square: 0.1610 - val_loss: 0.9373 - val_root_mean_squared_error: 0.9682 - val_mean_absolute_error: 0.7510 - val_r_square: 0.1665
# Epoch 33/40
# 312294/312294 [==============================] - 645s 2ms/step - loss: 0.9434 - root_mean_squared_error: 0.9713 - mean_absolute_error: 0.7538 - r_square: 0.1610 - val_loss: 0.9389 - val_root_mean_squared_error: 0.9690 - val_mean_absolute_error: 0.7538 - val_r_square: 0.1651
# Epoch 34/40
# 312294/312294 [==============================] - 646s 2ms/step - loss: 0.9430 - root_mean_squared_error: 0.9711 - mean_absolute_error: 0.7536 - r_square: 0.1615 - val_loss: 0.9400 - val_root_mean_squared_error: 0.9695 - val_mean_absolute_error: 0.7532 - val_r_square: 0.1641
# Epoch 35/40
# 312294/312294 [==============================] - 645s 2ms/step - loss: 0.9426 - root_mean_squared_error: 0.9709 - mean_absolute_error: 0.7534 - r_square: 0.1615 - val_loss: 0.9420 - val_root_mean_squared_error: 0.9706 - val_mean_absolute_error: 0.7570 - val_r_square: 0.1623
# Epoch 36/40
# 312294/312294 [==============================] - 645s 2ms/step - loss: 0.9422 - root_mean_squared_error: 0.9707 - mean_absolute_error: 0.7532 - r_square: 0.1623 - val_loss: 0.9387 - val_root_mean_squared_error: 0.9689 - val_mean_absolute_error: 0.7544 - val_r_square: 0.1653
# Epoch 37/40
# 312294/312294 [==============================] - 646s 2ms/step - loss: 0.9419 - root_mean_squared_error: 0.9705 - mean_absolute_error: 0.7531 - r_square: 0.1624 - val_loss: 0.9351 - val_root_mean_squared_error: 0.9670 - val_mean_absolute_error: 0.7490 - val_r_square: 0.1685
# Epoch 38/40
# 312294/312294 [==============================] - 647s 2ms/step - loss: 0.9415 - root_mean_squared_error: 0.9703 - mean_absolute_error: 0.7529 - r_square: 0.1626 - val_loss: 0.9364 - val_root_mean_squared_error: 0.9677 - val_mean_absolute_error: 0.7519 - val_r_square: 0.1673
# Epoch 39/40
# 312294/312294 [==============================] - 646s 2ms/step - loss: 0.9413 - root_mean_squared_error: 0.9702 - mean_absolute_error: 0.7527 - r_square: 0.1632 - val_loss: 0.9482 - val_root_mean_squared_error: 0.9737 - val_mean_absolute_error: 0.7576 - val_r_square: 0.1569
# Epoch 40/40
# 312294/312294 [==============================] - 646s 2ms/step - loss: 0.9410 - root_mean_squared_error: 0.9700 - mean_absolute_error: 0.7525 - r_square: 0.1633 - val_loss: 0.9356 - val_root_mean_squared_error: 0.9673 - val_mean_absolute_error: 0.7516 - val_r_square: 0.1680

# %% [markdown]
# #### After fitting

# %%
metric_name = ['Loss', 'RootMSE', 'MAE', 'R2']
train_metric = ['loss', 'root_mean_squared_error', 'mean_absolute_error', 'r_square']
val_metric = ['val_loss', 'val_root_mean_squared_error', 'val_mean_absolute_error', 'val_r_square']

for i in range(len(metric_name)):

  print(f"\n----------- {metric_name[i]} chart -----------\n")

  # matplotlib chart
  plt.plot(trained_model.history[train_metric[i]], label=f"Train {metric_name[i]}")
  plt.plot(trained_model.history[val_metric[i]], label=f"Val {metric_name[i]}")
  plt.legend()
  plt.show()
# Out:
# ----------- Loss chart -----------
# ----------- RootMSE chart -----------
# ----------- MAE chart -----------
# ----------- R2 chart -----------

# %%
# Validation data values in the last epoch
print("number of epochs:", trained_model.epoch[-1] + 1)
print("val_loss:", trained_model.history['val_loss'][-1])
print("val_root_mean_squared_error:", trained_model.history['val_root_mean_squared_error'][-1])
print("val_mean_absolute_error:", trained_model.history['val_mean_absolute_error'][-1])
print("val_r2_score:", trained_model.history['val_r_square'][-1])
# Out:
# number of epochs: 40
# val_loss: 0.9356333613395691
# val_root_mean_squared_error: 0.9672814011573792
# val_mean_absolute_error: 0.7515869140625
# val_r2_score: 0.16799306869506836

# %%
# Evaluate the model on the test data
print("Evaluate on test data")
test_loss, test_mean_squared_error, test_mean_absolute_error, test_r2_score = my_model.evaluate(test_data, test_target_ratings)
print("Test_loss:", test_loss)
print("Test_root_mean_squared_error:", test_mean_squared_error)
print("Test_mean_absolute_error:", test_mean_absolute_error)
print("Test_r2_score:", test_r2_score)
print('\n')

print("Generate predictions for 10 samples")
predictions = my_model.predict(test_data)
test_y_comparison = pd.DataFrame({'test_y_true': test_target_ratings, 'test_y_pred': [x for x in predictions]})

print(test_y_comparison.head(10))
# Out:
# Evaluate on test data
# 78074/78074 [==============================] - 108s 1ms/step - loss: 0.9607 - root_mean_squared_error: 0.9802 - mean_absolute_error: 0.7625 - r_square: 0.1469
# Test_loss: 0.9607458710670471
# Test_root_mean_squared_error: 0.9801764488220215
# Test_mean_absolute_error: 0.7624932527542114
# Test_r2_score: 0.1469329595565796
#
#
# Generate predictions for 10 samples
# 78074/78074 [==============================] - 60s 771us/step
#    test_y_true  test_y_pred
# 0          4.0  [3.5387905]
# 1          4.5  [3.8628702]
# 2          2.5  [3.0565794]
# 3          4.5  [3.6448276]
# 4          3.5  [4.1324835]
# 5          3.5  [3.1636982]
# 6          3.0  [3.7401915]
# 7          3.0  [3.1665974]
# 8          4.0  [4.1395826]
# 9          1.5   [3.014216]

# %%
if wandb_log:
  wandb.finish()
# Out:
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch/epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>epoch/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/loss</td><td>█▆▅▅▄▄▄▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/mean_absolute_error</td><td>█▆▅▅▄▄▄▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/r_square</td><td>▁▃▄▄▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇███████████████</td></tr><tr><td>epoch/root_mean_squared_error</td><td>█▆▅▅▄▄▄▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/val_loss</td><td>█▇▆▅▅▅▄▄▃▃▃▅▃▅▂▂▂▂▃▂▂▃▂▂▂▂▃▂▂▁▂▁▁▂▂▁▁▁▂▁</td></tr><tr><td>epoch/val_mean_absolute_error</td><td>█▇█▅▆▆▅▄▄▃▄▇▃▆▂▂▃▂▃▃▂▃▃▂▂▂▄▃▂▁▂▁▂▂▃▂▁▂▃▂</td></tr><tr><td>epoch/val_r_square</td><td>▁▂▃▄▄▄▅▅▆▆▆▄▆▄▇▇▇▇▆▇▇▆▇▇▇▇▆▇▇█▇██▇▇███▇█</td></tr><tr><td>epoch/val_root_mean_squared_error</td><td>█▇▆▅▅▅▄▄▃▃▃▅▃▅▂▂▂▂▃▂▂▃▂▂▂▂▃▂▂▁▂▁▁▂▂▁▁▁▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/epoch</td><td>39</td></tr><tr><td>epoch/learning_rate</td><td>0.01</td></tr><tr><td>epoch/loss</td><td>0.94096</td></tr><tr><td>epoch/mean_absolute_error</td><td>0.75255</td></tr><tr><td>epoch/r_square</td><td>0.16335</td></tr><tr><td>epoch/root_mean_squared_error</td><td>0.97003</td></tr><tr><td>epoch/val_loss</td><td>0.93563</td></tr><tr><td>epoch/val_mean_absolute_error</td><td>0.75159</td></tr><tr><td>epoch/val_r_square</td><td>0.16799</td></tr><tr><td>epoch/val_root_mean_squared_error</td><td>0.96728</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">arch10_25m_dded_imdb_context_max_abs_scaler_gc_4</strong> at: <a href='https://wandb.ai/xbarantomik/dp/runs/57v9z8a7' target="_blank">https://wandb.ai/xbarantomik/dp/runs/57v9z8a7</a><br/> View project at: <a href='https://wandb.ai/xbarantomik/dp' target="_blank">https://wandb.ai/xbarantomik/dp</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240502_022924-57v9z8a7/logs</code>
