# %% [markdown]
# ## Experiment 4 - Architecture 8 - 25m Added IMDb Context

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import load_model
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json
# Out:
# 2024-05-09 01:33:42.756354: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-09 01:33:42.873633: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-09 01:33:43.366538: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/baran-tomik/bin/miniconda3/envs/tf/lib/
# 2024-05-09 01:33:43.366639: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/baran-tomik/bin/miniconda3/envs/tf/lib/
# 2024-05-09 01:33:43.366645: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
checkpoint_model_filepath = 'checkpoints/'
trained_model_filepath = 'trained_models/'
training_data_path = 'data_25m/'
nn_config_path = '../config/nn_config_exp5.json'
wandb_config_path = '../config/wandb_config.json'

print('Training data path:', training_data_path)

import nn_model
# Out:
# Training data path: data_25m/
# /home/baran-tomik/bin/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# /home/baran-tomik/bin/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.13.0 and strictly below 2.16.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.10.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
try:
  with open(wandb_config_path, 'r') as f:
    wandb_config = json.load(f)

  wandb_log = True
  wandb_run_name = wandb_config["wandb_run_name"]
  wandb_group_name = wandb_config["wandb_group_name"]
  wandb_entity = wandb_config["wandb_entity"]
  wandb_project_name = wandb_config["wandb_project_name"]
  if wandb_config["new_model"] == 'false':
    new_model = False
  else:
    new_model = True
  run_name_before = wandb_config["run_name_before"]   # Model to be loaded
  if wandb_config["eval_only"] == 'false':
    eval_only = False
  else:
    eval_only = True

  print('wandb_log:', wandb_log)
  print('wandb_run_name:', wandb_run_name)
  print('wandb_group_name:', wandb_group_name)
  print('wandb_entity:', wandb_entity)
  print('wandb_project_name:', wandb_project_name)
  print('new_model:', new_model)
  print('run_name_before:', run_name_before)
  print('eval_only:', eval_only)

except OSError as e:
  print('\nERROR loading wandb_config file')
  print(e)
  # quit()
# Out:
# wandb_log: True
# wandb_run_name: arch8_exp5_25m_added_imdb_context_max_abs_scaler_gn
# wandb_group_name: 25m_deep_dense
# wandb_entity: xbarantomik
# wandb_project_name: DP
# new_model: True
# run_name_before: -
# eval_only: False

# %%
try:
  with open(nn_config_path, 'r') as f:
    nn_config = json.load(f)

  epochs = int(nn_config['epochs'])
  batch_size = int(nn_config['batch_size'])
  patience = int(nn_config['patience'])
  learning_rate = float(nn_config['learning_rate'])
  architecture = int(nn_config['architecture'])
  training_data_file = nn_config['training_data_file'] + '/'

  print('epochs:', epochs)
  print('batch_size:', batch_size)
  print('patience:', patience)
  print('learning_rate:', learning_rate)
  print('architecture:', architecture)
  print('training_data_file:', training_data_file)

except OSError as e:
  print('\nERROR loading nn_config file')
  print(e)
# Out:
# epochs: 25
# batch_size: 128
# patience: 15
# learning_rate: 0.001
# architecture: 8
# training_data_file: added_imdb_context_max_abs_scaler/

# %% [markdown]
# #### Load training data

# %%
try:
  train_data = np.load(training_data_path + training_data_file + 'train_data.npy')
  val_data = np.load(training_data_path + training_data_file + 'val_data.npy')
  test_data = np.load(training_data_path + training_data_file + 'test_data.npy')
  train_target_ratings = np.load(training_data_path + training_data_file + 'train_target_ratings.npy')
  val_target_ratings = np.load(training_data_path + training_data_file + 'val_target_ratings.npy')
  test_target_ratings = np.load(training_data_path + training_data_file + 'test_target_ratings.npy')

except OSError as e:
  print('\nERROR loading training data')
  print(e)
  quit()

# %%
if wandb_log:
  import wandb
  from wandb.keras import WandbMetricsLogger, WandbModelCheckpoint

  wandb.login()

  wandb.init(
    config=nn_config,
    entity=wandb_entity,
    project=wandb_project_name,
    name=wandb_run_name,
    group=wandb_group_name
  )
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: xbarantomik. Use `wandb login --relogin` to force relogin
# wandb version 0.17.0 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/home/baran-tomik/projects/DP/training/wandb/run-20240509_013402-ac0yq11v</code>
# Syncing run <strong><a href='https://wandb.ai/xbarantomik/dp/runs/ac0yq11v' target="_blank">arch8_exp5_25m_added_imdb_context_max_abs_scaler_gn</a></strong> to <a href='https://wandb.ai/xbarantomik/dp' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/xbarantomik/dp' target="_blank">https://wandb.ai/xbarantomik/dp</a>
#  View run at <a href='https://wandb.ai/xbarantomik/dp/runs/ac0yq11v' target="_blank">https://wandb.ai/xbarantomik/dp/runs/ac0yq11v</a>

# %% [markdown]
# #### NN MODEL

# %%
early_stopping = EarlyStopping(patience=patience, monitor='val_loss')

# %%
checkpoint_filepath = checkpoint_model_filepath + f"{wandb_run_name}_checkpoint.h5"
checkpoint_callback = ModelCheckpoint(filepath=checkpoint_filepath, monitor='val_loss', save_best_only=True, mode='min', save_weights_only=False, save_format='tf')

if wandb_log:
  callbacks = [early_stopping, checkpoint_callback, WandbMetricsLogger()]
else:
  callbacks = [early_stopping, checkpoint_callback]

# %% [markdown]
# #### Create model

# %%
if new_model:
  my_model = nn_model.create_model(architecture=architecture, lr=learning_rate, train_data_shape=train_data.shape[1])
  print('\nCreated a new model')
else:
  my_model = load_model(checkpoint_model_filepath + run_name_before + '_checkpoint.h5')
  print('\nLoaded a model')

if my_model != None:
  my_model.summary()
else:
  print('\nERROR loading NN model')
  quit()
# Out:
# Model 8
#
# Created a new model
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# 2024-05-09 01:34:07.050894: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-09 01:34:07.075429: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-09 01:34:07.075667: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-09 01:34:07.076287: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-09 01:34:07.076940: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-09 01:34:07.077147: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-09 01:34:07.077329: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-09 01:34:07.163014: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-09 01:34:07.163204: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-09 01:34:07.163333: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-09 01:34:07.163443: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7511 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1070, pci bus id: 0000:01:00.0, compute capability: 6.1
# =================================================================
#  dense (Dense)               (None, 512)               21504
#
#  activation (Activation)     (None, 512)               0
#
#  dropout (Dropout)           (None, 512)               0
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  activation_1 (Activation)   (None, 512)               0
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 512)               262656
#
#  activation_2 (Activation)   (None, 512)               0
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 256)               131328
#
#  activation_3 (Activation)   (None, 256)               0
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 256)               65792
#
#  activation_4 (Activation)   (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 1)                 257
#
#  activation_5 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 744,193
# Trainable params: 744,193
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Model fitting

# %%
if not eval_only:
  print('Training model')
  trained_model = my_model.fit(train_data, train_target_ratings, batch_size, epochs, validation_data=(val_data, val_target_ratings), callbacks=callbacks, verbose=1)
  my_model.save(trained_model_filepath + f"{wandb_run_name}_trained.keras")
else:
  print('Only evaluating model')
# Out:
# Training model
# 2024-05-09 01:34:08.452783: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 3277831100 exceeds 10% of free system memory.
# 2024-05-09 01:34:10.430728: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 3277831100 exceeds 10% of free system memory.
# Epoch 1/25
# 156147/156147 [==============================] - 371s 2ms/step - loss: 1.0345 - root_mean_squared_error: 1.0171 - mean_absolute_error: 0.7980 - r_square: 0.0803 - val_loss: 0.9865 - val_root_mean_squared_error: 0.9932 - val_mean_absolute_error: 0.7764 - val_r_square: 0.1226
# Epoch 2/25
# 156147/156147 [==============================] - 371s 2ms/step - loss: 0.9896 - root_mean_squared_error: 0.9948 - mean_absolute_error: 0.7761 - r_square: 0.1201 - val_loss: 0.9708 - val_root_mean_squared_error: 0.9853 - val_mean_absolute_error: 0.7713 - val_r_square: 0.1366
# Epoch 3/25
# 156147/156147 [==============================] - 371s 2ms/step - loss: 0.9773 - root_mean_squared_error: 0.9886 - mean_absolute_error: 0.7702 - r_square: 0.1310 - val_loss: 0.9607 - val_root_mean_squared_error: 0.9802 - val_mean_absolute_error: 0.7621 - val_r_square: 0.1456
# Epoch 4/25
# 156147/156147 [==============================] - 371s 2ms/step - loss: 0.9704 - root_mean_squared_error: 0.9851 - mean_absolute_error: 0.7668 - r_square: 0.1373 - val_loss: 0.9531 - val_root_mean_squared_error: 0.9762 - val_mean_absolute_error: 0.7570 - val_r_square: 0.1524
# Epoch 5/25
# 156147/156147 [==============================] - 371s 2ms/step - loss: 0.9655 - root_mean_squared_error: 0.9826 - mean_absolute_error: 0.7643 - r_square: 0.1417 - val_loss: 0.9492 - val_root_mean_squared_error: 0.9743 - val_mean_absolute_error: 0.7564 - val_r_square: 0.1558
# Epoch 6/25
# 156147/156147 [==============================] - 371s 2ms/step - loss: 0.9620 - root_mean_squared_error: 0.9808 - mean_absolute_error: 0.7625 - r_square: 0.1444 - val_loss: 0.9465 - val_root_mean_squared_error: 0.9729 - val_mean_absolute_error: 0.7539 - val_r_square: 0.1583
# Epoch 7/25
# 156147/156147 [==============================] - 372s 2ms/step - loss: 0.9596 - root_mean_squared_error: 0.9796 - mean_absolute_error: 0.7613 - r_square: 0.1467 - val_loss: 0.9449 - val_root_mean_squared_error: 0.9721 - val_mean_absolute_error: 0.7551 - val_r_square: 0.1597
# Epoch 8/25
# 156147/156147 [==============================] - 371s 2ms/step - loss: 0.9575 - root_mean_squared_error: 0.9785 - mean_absolute_error: 0.7602 - r_square: 0.1486 - val_loss: 0.9436 - val_root_mean_squared_error: 0.9714 - val_mean_absolute_error: 0.7553 - val_r_square: 0.1608
# Epoch 9/25
# 156147/156147 [==============================] - 372s 2ms/step - loss: 0.9560 - root_mean_squared_error: 0.9778 - mean_absolute_error: 0.7595 - r_square: 0.1501 - val_loss: 0.9431 - val_root_mean_squared_error: 0.9711 - val_mean_absolute_error: 0.7555 - val_r_square: 0.1613
# Epoch 10/25
# 156147/156147 [==============================] - 373s 2ms/step - loss: 0.9548 - root_mean_squared_error: 0.9771 - mean_absolute_error: 0.7589 - r_square: 0.1511 - val_loss: 0.9414 - val_root_mean_squared_error: 0.9702 - val_mean_absolute_error: 0.7541 - val_r_square: 0.1628
# Epoch 11/25
# 156147/156147 [==============================] - 373s 2ms/step - loss: 0.9536 - root_mean_squared_error: 0.9765 - mean_absolute_error: 0.7583 - r_square: 0.1522 - val_loss: 0.9417 - val_root_mean_squared_error: 0.9704 - val_mean_absolute_error: 0.7534 - val_r_square: 0.1625
# Epoch 12/25
# 156147/156147 [==============================] - 370s 2ms/step - loss: 0.9528 - root_mean_squared_error: 0.9761 - mean_absolute_error: 0.7579 - r_square: 0.1529 - val_loss: 0.9389 - val_root_mean_squared_error: 0.9690 - val_mean_absolute_error: 0.7512 - val_r_square: 0.1650
# Epoch 13/25
# 156147/156147 [==============================] - 371s 2ms/step - loss: 0.9521 - root_mean_squared_error: 0.9758 - mean_absolute_error: 0.7576 - r_square: 0.1536 - val_loss: 0.9385 - val_root_mean_squared_error: 0.9688 - val_mean_absolute_error: 0.7502 - val_r_square: 0.1654
# Epoch 14/25
# 156147/156147 [==============================] - 369s 2ms/step - loss: 0.9514 - root_mean_squared_error: 0.9754 - mean_absolute_error: 0.7571 - r_square: 0.1540 - val_loss: 0.9382 - val_root_mean_squared_error: 0.9686 - val_mean_absolute_error: 0.7513 - val_r_square: 0.1656
# Epoch 15/25
# 156147/156147 [==============================] - 370s 2ms/step - loss: 0.9508 - root_mean_squared_error: 0.9751 - mean_absolute_error: 0.7569 - r_square: 0.1545 - val_loss: 0.9384 - val_root_mean_squared_error: 0.9687 - val_mean_absolute_error: 0.7515 - val_r_square: 0.1654
# Epoch 16/25
# 156147/156147 [==============================] - 370s 2ms/step - loss: 0.9504 - root_mean_squared_error: 0.9749 - mean_absolute_error: 0.7567 - r_square: 0.1550 - val_loss: 0.9377 - val_root_mean_squared_error: 0.9684 - val_mean_absolute_error: 0.7510 - val_r_square: 0.1660
# Epoch 17/25
# 156147/156147 [==============================] - 369s 2ms/step - loss: 0.9500 - root_mean_squared_error: 0.9747 - mean_absolute_error: 0.7564 - r_square: 0.1553 - val_loss: 0.9384 - val_root_mean_squared_error: 0.9687 - val_mean_absolute_error: 0.7504 - val_r_square: 0.1654
# Epoch 18/25
# 156147/156147 [==============================] - 370s 2ms/step - loss: 0.9496 - root_mean_squared_error: 0.9745 - mean_absolute_error: 0.7563 - r_square: 0.1559 - val_loss: 0.9367 - val_root_mean_squared_error: 0.9678 - val_mean_absolute_error: 0.7500 - val_r_square: 0.1669
# Epoch 19/25
# 156147/156147 [==============================] - 369s 2ms/step - loss: 0.9493 - root_mean_squared_error: 0.9743 - mean_absolute_error: 0.7561 - r_square: 0.1559 - val_loss: 0.9366 - val_root_mean_squared_error: 0.9678 - val_mean_absolute_error: 0.7518 - val_r_square: 0.1670
# Epoch 20/25
# 156147/156147 [==============================] - 374s 2ms/step - loss: 0.9489 - root_mean_squared_error: 0.9741 - mean_absolute_error: 0.7559 - r_square: 0.1561 - val_loss: 0.9371 - val_root_mean_squared_error: 0.9680 - val_mean_absolute_error: 0.7523 - val_r_square: 0.1666
# Epoch 21/25
# 156147/156147 [==============================] - 372s 2ms/step - loss: 0.9487 - root_mean_squared_error: 0.9740 - mean_absolute_error: 0.7558 - r_square: 0.1566 - val_loss: 0.9378 - val_root_mean_squared_error: 0.9684 - val_mean_absolute_error: 0.7512 - val_r_square: 0.1660
# Epoch 22/25
# 156147/156147 [==============================] - 370s 2ms/step - loss: 0.9486 - root_mean_squared_error: 0.9739 - mean_absolute_error: 0.7558 - r_square: 0.1565 - val_loss: 0.9362 - val_root_mean_squared_error: 0.9676 - val_mean_absolute_error: 0.7505 - val_r_square: 0.1674
# Epoch 23/25
# 156147/156147 [==============================] - 371s 2ms/step - loss: 0.9484 - root_mean_squared_error: 0.9739 - mean_absolute_error: 0.7557 - r_square: 0.1565 - val_loss: 0.9378 - val_root_mean_squared_error: 0.9684 - val_mean_absolute_error: 0.7523 - val_r_square: 0.1660
# Epoch 24/25
# 156147/156147 [==============================] - 372s 2ms/step - loss: 0.9482 - root_mean_squared_error: 0.9738 - mean_absolute_error: 0.7556 - r_square: 0.1568 - val_loss: 0.9380 - val_root_mean_squared_error: 0.9685 - val_mean_absolute_error: 0.7531 - val_r_square: 0.1658
# Epoch 25/25
# 156147/156147 [==============================] - 372s 2ms/step - loss: 0.9480 - root_mean_squared_error: 0.9736 - mean_absolute_error: 0.7554 - r_square: 0.1574 - val_loss: 0.9379 - val_root_mean_squared_error: 0.9684 - val_mean_absolute_error: 0.7533 - val_r_square: 0.1659

# %% [markdown]
# #### After fitting

# %%
metric_name = ['Loss', 'RootMSE', 'MAE', 'R2']
train_metric = ['loss', 'root_mean_squared_error', 'mean_absolute_error', 'r_square']
val_metric = ['val_loss', 'val_root_mean_squared_error', 'val_mean_absolute_error', 'val_r_square']

for i in range(len(metric_name)):

  print(f"\n----------- {metric_name[i]} chart -----------\n")

  # matplotlib chart
  plt.plot(trained_model.history[train_metric[i]], label=f"Train {metric_name[i]}")
  plt.plot(trained_model.history[val_metric[i]], label=f"Val {metric_name[i]}")
  plt.legend()
  plt.show()
# Out:
# ----------- Loss chart -----------
# ----------- RootMSE chart -----------
# ----------- MAE chart -----------
# ----------- R2 chart -----------

# %%
# Validation data values in the last epoch
print("number of epochs:", trained_model.epoch[-1] + 1)
print("val_loss:", trained_model.history['val_loss'][-1])
print("val_root_mean_squared_error:", trained_model.history['val_root_mean_squared_error'][-1])
print("val_mean_absolute_error:", trained_model.history['val_mean_absolute_error'][-1])
print("val_r2_score:", trained_model.history['val_r_square'][-1])
# Out:
# number of epochs: 25
# val_loss: 0.9378895163536072
# val_root_mean_squared_error: 0.9684469699859619
# val_mean_absolute_error: 0.7532984614372253
# val_r2_score: 0.16589176654815674

# %%
# Evaluate the model on the test data
print("Evaluate on test data")
test_loss, test_mean_squared_error, test_mean_absolute_error, test_r2_score = my_model.evaluate(test_data, test_target_ratings)
print("Test_loss:", test_loss)
print("Test_root_mean_squared_error:", test_mean_squared_error)
print("Test_mean_absolute_error:", test_mean_absolute_error)
print("Test_r2_score:", test_r2_score)
print('\n')

print("Generate predictions for 10 samples")
predictions = my_model.predict(test_data)
test_y_comparison = pd.DataFrame({'test_y_true': test_target_ratings, 'test_y_pred': [x for x in predictions]})

print(test_y_comparison.head(10))
# Out:
# Evaluate on test data
# 78074/78074 [==============================] - 110s 1ms/step - loss: 0.9547 - root_mean_squared_error: 0.9771 - mean_absolute_error: 0.7608 - r_square: 0.1523
# Test_loss: 0.9546607136726379
# Test_root_mean_squared_error: 0.9770674109458923
# Test_mean_absolute_error: 0.7608171701431274
# Test_r2_score: 0.15233606100082397
#
#
# Generate predictions for 10 samples
# 78074/78074 [==============================] - 61s 782us/step
#    test_y_true  test_y_pred
# 0          4.0   [3.469119]
# 1          4.5  [3.8540463]
# 2          2.5  [2.9476447]
# 3          4.5    [3.67726]
# 4          3.5  [4.0223484]
# 5          3.5   [3.345128]
# 6          3.0  [3.7274928]
# 7          3.0  [2.9915988]
# 8          4.0   [4.000349]
# 9          1.5  [3.0344965]

# %%
if wandb_log:
  wandb.finish()
# Out:
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch/epoch</td><td>▁▁▂▂▂▂▃▃▃▄▄▄▅▅▅▅▆▆▆▇▇▇▇██</td></tr><tr><td>epoch/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/loss</td><td>█▄▃▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/mean_absolute_error</td><td>█▄▃▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/r_square</td><td>▁▅▆▆▇▇▇▇▇▇███████████████</td></tr><tr><td>epoch/root_mean_squared_error</td><td>█▄▃▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/val_loss</td><td>█▆▄▃▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/val_mean_absolute_error</td><td>█▇▄▃▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▂▁▁▂▂▂</td></tr><tr><td>epoch/val_r_square</td><td>▁▃▅▆▆▇▇▇▇▇▇██████████████</td></tr><tr><td>epoch/val_root_mean_squared_error</td><td>█▆▄▃▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/epoch</td><td>24</td></tr><tr><td>epoch/learning_rate</td><td>0.001</td></tr><tr><td>epoch/loss</td><td>0.94797</td></tr><tr><td>epoch/mean_absolute_error</td><td>0.75537</td></tr><tr><td>epoch/r_square</td><td>0.15736</td></tr><tr><td>epoch/root_mean_squared_error</td><td>0.97364</td></tr><tr><td>epoch/val_loss</td><td>0.93789</td></tr><tr><td>epoch/val_mean_absolute_error</td><td>0.7533</td></tr><tr><td>epoch/val_r_square</td><td>0.16589</td></tr><tr><td>epoch/val_root_mean_squared_error</td><td>0.96845</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">arch8_exp5_25m_added_imdb_context_max_abs_scaler_gn</strong> at: <a href='https://wandb.ai/xbarantomik/dp/runs/ac0yq11v' target="_blank">https://wandb.ai/xbarantomik/dp/runs/ac0yq11v</a><br/> View project at: <a href='https://wandb.ai/xbarantomik/dp' target="_blank">https://wandb.ai/xbarantomik/dp</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240509_013402-ac0yq11v/logs</code>
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
