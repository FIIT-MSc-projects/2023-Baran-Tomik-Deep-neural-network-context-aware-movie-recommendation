# %% [markdown]
# ## Experiment 4 - Architecture 6 - Exponential learning rate scheduler - 25m Added IMDb Context

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import load_model
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import numpy as np
import json
# Out:
# 2024-05-09 11:13:26.008349: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-09 11:13:26.151177: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-09 11:13:27.065596: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/baran-tomik/bin/miniconda3/envs/tf/lib/
# 2024-05-09 11:13:27.065681: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/baran-tomik/bin/miniconda3/envs/tf/lib/
# 2024-05-09 11:13:27.065688: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
checkpoint_model_filepath = 'checkpoints/'
trained_model_filepath = 'trained_models/'
training_data_path = 'data_25m/'
nn_config_path = '../config/nn_config_exp5.json'
wandb_config_path = '../config/wandb_config.json'

print('Training data path:', training_data_path)

import nn_model
# Out:
# Training data path: data_25m/
# /home/baran-tomik/bin/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# /home/baran-tomik/bin/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.13.0 and strictly below 2.16.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.10.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
try:
  with open(wandb_config_path, 'r') as f:
    wandb_config = json.load(f)

  wandb_log = True
  wandb_run_name = wandb_config["wandb_run_name"]
  wandb_group_name = wandb_config["wandb_group_name"]
  wandb_entity = wandb_config["wandb_entity"]
  wandb_project_name = wandb_config["wandb_project_name"]
  if wandb_config["new_model"] == 'false':
    new_model = False
  else:
    new_model = True
  run_name_before = wandb_config["run_name_before"]   # Model to be loaded
  if wandb_config["eval_only"] == 'false':
    eval_only = False
  else:
    eval_only = True

  print('wandb_log:', wandb_log)
  print('wandb_run_name:', wandb_run_name)
  print('wandb_group_name:', wandb_group_name)
  print('wandb_entity:', wandb_entity)
  print('wandb_project_name:', wandb_project_name)
  print('new_model:', new_model)
  print('run_name_before:', run_name_before)
  print('eval_only:', eval_only)

except OSError as e:
  print('\nERROR loading wandb_config file')
  print(e)
  # quit()
# Out:
# wandb_log: True
# wandb_run_name: arch6_exp5_25m_added_imdb_context_max_abs_scaler_lr_exp_decay_gn
# wandb_group_name: 25m_deep_dense
# wandb_entity: xbarantomik
# wandb_project_name: DP
# new_model: True
# run_name_before: -
# eval_only: False

# %%
try:
  with open(nn_config_path, 'r') as f:
    nn_config = json.load(f)

  epochs = int(nn_config['epochs'])
  batch_size = int(nn_config['batch_size'])
  patience = int(nn_config['patience'])
  learning_rate = float(nn_config['learning_rate'])
  architecture = int(nn_config['architecture'])
  training_data_file = nn_config['training_data_file'] + '/'

  print('epochs:', epochs)
  print('batch_size:', batch_size)
  print('patience:', patience)
  print('learning_rate:', learning_rate)
  print('architecture:', architecture)
  print('training_data_file:', training_data_file)

except OSError as e:
  print('\nERROR loading nn_config file')
  print(e)
# Out:
# epochs: 25
# batch_size: 128
# patience: 15
# learning_rate: 0.001
# architecture: 6
# training_data_file: added_imdb_context_max_abs_scaler/

# %% [markdown]
# #### Load training data

# %%
try:
  train_data = np.load(training_data_path + training_data_file + 'train_data.npy')
  val_data = np.load(training_data_path + training_data_file + 'val_data.npy')
  test_data = np.load(training_data_path + training_data_file + 'test_data.npy')
  train_target_ratings = np.load(training_data_path + training_data_file + 'train_target_ratings.npy')
  val_target_ratings = np.load(training_data_path + training_data_file + 'val_target_ratings.npy')
  test_target_ratings = np.load(training_data_path + training_data_file + 'test_target_ratings.npy')

except OSError as e:
  print('\nERROR loading training data')
  print(e)
  quit()

# %%
if wandb_log:
  import wandb
  from wandb.keras import WandbMetricsLogger, WandbModelCheckpoint

  wandb.login()

  wandb.init(
    config=nn_config,
    entity=wandb_entity,
    project=wandb_project_name,
    name=wandb_run_name,
    group=wandb_group_name
  )
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: xbarantomik. Use `wandb login --relogin` to force relogin
# wandb version 0.17.0 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/home/baran-tomik/projects/DP/training/wandb/run-20240509_111342-ca4znyov</code>
# Syncing run <strong><a href='https://wandb.ai/xbarantomik/dp/runs/ca4znyov' target="_blank">arch6_exp5_25m_added_imdb_context_max_abs_scaler_lr_exp_decay_gn</a></strong> to <a href='https://wandb.ai/xbarantomik/dp' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/xbarantomik/dp' target="_blank">https://wandb.ai/xbarantomik/dp</a>
#  View run at <a href='https://wandb.ai/xbarantomik/dp/runs/ca4znyov' target="_blank">https://wandb.ai/xbarantomik/dp/runs/ca4znyov</a>

# %% [markdown]
# #### NN MODEL

# %%
early_stopping = EarlyStopping(patience=patience, monitor='val_loss')

# %%
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    learning_rate,
    decay_steps=4,
    decay_rate=0.5,
    staircase=True)
scheduler = tf.keras.callbacks.LearningRateScheduler(lr_schedule)

# %%
checkpoint_filepath = checkpoint_model_filepath + f"{wandb_run_name}_checkpoint.h5"
checkpoint_callback = ModelCheckpoint(filepath=checkpoint_filepath, monitor='val_loss', save_best_only=True, mode='min', save_weights_only=False, save_format='tf')

if wandb_log:
  callbacks = [early_stopping, scheduler, checkpoint_callback, WandbMetricsLogger()]
else:
  callbacks = [early_stopping, scheduler, checkpoint_callback]

# %% [markdown]
# #### Create model

# %%
if new_model:
  my_model = nn_model.create_model(architecture=architecture, lr=lr_schedule, train_data_shape=train_data.shape[1])
  print('\nCreated a new model')
else:
  my_model = load_model(checkpoint_model_filepath + run_name_before + '_checkpoint.h5')
  print('\nLoaded a model')

if my_model != None:
  my_model.summary()
else:
  print('\nERROR loading NN model')
  quit()
# Out:
# Model 6
#
# Created a new model
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               21504
#
#  activation (Activation)     (None, 512)               0
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  activation_1 (Activation)   (None, 512)               0
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 512)               262656
#
#  activation_2 (Activation)   (None, 512)               0
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 256)               131328
#
#  activation_3 (Activation)   (None, 256)               0
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 256)               65792
#
#  activation_4 (Activation)   (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 744,193
# Trainable params: 744,193
# Non-trainable params: 0
# _________________________________________________________________
# 2024-05-09 11:13:47.632603: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-09 11:13:47.656857: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-09 11:13:47.657047: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-09 11:13:47.657411: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-09 11:13:47.657985: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-09 11:13:47.658151: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-09 11:13:47.658288: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-09 11:13:47.719018: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-09 11:13:47.719204: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-09 11:13:47.719328: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-09 11:13:47.719425: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7511 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1070, pci bus id: 0000:01:00.0, compute capability: 6.1

# %% [markdown]
# ## Model fitting

# %%
if not eval_only:
  print('Training model')
  trained_model = my_model.fit(train_data, train_target_ratings, batch_size, epochs, validation_data=(val_data, val_target_ratings), callbacks=callbacks, verbose=1)
  my_model.save(trained_model_filepath + f"{wandb_run_name}_trained.keras")
else:
  print('Only evaluating model')
# Out:
# Training model
# 2024-05-09 11:13:49.005836: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 3277831100 exceeds 10% of free system memory.
# 2024-05-09 11:13:50.891683: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 3277831100 exceeds 10% of free system memory.
# Epoch 1/25
# 156147/156147 [==============================] - 371s 2ms/step - loss: 1.0575 - root_mean_squared_error: 1.0284 - mean_absolute_error: 0.8093 - r_square: 0.0598 - val_loss: 1.0399 - val_root_mean_squared_error: 1.0197 - val_mean_absolute_error: 0.8089 - val_r_square: 0.0752 - lr: 0.0010
# Epoch 2/25
# 156147/156147 [==============================] - 370s 2ms/step - loss: 1.0468 - root_mean_squared_error: 1.0231 - mean_absolute_error: 0.8042 - r_square: 0.0693 - val_loss: 1.0393 - val_root_mean_squared_error: 1.0195 - val_mean_absolute_error: 0.8027 - val_r_square: 0.0757 - lr: 0.0010
# Epoch 3/25
# 156147/156147 [==============================] - 371s 2ms/step - loss: 1.0499 - root_mean_squared_error: 1.0247 - mean_absolute_error: 0.8060 - r_square: 0.0665 - val_loss: 1.0378 - val_root_mean_squared_error: 1.0187 - val_mean_absolute_error: 0.8054 - val_r_square: 0.0771 - lr: 0.0010
# Epoch 4/25
# 156147/156147 [==============================] - 371s 2ms/step - loss: 1.0523 - root_mean_squared_error: 1.0258 - mean_absolute_error: 0.8079 - r_square: 0.0643 - val_loss: 1.0470 - val_root_mean_squared_error: 1.0232 - val_mean_absolute_error: 0.8048 - val_r_square: 0.0689 - lr: 0.0010
# Epoch 5/25
# 156147/156147 [==============================] - 371s 2ms/step - loss: 1.0452 - root_mean_squared_error: 1.0223 - mean_absolute_error: 0.8046 - r_square: 0.0707 - val_loss: 1.0348 - val_root_mean_squared_error: 1.0172 - val_mean_absolute_error: 0.8013 - val_r_square: 0.0797 - lr: 5.0000e-04
# Epoch 6/25
# 156147/156147 [==============================] - 371s 2ms/step - loss: 1.0421 - root_mean_squared_error: 1.0209 - mean_absolute_error: 0.8030 - r_square: 0.0734 - val_loss: 1.0349 - val_root_mean_squared_error: 1.0173 - val_mean_absolute_error: 0.7993 - val_r_square: 0.0796 - lr: 5.0000e-04
# Epoch 7/25
# 156147/156147 [==============================] - 371s 2ms/step - loss: 1.0418 - root_mean_squared_error: 1.0207 - mean_absolute_error: 0.8033 - r_square: 0.0741 - val_loss: 1.0343 - val_root_mean_squared_error: 1.0170 - val_mean_absolute_error: 0.8021 - val_r_square: 0.0802 - lr: 5.0000e-04
# Epoch 8/25
# 156147/156147 [==============================] - 371s 2ms/step - loss: 1.0408 - root_mean_squared_error: 1.0202 - mean_absolute_error: 0.8029 - r_square: 0.0748 - val_loss: 1.0395 - val_root_mean_squared_error: 1.0196 - val_mean_absolute_error: 0.8072 - val_r_square: 0.0755 - lr: 5.0000e-04
# Epoch 9/25
# 156147/156147 [==============================] - 371s 2ms/step - loss: 1.0367 - root_mean_squared_error: 1.0182 - mean_absolute_error: 0.8011 - r_square: 0.0784 - val_loss: 1.0339 - val_root_mean_squared_error: 1.0168 - val_mean_absolute_error: 0.8021 - val_r_square: 0.0805 - lr: 2.5000e-04
# Epoch 10/25
# 156147/156147 [==============================] - 371s 2ms/step - loss: 1.0351 - root_mean_squared_error: 1.0174 - mean_absolute_error: 0.8002 - r_square: 0.0796 - val_loss: 1.0325 - val_root_mean_squared_error: 1.0161 - val_mean_absolute_error: 0.7998 - val_r_square: 0.0818 - lr: 2.5000e-04
# Epoch 11/25
# 156147/156147 [==============================] - 372s 2ms/step - loss: 1.0346 - root_mean_squared_error: 1.0172 - mean_absolute_error: 0.8000 - r_square: 0.0802 - val_loss: 1.0285 - val_root_mean_squared_error: 1.0141 - val_mean_absolute_error: 0.7972 - val_r_square: 0.0853 - lr: 2.5000e-04
# Epoch 12/25
# 156147/156147 [==============================] - 371s 2ms/step - loss: 1.0337 - root_mean_squared_error: 1.0167 - mean_absolute_error: 0.7994 - r_square: 0.0809 - val_loss: 1.0286 - val_root_mean_squared_error: 1.0142 - val_mean_absolute_error: 0.7975 - val_r_square: 0.0852 - lr: 2.5000e-04
# Epoch 13/25
# 156147/156147 [==============================] - 371s 2ms/step - loss: 1.0305 - root_mean_squared_error: 1.0151 - mean_absolute_error: 0.7977 - r_square: 0.0839 - val_loss: 1.0306 - val_root_mean_squared_error: 1.0152 - val_mean_absolute_error: 0.8015 - val_r_square: 0.0834 - lr: 1.2500e-04
# Epoch 14/25
# 156147/156147 [==============================] - 369s 2ms/step - loss: 1.0288 - root_mean_squared_error: 1.0143 - mean_absolute_error: 0.7970 - r_square: 0.0853 - val_loss: 1.0285 - val_root_mean_squared_error: 1.0142 - val_mean_absolute_error: 0.8003 - val_r_square: 0.0853 - lr: 1.2500e-04
# Epoch 15/25
# 156147/156147 [==============================] - 369s 2ms/step - loss: 1.0279 - root_mean_squared_error: 1.0138 - mean_absolute_error: 0.7965 - r_square: 0.0860 - val_loss: 1.0275 - val_root_mean_squared_error: 1.0137 - val_mean_absolute_error: 0.7984 - val_r_square: 0.0862 - lr: 1.2500e-04
# Epoch 16/25
# 156147/156147 [==============================] - 369s 2ms/step - loss: 1.0273 - root_mean_squared_error: 1.0135 - mean_absolute_error: 0.7962 - r_square: 0.0866 - val_loss: 1.0256 - val_root_mean_squared_error: 1.0127 - val_mean_absolute_error: 0.7956 - val_r_square: 0.0879 - lr: 1.2500e-04
# Epoch 17/25
# 156147/156147 [==============================] - 370s 2ms/step - loss: 1.0257 - root_mean_squared_error: 1.0128 - mean_absolute_error: 0.7955 - r_square: 0.0881 - val_loss: 1.0262 - val_root_mean_squared_error: 1.0130 - val_mean_absolute_error: 0.7967 - val_r_square: 0.0874 - lr: 6.2500e-05
# Epoch 18/25
# 156147/156147 [==============================] - 370s 2ms/step - loss: 1.0252 - root_mean_squared_error: 1.0125 - mean_absolute_error: 0.7952 - r_square: 0.0887 - val_loss: 1.0261 - val_root_mean_squared_error: 1.0130 - val_mean_absolute_error: 0.7983 - val_r_square: 0.0875 - lr: 6.2500e-05
# Epoch 19/25
# 156147/156147 [==============================] - 369s 2ms/step - loss: 1.0248 - root_mean_squared_error: 1.0123 - mean_absolute_error: 0.7951 - r_square: 0.0889 - val_loss: 1.0259 - val_root_mean_squared_error: 1.0129 - val_mean_absolute_error: 0.7982 - val_r_square: 0.0876 - lr: 6.2500e-05
# Epoch 20/25
# 156147/156147 [==============================] - 372s 2ms/step - loss: 1.0246 - root_mean_squared_error: 1.0122 - mean_absolute_error: 0.7950 - r_square: 0.0891 - val_loss: 1.0260 - val_root_mean_squared_error: 1.0129 - val_mean_absolute_error: 0.7985 - val_r_square: 0.0875 - lr: 6.2500e-05
# Epoch 21/25
# 156147/156147 [==============================] - 372s 2ms/step - loss: 1.0237 - root_mean_squared_error: 1.0118 - mean_absolute_error: 0.7945 - r_square: 0.0899 - val_loss: 1.0245 - val_root_mean_squared_error: 1.0122 - val_mean_absolute_error: 0.7973 - val_r_square: 0.0888 - lr: 3.1250e-05
# Epoch 22/25
# 156147/156147 [==============================] - 371s 2ms/step - loss: 1.0237 - root_mean_squared_error: 1.0118 - mean_absolute_error: 0.7946 - r_square: 0.0899 - val_loss: 1.0261 - val_root_mean_squared_error: 1.0130 - val_mean_absolute_error: 0.7992 - val_r_square: 0.0874 - lr: 3.1250e-05
# Epoch 23/25
# 156147/156147 [==============================] - 371s 2ms/step - loss: 1.0235 - root_mean_squared_error: 1.0117 - mean_absolute_error: 0.7945 - r_square: 0.0901 - val_loss: 1.0238 - val_root_mean_squared_error: 1.0118 - val_mean_absolute_error: 0.7958 - val_r_square: 0.0895 - lr: 3.1250e-05
# Epoch 24/25
# 156147/156147 [==============================] - 371s 2ms/step - loss: 1.0233 - root_mean_squared_error: 1.0116 - mean_absolute_error: 0.7944 - r_square: 0.0902 - val_loss: 1.0227 - val_root_mean_squared_error: 1.0113 - val_mean_absolute_error: 0.7949 - val_r_square: 0.0904 - lr: 3.1250e-05
# Epoch 25/25
# 156147/156147 [==============================] - 371s 2ms/step - loss: 1.0229 - root_mean_squared_error: 1.0114 - mean_absolute_error: 0.7943 - r_square: 0.0906 - val_loss: 1.0247 - val_root_mean_squared_error: 1.0123 - val_mean_absolute_error: 0.7972 - val_r_square: 0.0887 - lr: 1.5625e-05

# %% [markdown]
# #### After fitting

# %%
metric_name = ['Loss', 'RootMSE', 'MAE', 'R2']
train_metric = ['loss', 'root_mean_squared_error', 'mean_absolute_error', 'r_square']
val_metric = ['val_loss', 'val_root_mean_squared_error', 'val_mean_absolute_error', 'val_r_square']

for i in range(len(metric_name)):

  print(f"\n----------- {metric_name[i]} chart -----------\n")

  # matplotlib chart
  plt.plot(trained_model.history[train_metric[i]], label=f"Train {metric_name[i]}")
  plt.plot(trained_model.history[val_metric[i]], label=f"Val {metric_name[i]}")
  plt.legend()
  plt.show()
# Out:
# ----------- Loss chart -----------
# ----------- RootMSE chart -----------
# ----------- MAE chart -----------
# ----------- R2 chart -----------

# %%
# Validation data values in the last epoch
print("number of epochs:", trained_model.epoch[-1] + 1)
print("val_loss:", trained_model.history['val_loss'][-1])
print("val_root_mean_squared_error:", trained_model.history['val_root_mean_squared_error'][-1])
print("val_mean_absolute_error:", trained_model.history['val_mean_absolute_error'][-1])
print("val_r2_score:", trained_model.history['val_r_square'][-1])
# Out:
# number of epochs: 25
# val_loss: 1.0246753692626953
# val_root_mean_squared_error: 1.0122624635696411
# val_mean_absolute_error: 0.7971854209899902
# val_r2_score: 0.08870917558670044

# %%
# Evaluate the model on the test data
print("Evaluate on test data")
test_loss, test_mean_squared_error, test_mean_absolute_error, test_r2_score = my_model.evaluate(test_data, test_target_ratings)
print("Test_loss:", test_loss)
print("Test_root_mean_squared_error:", test_mean_squared_error)
print("Test_mean_absolute_error:", test_mean_absolute_error)
print("Test_r2_score:", test_r2_score)
print('\n')

print("Generate predictions for 10 samples")
predictions = my_model.predict(test_data)
test_y_comparison = pd.DataFrame({'test_y_true': test_target_ratings, 'test_y_pred': [x for x in predictions]})

print(test_y_comparison.head(10))
# Out:
# Evaluate on test data
# 78074/78074 [==============================] - 107s 1ms/step - loss: 1.0283 - root_mean_squared_error: 1.0141 - mean_absolute_error: 0.7978 - r_square: 0.0869
# Test_loss: 1.0283268690109253
# Test_root_mean_squared_error: 1.0140645503997803
# Test_mean_absolute_error: 0.7977995276451111
# Test_r2_score: 0.08692634105682373
#
#
# Generate predictions for 10 samples
# 78074/78074 [==============================] - 60s 770us/step
#    test_y_true  test_y_pred
# 0          4.0  [3.3292449]
# 1          4.5   [3.614739]
# 2          2.5   [3.171001]
# 3          4.5  [3.5604756]
# 4          3.5  [3.7966046]
# 5          3.5  [3.3292449]
# 6          3.0  [3.7395945]
# 7          3.0  [3.3292449]
# 8          4.0  [3.8367872]
# 9          1.5  [3.5604756]

# %%
if wandb_log:
  wandb.finish()
# Out:
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch/epoch</td><td>▁▁▂▂▂▂▃▃▃▄▄▄▅▅▅▅▆▆▆▇▇▇▇██</td></tr><tr><td>epoch/learning_rate</td><td>████▄▄▄▄▃▃▃▃▂▂▂▂▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/loss</td><td>█▆▆▇▅▅▅▅▄▃▃▃▃▂▂▂▂▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/lr</td><td>████▄▄▄▄▃▃▃▃▂▂▂▂▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/mean_absolute_error</td><td>█▆▆▇▆▅▅▅▄▄▄▃▃▂▂▂▂▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/r_square</td><td>▁▃▃▂▃▄▄▄▅▅▆▆▆▇▇▇▇████████</td></tr><tr><td>epoch/root_mean_squared_error</td><td>█▆▆▇▆▅▅▅▄▃▃▃▃▂▂▂▂▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/val_loss</td><td>▆▆▅█▄▅▄▆▄▄▃▃▃▃▂▂▂▂▂▂▂▂▁▁▂</td></tr><tr><td>epoch/val_mean_absolute_error</td><td>█▅▆▆▄▃▅▇▅▃▂▂▄▄▃▁▂▃▃▃▂▃▁▁▂</td></tr><tr><td>epoch/val_r_square</td><td>▃▃▄▁▅▄▅▃▅▅▆▆▆▆▇▇▇▇▇▇▇▇██▇</td></tr><tr><td>epoch/val_root_mean_squared_error</td><td>▆▆▅█▄▅▄▆▄▄▃▃▃▃▂▂▂▂▂▂▂▂▁▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/epoch</td><td>24</td></tr><tr><td>epoch/learning_rate</td><td>2e-05</td></tr><tr><td>epoch/loss</td><td>1.0229</td></tr><tr><td>epoch/lr</td><td>2e-05</td></tr><tr><td>epoch/mean_absolute_error</td><td>0.79428</td></tr><tr><td>epoch/r_square</td><td>0.09058</td></tr><tr><td>epoch/root_mean_squared_error</td><td>1.01138</td></tr><tr><td>epoch/val_loss</td><td>1.02468</td></tr><tr><td>epoch/val_mean_absolute_error</td><td>0.79719</td></tr><tr><td>epoch/val_r_square</td><td>0.08871</td></tr><tr><td>epoch/val_root_mean_squared_error</td><td>1.01226</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">arch6_exp5_25m_added_imdb_context_max_abs_scaler_lr_exp_decay_gn</strong> at: <a href='https://wandb.ai/xbarantomik/dp/runs/ca4znyov' target="_blank">https://wandb.ai/xbarantomik/dp/runs/ca4znyov</a><br/> View project at: <a href='https://wandb.ai/xbarantomik/dp' target="_blank">https://wandb.ai/xbarantomik/dp</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240509_111342-ca4znyov/logs</code>
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
