# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import load_model
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json

# %%
checkpoint_model_filepath = 'checkpoints/'
trained_model_filepath = 'trained_models/'
training_data_path = 'data_25m/'
nn_config_path = '../config/nn_config.json'
wandb_config_path = '../config/wandb_config.json'

print('Training data path:', training_data_path)

import nn_model
# Out:
# Running on Colab
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Training data path: /content/drive/MyDrive/DP/training/data_1m/

# %%
try:
  with open(wandb_config_path, 'r') as f:
    wandb_config = json.load(f)

  wandb_log = True
  wandb_run_name = wandb_config["wandb_run_name"]
  wandb_group_name = wandb_config["wandb_group_name"]
  wandb_entity = wandb_config["wandb_entity"]
  wandb_project_name = wandb_config["wandb_project_name"]
  if wandb_config["new_model"] == 'false':
    new_model = False
  else:
    new_model = True
  run_name_before = wandb_config["run_name_before"]   # Model to be loaded
  if wandb_config["eval_only"] == 'false':
    eval_only = False
  else:
    eval_only = True

  print('wandb_log:', wandb_log)
  print('wandb_run_name:', wandb_run_name)
  print('wandb_group_name:', wandb_group_name)
  print('wandb_entity:', wandb_entity)
  print('wandb_project_name:', wandb_project_name)
  print('new_model:', new_model)
  print('run_name_before:', run_name_before)
  print('eval_only:', eval_only)

except OSError as e:
  print('\nERROR loading wandb_config file')
  print(e)
  # quit()
# Out:
# wandb_log: True
# wandb_run_name: arch4_1m_lr_context_data
# wandb_group_name: 1m_deep_dense
# wandb_entity: xbarantomik
# wandb_project_name: DP
# new_model: True
# run_name_before: -
# eval_only: False

# %%
try:
  with open(nn_config_path, 'r') as f:
    nn_config = json.load(f)

  epochs = int(nn_config['epochs'])
  batch_size = int(nn_config['batch_size'])
  patience = int(nn_config['patience'])
  learning_rate = float(nn_config['learning_rate'])
  architecture = int(nn_config['architecture'])
  training_data_file = nn_config['training_data_file'] + '/'

  print('epochs:', epochs)
  print('batch_size:', batch_size)
  print('patience:', patience)
  print('learning_rate:', learning_rate)
  print('architecture:', architecture)
  print('training_data_file:', training_data_file)

except OSError as e:
  print('\nERROR loading nn_config file')
  print(e)
  # quit()
# Out:
# epochs: 25
# batch_size: 128
# patience: 15
# learning_rate: 0.001
# architecture: 4
# training_data_file: lr_context_data/

# %% [markdown]
# #### Load training data

# %%
try:
  train_data = np.load(training_data_path + training_data_file + 'train_data.npy')
  val_data = np.load(training_data_path + training_data_file + 'val_data.npy')
  test_data = np.load(training_data_path + training_data_file + 'test_data.npy')
  train_target_ratings = np.load(training_data_path + training_data_file + 'train_target_ratings.npy')
  val_target_ratings = np.load(training_data_path + training_data_file + 'val_target_ratings.npy')
  test_target_ratings = np.load(training_data_path + training_data_file + 'test_target_ratings.npy')

except OSError as e:
  print('\nERROR loading training data')
  print(e)
  quit()

# %%
if wandb_log:
  import wandb
  from wandb.keras import WandbMetricsLogger, WandbModelCheckpoint

  wandb.login()

  wandb.init(
    config=nn_config,
    entity=wandb_entity,
    project=wandb_project_name,
    name=wandb_run_name,
    group=wandb_group_name
  )
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: xbarantomik. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/content/wandb/run-20240504_003431-q78rcrle</code>
# Syncing run <strong><a href='https://wandb.ai/xbarantomik/dp/runs/q78rcrle' target="_blank">arch4_1m_lr_context_data</a></strong> to <a href='https://wandb.ai/xbarantomik/dp' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/xbarantomik/dp' target="_blank">https://wandb.ai/xbarantomik/dp</a>
#  View run at <a href='https://wandb.ai/xbarantomik/dp/runs/q78rcrle' target="_blank">https://wandb.ai/xbarantomik/dp/runs/q78rcrle</a>

# %% [markdown]
# #### NN MODEL

# %%
early_stopping = EarlyStopping(patience=patience, monitor='val_loss')

# %%
checkpoint_filepath = checkpoint_model_filepath + f"{wandb_run_name}_checkpoint.h5"
checkpoint_callback = ModelCheckpoint(filepath=checkpoint_filepath, monitor='val_loss', save_best_only=True, mode='min', save_weights_only=False, save_format='tf')

if wandb_log:
  callbacks = [early_stopping, checkpoint_callback, WandbMetricsLogger()]

else:
  callbacks = [early_stopping, checkpoint_callback]

# %% [markdown]
# #### Create model

# %%
if new_model:
  my_model = nn_model.create_model(architecture=architecture, lr=learning_rate, train_data_shape=train_data.shape[1])
  print('\nCreated a new model')
else:
  my_model = load_model(checkpoint_model_filepath + run_name_before + '_checkpoint.h5')
  print('\nLoaded a model')

if my_model != None:
  my_model.summary()
else:
  print('\nERROR loading NN model')
  quit()
# Out:
# Model 4
#
# Created a new model
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               6144
#
#  activation (Activation)     (None, 512)               0
#
#  dropout (Dropout)           (None, 512)               0
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  activation_1 (Activation)   (None, 512)               0
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 256)               131328
#
#  activation_2 (Activation)   (None, 256)               0
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 400385 (1.53 MB)
# Trainable params: 400385 (1.53 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Model fitting

# %%
if not eval_only:
  print('Training model')
  trained_model = my_model.fit(train_data, train_target_ratings, batch_size, epochs, validation_data=(val_data, val_target_ratings), callbacks=callbacks, verbose=1)
  my_model.save(trained_model_filepath + f"{wandb_run_name}_trained.keras")
else:
  print('Only evaluating model')
# Out:
# Training model
# Epoch 1/25
# 6252/6252 [==============================] - 29s 4ms/step - loss: 1.2417 - root_mean_squared_error: 1.1143 - mean_absolute_error: 0.9079 - val_loss: 1.1830 - val_root_mean_squared_error: 1.0877 - val_mean_absolute_error: 0.8808
# Epoch 2/25
#   23/6252 [..............................] - ETA: 29s - loss: 1.2530 - root_mean_squared_error: 1.1194 - mean_absolute_error: 0.9132
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 6252/6252 [==============================] - 29s 5ms/step - loss: 1.1928 - root_mean_squared_error: 1.0921 - mean_absolute_error: 0.8909 - val_loss: 1.1762 - val_root_mean_squared_error: 1.0845 - val_mean_absolute_error: 0.8794
# Epoch 3/25
# 6252/6252 [==============================] - 24s 4ms/step - loss: 1.1830 - root_mean_squared_error: 1.0876 - mean_absolute_error: 0.8871 - val_loss: 1.1663 - val_root_mean_squared_error: 1.0799 - val_mean_absolute_error: 0.8821
# Epoch 4/25
# 6252/6252 [==============================] - 24s 4ms/step - loss: 1.1763 - root_mean_squared_error: 1.0846 - mean_absolute_error: 0.8846 - val_loss: 1.1653 - val_root_mean_squared_error: 1.0795 - val_mean_absolute_error: 0.8842
# Epoch 5/25
# 6252/6252 [==============================] - 25s 4ms/step - loss: 1.1723 - root_mean_squared_error: 1.0827 - mean_absolute_error: 0.8831 - val_loss: 1.1610 - val_root_mean_squared_error: 1.0775 - val_mean_absolute_error: 0.8777
# Epoch 6/25
# 6252/6252 [==============================] - 27s 4ms/step - loss: 1.1686 - root_mean_squared_error: 1.0810 - mean_absolute_error: 0.8817 - val_loss: 1.1594 - val_root_mean_squared_error: 1.0767 - val_mean_absolute_error: 0.8745
# Epoch 7/25
# 6252/6252 [==============================] - 25s 4ms/step - loss: 1.1657 - root_mean_squared_error: 1.0797 - mean_absolute_error: 0.8804 - val_loss: 1.1579 - val_root_mean_squared_error: 1.0760 - val_mean_absolute_error: 0.8760
# Epoch 8/25
# 6252/6252 [==============================] - 23s 4ms/step - loss: 1.1635 - root_mean_squared_error: 1.0787 - mean_absolute_error: 0.8797 - val_loss: 1.1582 - val_root_mean_squared_error: 1.0762 - val_mean_absolute_error: 0.8771
# Epoch 9/25
# 6252/6252 [==============================] - 22s 4ms/step - loss: 1.1618 - root_mean_squared_error: 1.0779 - mean_absolute_error: 0.8788 - val_loss: 1.1595 - val_root_mean_squared_error: 1.0768 - val_mean_absolute_error: 0.8788
# Epoch 10/25
# 6252/6252 [==============================] - 23s 4ms/step - loss: 1.1601 - root_mean_squared_error: 1.0771 - mean_absolute_error: 0.8782 - val_loss: 1.1622 - val_root_mean_squared_error: 1.0781 - val_mean_absolute_error: 0.8706
# Epoch 11/25
# 6252/6252 [==============================] - 23s 4ms/step - loss: 1.1577 - root_mean_squared_error: 1.0760 - mean_absolute_error: 0.8774 - val_loss: 1.1537 - val_root_mean_squared_error: 1.0741 - val_mean_absolute_error: 0.8707
# Epoch 12/25
# 6252/6252 [==============================] - 24s 4ms/step - loss: 1.1564 - root_mean_squared_error: 1.0754 - mean_absolute_error: 0.8770 - val_loss: 1.1554 - val_root_mean_squared_error: 1.0749 - val_mean_absolute_error: 0.8770
# Epoch 13/25
# 6252/6252 [==============================] - 23s 4ms/step - loss: 1.1549 - root_mean_squared_error: 1.0747 - mean_absolute_error: 0.8761 - val_loss: 1.1540 - val_root_mean_squared_error: 1.0742 - val_mean_absolute_error: 0.8762
# Epoch 14/25
# 6252/6252 [==============================] - 23s 4ms/step - loss: 1.1541 - root_mean_squared_error: 1.0743 - mean_absolute_error: 0.8761 - val_loss: 1.1531 - val_root_mean_squared_error: 1.0738 - val_mean_absolute_error: 0.8708
# Epoch 15/25
# 6252/6252 [==============================] - 22s 4ms/step - loss: 1.1534 - root_mean_squared_error: 1.0739 - mean_absolute_error: 0.8759 - val_loss: 1.1534 - val_root_mean_squared_error: 1.0740 - val_mean_absolute_error: 0.8731
# Epoch 16/25
# 6252/6252 [==============================] - 25s 4ms/step - loss: 1.1525 - root_mean_squared_error: 1.0736 - mean_absolute_error: 0.8757 - val_loss: 1.1522 - val_root_mean_squared_error: 1.0734 - val_mean_absolute_error: 0.8709
# Epoch 17/25
# 6252/6252 [==============================] - 25s 4ms/step - loss: 1.1520 - root_mean_squared_error: 1.0733 - mean_absolute_error: 0.8755 - val_loss: 1.1540 - val_root_mean_squared_error: 1.0742 - val_mean_absolute_error: 0.8764
# Epoch 18/25
# 6252/6252 [==============================] - 28s 4ms/step - loss: 1.1516 - root_mean_squared_error: 1.0731 - mean_absolute_error: 0.8752 - val_loss: 1.1522 - val_root_mean_squared_error: 1.0734 - val_mean_absolute_error: 0.8769
# Epoch 19/25
# 6252/6252 [==============================] - 25s 4ms/step - loss: 1.1509 - root_mean_squared_error: 1.0728 - mean_absolute_error: 0.8749 - val_loss: 1.1504 - val_root_mean_squared_error: 1.0726 - val_mean_absolute_error: 0.8756
# Epoch 20/25
# 6252/6252 [==============================] - 24s 4ms/step - loss: 1.1506 - root_mean_squared_error: 1.0726 - mean_absolute_error: 0.8750 - val_loss: 1.1488 - val_root_mean_squared_error: 1.0718 - val_mean_absolute_error: 0.8743
# Epoch 21/25
# 6252/6252 [==============================] - 23s 4ms/step - loss: 1.1500 - root_mean_squared_error: 1.0724 - mean_absolute_error: 0.8748 - val_loss: 1.1491 - val_root_mean_squared_error: 1.0720 - val_mean_absolute_error: 0.8699
# Epoch 22/25
# 6252/6252 [==============================] - 30s 5ms/step - loss: 1.1492 - root_mean_squared_error: 1.0720 - mean_absolute_error: 0.8743 - val_loss: 1.1505 - val_root_mean_squared_error: 1.0726 - val_mean_absolute_error: 0.8724
# Epoch 23/25
# 6252/6252 [==============================] - 26s 4ms/step - loss: 1.1485 - root_mean_squared_error: 1.0717 - mean_absolute_error: 0.8738 - val_loss: 1.1528 - val_root_mean_squared_error: 1.0737 - val_mean_absolute_error: 0.8761
# Epoch 24/25
# 6252/6252 [==============================] - 24s 4ms/step - loss: 1.1483 - root_mean_squared_error: 1.0716 - mean_absolute_error: 0.8737 - val_loss: 1.1439 - val_root_mean_squared_error: 1.0695 - val_mean_absolute_error: 0.8714
# Epoch 25/25
# 6252/6252 [==============================] - 24s 4ms/step - loss: 1.1474 - root_mean_squared_error: 1.0712 - mean_absolute_error: 0.8734 - val_loss: 1.1422 - val_root_mean_squared_error: 1.0687 - val_mean_absolute_error: 0.8718

# %% [markdown]
# #### After fitting

# %%
metric_name = ['Loss', 'RootMSE', 'MAE']
train_metric = ['loss', 'root_mean_squared_error', 'mean_absolute_error']
val_metric = ['val_loss', 'val_root_mean_squared_error', 'val_mean_absolute_error']

for i in range(len(metric_name)):

  print(f"\n----------- {metric_name[i]} chart -----------\n")

  # matplotlib chart
  plt.plot(trained_model.history[train_metric[i]], label=f"Train {metric_name[i]}")
  plt.plot(trained_model.history[val_metric[i]], label=f"Val {metric_name[i]}")
  plt.legend()
  plt.show()
# Out:
# ----------- Loss chart -----------
# ----------- RootMSE chart -----------
# ----------- MAE chart -----------

# %%
# Validation data values in the last epoch
print("number of epochs:", trained_model.epoch[-1] + 1)
print("val_loss:", trained_model.history['val_loss'][-1])
print("val_root_mean_squared_error:", trained_model.history['val_root_mean_squared_error'][-1])
print("val_mean_absolute_error:", trained_model.history['val_mean_absolute_error'][-1])
# Out:
# number of epochs: 25
# val_loss: 1.1421602964401245
# val_root_mean_squared_error: 1.0687189102172852
# val_mean_absolute_error: 0.8717858195304871

# %%
# Evaluate the model on the test data
print("Evaluate on test data")
test_loss, test_mean_squared_error, test_mean_absolute_error = my_model.evaluate(test_data, test_target_ratings)
print("Test_loss:", test_loss)
print("Test_root_mean_squared_error:", test_mean_squared_error)
print("Test_mean_absolute_error:", test_mean_absolute_error)
print('\n')

print("Generate predictions for 10 samples")
predictions = my_model.predict(test_data)
test_y_comparison = pd.DataFrame({'test_y_true': test_target_ratings, 'test_y_pred': [x for x in predictions]})

print(test_y_comparison.head(10))
# Out:
# Evaluate on test data
# 3126/3126 [==============================] - 7s 2ms/step - loss: 1.1445 - root_mean_squared_error: 1.0698 - mean_absolute_error: 0.8734
# Test_loss: 1.1445142030715942
# Test_root_mean_squared_error: 1.069819688796997
# Test_mean_absolute_error: 0.8733557462692261
#
#
# Generate predictions for 10 samples
# 3126/3126 [==============================] - 5s 1ms/step
#    test_y_true  test_y_pred
# 0            4  [3.6867952]
# 1            3  [3.2825828]
# 2            5  [3.4081123]
# 3            5  [4.0448995]
# 4            4  [4.0448995]
# 5            4  [3.6702504]
# 6            4   [4.316164]
# 7            3  [4.1128726]
# 8            1  [3.2372837]
# 9            5    [4.02911]

# %%
if wandb_log:
  wandb.finish()
# Out:
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch/epoch</td><td>▁▁▂▂▂▂▃▃▃▄▄▄▅▅▅▅▆▆▆▇▇▇▇██</td></tr><tr><td>epoch/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/loss</td><td>█▄▄▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/mean_absolute_error</td><td>█▅▄▃▃▃▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/root_mean_squared_error</td><td>█▄▄▃▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/val_loss</td><td>█▇▅▅▄▄▄▄▄▄▃▃▃▃▃▃▃▃▂▂▂▂▃▁▁</td></tr><tr><td>epoch/val_mean_absolute_error</td><td>▆▆▇█▅▃▄▅▅▁▁▄▄▁▃▁▄▄▄▃▁▂▄▂▂</td></tr><tr><td>epoch/val_root_mean_squared_error</td><td>█▇▅▅▄▄▄▄▄▄▃▃▃▃▃▃▃▃▂▂▂▂▃▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/epoch</td><td>24</td></tr><tr><td>epoch/learning_rate</td><td>0.001</td></tr><tr><td>epoch/loss</td><td>1.1474</td></tr><tr><td>epoch/mean_absolute_error</td><td>0.87337</td></tr><tr><td>epoch/root_mean_squared_error</td><td>1.07117</td></tr><tr><td>epoch/val_loss</td><td>1.14216</td></tr><tr><td>epoch/val_mean_absolute_error</td><td>0.87179</td></tr><tr><td>epoch/val_root_mean_squared_error</td><td>1.06872</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">arch4_1m_lr_context_data</strong> at: <a href='https://wandb.ai/xbarantomik/dp/runs/q78rcrle' target="_blank">https://wandb.ai/xbarantomik/dp/runs/q78rcrle</a><br/> View project at: <a href='https://wandb.ai/xbarantomik/dp' target="_blank">https://wandb.ai/xbarantomik/dp</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240504_003431-q78rcrle/logs</code>
