# %% [markdown]
# ## Experiment 2 - Feature selection - L1

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import load_model
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json

# %%
checkpoint_model_filepath = 'checkpoints/'
trained_model_filepath = 'trained_models/'
training_data_path = 'data_1m/'
nn_config_path = '../config/nn_config.json'
wandb_config_path = '../config/wandb_config.json'

print('Training data path:', training_data_path)

import nn_model
# Out:
# Running on Colab
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Training data path: /content/drive/MyDrive/DP/training/data_1m/

# %%
try:
  with open(wandb_config_path, 'r') as f:
    wandb_config = json.load(f)

  wandb_log = True
  wandb_run_name = wandb_config["wandb_run_name"]
  wandb_group_name = wandb_config["wandb_group_name"]
  wandb_entity = wandb_config["wandb_entity"]
  wandb_project_name = wandb_config["wandb_project_name"]
  if wandb_config["new_model"] == 'false':
    new_model = False
  else:
    new_model = True
  run_name_before = wandb_config["run_name_before"]   # Model to be loaded
  if wandb_config["eval_only"] == 'false':
    eval_only = False
  else:
    eval_only = True

  print('wandb_log:', wandb_log)
  print('wandb_run_name:', wandb_run_name)
  print('wandb_group_name:', wandb_group_name)
  print('wandb_entity:', wandb_entity)
  print('wandb_project_name:', wandb_project_name)
  print('new_model:', new_model)
  print('run_name_before:', run_name_before)
  print('eval_only:', eval_only)

except OSError as e:
  print('\nERROR loading wandb_config file')
  print(e)
  # quit()
# Out:
# wandb_log: True
# wandb_run_name: arch4_1m_l1_context_data
# wandb_group_name: 1m_deep_dense
# wandb_entity: xbarantomik
# wandb_project_name: DP
# new_model: True
# run_name_before: -
# eval_only: False

# %%
try:
  with open(nn_config_path, 'r') as f:
    nn_config = json.load(f)

  epochs = int(nn_config['epochs'])
  batch_size = int(nn_config['batch_size'])
  patience = int(nn_config['patience'])
  learning_rate = float(nn_config['learning_rate'])
  architecture = int(nn_config['architecture'])
  training_data_file = nn_config['training_data_file'] + '/'

  print('epochs:', epochs)
  print('batch_size:', batch_size)
  print('patience:', patience)
  print('learning_rate:', learning_rate)
  print('architecture:', architecture)
  print('training_data_file:', training_data_file)

except OSError as e:
  print('\nERROR loading nn_config file')
  print(e)
  # quit()
# Out:
# epochs: 25
# batch_size: 128
# patience: 15
# learning_rate: 0.001
# architecture: 4
# training_data_file: l1_context_data/

# %% [markdown]
# #### Load training data

# %%
try:
  train_data = np.load(training_data_path + training_data_file + 'train_data.npy')
  val_data = np.load(training_data_path + training_data_file + 'val_data.npy')
  test_data = np.load(training_data_path + training_data_file + 'test_data.npy')
  train_target_ratings = np.load(training_data_path + training_data_file + 'train_target_ratings.npy')
  val_target_ratings = np.load(training_data_path + training_data_file + 'val_target_ratings.npy')
  test_target_ratings = np.load(training_data_path + training_data_file + 'test_target_ratings.npy')

except OSError as e:
  print('\nERROR loading training data')
  print(e)
  quit()

# %%
if wandb_log:
  import wandb
  from wandb.keras import WandbMetricsLogger, WandbModelCheckpoint

  wandb.login()

  wandb.init(
    config=nn_config,
    entity=wandb_entity,
    project=wandb_project_name,
    name=wandb_run_name,
    group=wandb_group_name
  )
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: xbarantomik. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/content/wandb/run-20240504_104841-0stesmpo</code>
# Syncing run <strong><a href='https://wandb.ai/xbarantomik/dp/runs/0stesmpo' target="_blank">arch4_1m_l1_context_data</a></strong> to <a href='https://wandb.ai/xbarantomik/dp' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/xbarantomik/dp' target="_blank">https://wandb.ai/xbarantomik/dp</a>
#  View run at <a href='https://wandb.ai/xbarantomik/dp/runs/0stesmpo' target="_blank">https://wandb.ai/xbarantomik/dp/runs/0stesmpo</a>

# %% [markdown]
# #### NN MODEL

# %%
early_stopping = EarlyStopping(patience=patience, monitor='val_loss')

# %%
checkpoint_filepath = checkpoint_model_filepath + f"{wandb_run_name}_checkpoint.h5"
checkpoint_callback = ModelCheckpoint(filepath=checkpoint_filepath, monitor='val_loss', save_best_only=True, mode='min', save_weights_only=False, save_format='tf')

if wandb_log:
  callbacks = [early_stopping, checkpoint_callback, WandbMetricsLogger()]

else:
  callbacks = [early_stopping, checkpoint_callback]

# %% [markdown]
# #### Create model

# %%
if new_model:
  my_model = nn_model.create_model(architecture=architecture, lr=learning_rate, train_data_shape=train_data.shape[1])
  print('\nCreated a new model')
else:
  my_model = load_model(checkpoint_model_filepath + run_name_before + '_checkpoint.h5')
  print('\nLoaded a model')

if my_model != None:
  my_model.summary()
else:
  print('\nERROR loading NN model')
  quit()
# Out:
# Model 4
#
# Created a new model
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               15872
#
#  activation (Activation)     (None, 512)               0
#
#  dropout (Dropout)           (None, 512)               0
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  activation_1 (Activation)   (None, 512)               0
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 256)               131328
#
#  activation_2 (Activation)   (None, 256)               0
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 410113 (1.56 MB)
# Trainable params: 410113 (1.56 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Model fitting

# %%
if not eval_only:
  print('Training model')
  trained_model = my_model.fit(train_data, train_target_ratings, batch_size, epochs, validation_data=(val_data, val_target_ratings), callbacks=callbacks, verbose=1)
  my_model.save(trained_model_filepath + f"{wandb_run_name}_trained.keras")
else:
  print('Only evaluating model')
# Out:
# Training model
# Epoch 1/25
# 6252/6252 [==============================] - ETA: 0s - loss: 1.2240 - root_mean_squared_error: 1.1063 - mean_absolute_error: 0.8991
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 6252/6252 [==============================] - 26s 4ms/step - loss: 1.2240 - root_mean_squared_error: 1.1063 - mean_absolute_error: 0.8991 - val_loss: 1.1476 - val_root_mean_squared_error: 1.0713 - val_mean_absolute_error: 0.8630
# Epoch 2/25
# 6252/6252 [==============================] - 21s 3ms/step - loss: 1.1625 - root_mean_squared_error: 1.0782 - mean_absolute_error: 0.8758 - val_loss: 1.1290 - val_root_mean_squared_error: 1.0625 - val_mean_absolute_error: 0.8582
# Epoch 3/25
# 6252/6252 [==============================] - 21s 3ms/step - loss: 1.1426 - root_mean_squared_error: 1.0689 - mean_absolute_error: 0.8673 - val_loss: 1.1159 - val_root_mean_squared_error: 1.0564 - val_mean_absolute_error: 0.8553
# Epoch 4/25
# 6252/6252 [==============================] - 21s 3ms/step - loss: 1.1307 - root_mean_squared_error: 1.0634 - mean_absolute_error: 0.8623 - val_loss: 1.1128 - val_root_mean_squared_error: 1.0549 - val_mean_absolute_error: 0.8517
# Epoch 5/25
# 6252/6252 [==============================] - 21s 3ms/step - loss: 1.1233 - root_mean_squared_error: 1.0598 - mean_absolute_error: 0.8592 - val_loss: 1.1091 - val_root_mean_squared_error: 1.0531 - val_mean_absolute_error: 0.8560
# Epoch 6/25
# 6252/6252 [==============================] - 21s 3ms/step - loss: 1.1168 - root_mean_squared_error: 1.0568 - mean_absolute_error: 0.8566 - val_loss: 1.1063 - val_root_mean_squared_error: 1.0518 - val_mean_absolute_error: 0.8579
# Epoch 7/25
# 6252/6252 [==============================] - 21s 3ms/step - loss: 1.1117 - root_mean_squared_error: 1.0544 - mean_absolute_error: 0.8545 - val_loss: 1.0993 - val_root_mean_squared_error: 1.0485 - val_mean_absolute_error: 0.8481
# Epoch 8/25
# 6252/6252 [==============================] - 21s 3ms/step - loss: 1.1074 - root_mean_squared_error: 1.0523 - mean_absolute_error: 0.8525 - val_loss: 1.0994 - val_root_mean_squared_error: 1.0485 - val_mean_absolute_error: 0.8451
# Epoch 9/25
# 6252/6252 [==============================] - 21s 3ms/step - loss: 1.1039 - root_mean_squared_error: 1.0507 - mean_absolute_error: 0.8508 - val_loss: 1.0949 - val_root_mean_squared_error: 1.0464 - val_mean_absolute_error: 0.8445
# Epoch 10/25
# 6252/6252 [==============================] - 21s 3ms/step - loss: 1.1013 - root_mean_squared_error: 1.0494 - mean_absolute_error: 0.8494 - val_loss: 1.0943 - val_root_mean_squared_error: 1.0461 - val_mean_absolute_error: 0.8458
# Epoch 11/25
# 6252/6252 [==============================] - 21s 3ms/step - loss: 1.0992 - root_mean_squared_error: 1.0484 - mean_absolute_error: 0.8480 - val_loss: 1.0929 - val_root_mean_squared_error: 1.0454 - val_mean_absolute_error: 0.8346
# Epoch 12/25
# 6252/6252 [==============================] - 21s 3ms/step - loss: 1.0968 - root_mean_squared_error: 1.0473 - mean_absolute_error: 0.8472 - val_loss: 1.0901 - val_root_mean_squared_error: 1.0441 - val_mean_absolute_error: 0.8447
# Epoch 13/25
# 6252/6252 [==============================] - 21s 3ms/step - loss: 1.0950 - root_mean_squared_error: 1.0464 - mean_absolute_error: 0.8464 - val_loss: 1.0887 - val_root_mean_squared_error: 1.0434 - val_mean_absolute_error: 0.8465
# Epoch 14/25
# 6252/6252 [==============================] - 21s 3ms/step - loss: 1.0939 - root_mean_squared_error: 1.0459 - mean_absolute_error: 0.8461 - val_loss: 1.0879 - val_root_mean_squared_error: 1.0430 - val_mean_absolute_error: 0.8385
# Epoch 15/25
# 6252/6252 [==============================] - 21s 3ms/step - loss: 1.0919 - root_mean_squared_error: 1.0449 - mean_absolute_error: 0.8452 - val_loss: 1.0843 - val_root_mean_squared_error: 1.0413 - val_mean_absolute_error: 0.8412
# Epoch 16/25
# 6252/6252 [==============================] - 21s 3ms/step - loss: 1.0904 - root_mean_squared_error: 1.0442 - mean_absolute_error: 0.8447 - val_loss: 1.0837 - val_root_mean_squared_error: 1.0410 - val_mean_absolute_error: 0.8431
# Epoch 17/25
# 6252/6252 [==============================] - 21s 3ms/step - loss: 1.0891 - root_mean_squared_error: 1.0436 - mean_absolute_error: 0.8440 - val_loss: 1.0816 - val_root_mean_squared_error: 1.0400 - val_mean_absolute_error: 0.8387
# Epoch 18/25
# 6252/6252 [==============================] - 21s 3ms/step - loss: 1.0880 - root_mean_squared_error: 1.0431 - mean_absolute_error: 0.8437 - val_loss: 1.0840 - val_root_mean_squared_error: 1.0412 - val_mean_absolute_error: 0.8434
# Epoch 19/25
# 6252/6252 [==============================] - 21s 3ms/step - loss: 1.0868 - root_mean_squared_error: 1.0425 - mean_absolute_error: 0.8431 - val_loss: 1.0805 - val_root_mean_squared_error: 1.0395 - val_mean_absolute_error: 0.8376
# Epoch 20/25
# 6252/6252 [==============================] - 21s 3ms/step - loss: 1.0854 - root_mean_squared_error: 1.0418 - mean_absolute_error: 0.8423 - val_loss: 1.0806 - val_root_mean_squared_error: 1.0395 - val_mean_absolute_error: 0.8343
# Epoch 21/25
# 6252/6252 [==============================] - 21s 3ms/step - loss: 1.0843 - root_mean_squared_error: 1.0413 - mean_absolute_error: 0.8421 - val_loss: 1.0776 - val_root_mean_squared_error: 1.0381 - val_mean_absolute_error: 0.8375
# Epoch 22/25
# 6252/6252 [==============================] - 21s 3ms/step - loss: 1.0830 - root_mean_squared_error: 1.0407 - mean_absolute_error: 0.8411 - val_loss: 1.0814 - val_root_mean_squared_error: 1.0399 - val_mean_absolute_error: 0.8433
# Epoch 23/25
# 6252/6252 [==============================] - 21s 3ms/step - loss: 1.0822 - root_mean_squared_error: 1.0403 - mean_absolute_error: 0.8409 - val_loss: 1.0794 - val_root_mean_squared_error: 1.0389 - val_mean_absolute_error: 0.8393
# Epoch 24/25
# 6252/6252 [==============================] - 21s 3ms/step - loss: 1.0809 - root_mean_squared_error: 1.0397 - mean_absolute_error: 0.8402 - val_loss: 1.0765 - val_root_mean_squared_error: 1.0375 - val_mean_absolute_error: 0.8363
# Epoch 25/25
# 6252/6252 [==============================] - 21s 3ms/step - loss: 1.0801 - root_mean_squared_error: 1.0393 - mean_absolute_error: 0.8399 - val_loss: 1.0785 - val_root_mean_squared_error: 1.0385 - val_mean_absolute_error: 0.8323

# %% [markdown]
# #### After fitting

# %%
metric_name = ['Loss', 'RootMSE', 'MAE']
train_metric = ['loss', 'root_mean_squared_error', 'mean_absolute_error']
val_metric = ['val_loss', 'val_root_mean_squared_error', 'val_mean_absolute_error']

for i in range(len(metric_name)):

  print(f"\n----------- {metric_name[i]} chart -----------\n")

  # matplotlib chart
  plt.plot(trained_model.history[train_metric[i]], label=f"Train {metric_name[i]}")
  plt.plot(trained_model.history[val_metric[i]], label=f"Val {metric_name[i]}")
  plt.legend()
  plt.show()
# Out:
# ----------- Loss chart -----------
# ----------- RootMSE chart -----------
# ----------- MAE chart -----------

# %%
# Validation data values in the last epoch
print("number of epochs:", trained_model.epoch[-1] + 1)
print("val_loss:", trained_model.history['val_loss'][-1])
print("val_root_mean_squared_error:", trained_model.history['val_root_mean_squared_error'][-1])
print("val_mean_absolute_error:", trained_model.history['val_mean_absolute_error'][-1])
# Out:
# number of epochs: 25
# val_loss: 1.0784821510314941
# val_root_mean_squared_error: 1.0384999513626099
# val_mean_absolute_error: 0.8323385119438171

# %%
# Evaluate the model on the test data
print("Evaluate on test data")
test_loss, test_mean_squared_error, test_mean_absolute_error = my_model.evaluate(test_data, test_target_ratings)
print("Test_loss:", test_loss)
print("Test_root_mean_squared_error:", test_mean_squared_error)
print("Test_mean_absolute_error:", test_mean_absolute_error)
print('\n')

print("Generate predictions for 10 samples")
predictions = my_model.predict(test_data)
test_y_comparison = pd.DataFrame({'test_y_true': test_target_ratings, 'test_y_pred': [x for x in predictions]})

print(test_y_comparison.head(10))
# Out:
# Evaluate on test data
# 3126/3126 [==============================] - 6s 2ms/step - loss: 1.0805 - root_mean_squared_error: 1.0395 - mean_absolute_error: 0.8341
# Test_loss: 1.0805034637451172
# Test_root_mean_squared_error: 1.0394726991653442
# Test_mean_absolute_error: 0.8340965509414673
#
#
# Generate predictions for 10 samples
# 3126/3126 [==============================] - 4s 1ms/step
#    test_y_true  test_y_pred
# 0            4  [3.8302097]
# 1            3  [2.8787744]
# 2            5   [4.023525]
# 3            5   [4.083543]
# 4            4   [4.031886]
# 5            4  [3.7617736]
# 6            4   [4.380582]
# 7            3   [4.008021]
# 8            1  [3.3730886]
# 9            5  [3.9254894]

# %%
if wandb_log:
  wandb.finish()
# Out:
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch/epoch</td><td>▁▁▂▂▂▂▃▃▃▄▄▄▅▅▅▅▆▆▆▇▇▇▇██</td></tr><tr><td>epoch/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/loss</td><td>█▅▄▃▃▃▃▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/mean_absolute_error</td><td>█▅▄▄▃▃▃▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/root_mean_squared_error</td><td>█▅▄▄▃▃▃▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/val_loss</td><td>█▆▅▅▄▄▃▃▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁</td></tr><tr><td>epoch/val_mean_absolute_error</td><td>█▇▆▅▆▇▅▄▄▄▂▄▄▂▃▃▂▄▂▁▂▄▃▂▁</td></tr><tr><td>epoch/val_root_mean_squared_error</td><td>█▆▅▅▄▄▃▃▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/epoch</td><td>24</td></tr><tr><td>epoch/learning_rate</td><td>0.001</td></tr><tr><td>epoch/loss</td><td>1.08006</td></tr><tr><td>epoch/mean_absolute_error</td><td>0.83994</td></tr><tr><td>epoch/root_mean_squared_error</td><td>1.03926</td></tr><tr><td>epoch/val_loss</td><td>1.07848</td></tr><tr><td>epoch/val_mean_absolute_error</td><td>0.83234</td></tr><tr><td>epoch/val_root_mean_squared_error</td><td>1.0385</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">arch4_1m_l1_context_data</strong> at: <a href='https://wandb.ai/xbarantomik/dp/runs/0stesmpo' target="_blank">https://wandb.ai/xbarantomik/dp/runs/0stesmpo</a><br/> View project at: <a href='https://wandb.ai/xbarantomik/dp' target="_blank">https://wandb.ai/xbarantomik/dp</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240504_104841-0stesmpo/logs</code>
